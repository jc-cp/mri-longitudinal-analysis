# %%
# %pip install nibabel
# Out:
# Requirement already satisfied: nibabel in /home/jc053/anaconda3/envs/mri-longitudinal-analysis/lib/python3.11/site-packages (5.1.0)
# Requirement already satisfied: numpy>=1.19 in /home/jc053/anaconda3/envs/mri-longitudinal-analysis/lib/python3.11/site-packages (from nibabel) (1.24.3)
# Requirement already satisfied: packaging>=17 in /home/jc053/anaconda3/envs/mri-longitudinal-analysis/lib/python3.11/site-packages (from nibabel) (23.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import re
import pandas as pd
from pathlib import Path
import numpy as np
import shutil
import nibabel as nib
from tqdm import tqdm
from collections import defaultdict
from datetime import datetime

# %% [markdown]
# ## BCH Data (Additional): Change dates in clinical csv dataset to right format

# %%
# Function to convert dates to DD/MM/YYYY format
def convert_date(date_item):
    # Check for NaN values or empty strings and return as is
    if pd.isnull(date_item) or date_item == '':
        return np.nan

    # Convert to string and remove time part if present
    date_str = str(date_item).strip().split(' ')[0]

    # Define date formats for parsing
    date_formats = ("%m/%d/%Y", "%m/%d/%y", "%Y-%m-%d")

    for fmt in date_formats:
        try:
            # Parse date
            dt = datetime.strptime(date_str, fmt)

            if fmt == "%m/%d/%y":
                if dt.year >= 70:  # Cutoff year: 1970
                    dt = dt.replace(year=dt.year + 1900)
                else:
                    dt = dt.replace(year=dt.year + 2000)

            # Check if the month is greater than 12, then swap month and day
            if dt.month > 12:
                dt = dt.replace(month=dt.day, day=dt.month)

            # Convert to desired format
            return "'" + dt.strftime("%d/%m/%Y")
        except ValueError:
            continue  # if the format does not match, it will pass to the next format



# Function to process the Excel file
def process_excel(df, column_name):
    # Read the Excel file
    print("Column: ", column_name)
    # Check if the column exists
    if column_name not in df.columns:
        raise ValueError(f"The column {column_name} does not exist in the Excel file.")

    # Convert all dates in the column to DD/MM/YYYY format
    df[column_name] = df[column_name].apply(lambda x: convert_date(str(x)) if not pd.isnull(x) else x)

# %%
dates = ["8/26/82", "10/24/83", "02/10/1987", "07/12/1983"]
converted_dates = [convert_date(d) for d in dates]

for original, converted in zip(dates, converted_dates):
    print(f"Original: {original}, Converted: {converted}")
# Out:
# Original: 8/26/82, Converted: '26/08/3882
# Original: 10/24/83, Converted: '24/10/3883
# Original: 02/10/1987, Converted: '10/02/1987
# Original: 07/12/1983, Converted: '12/07/1983

# %%
input_excel_path = '/home/jc053/GIT/mri_longitudinal_analysis/data/redcap/bch_new_redcap.xlsx'
output_excel_path = 'revised_dates.xlsx'
date_column_names = ['Date of Birth', 'Date of last clinical follow-up', 'Date of diagnosis (Path, and MRI if no biopsy)', 'Date of MRI diagnosis','Date of first surgery', 'Date of Systemic Therapy Start','Start Date of Radiation'  ]

# Call the function with the paths and column name
df = pd.read_excel(input_excel_path)
for column in date_column_names:
    process_excel(df, column)
    
# Save the revised dates back to the Excel file
#df.to_excel(output_excel_path, index=False)
# Out:
# Column:  Date of Birth
# Column:  Date of last clinical follow-up
# Column:  Date of diagnosis (Path, and MRI if no biopsy)
# Column:  Date of MRI diagnosis
# Column:  Date of first surgery
# Column:  Date of Systemic Therapy Start
# Column:  Start Date of Radiation

# %% [markdown]
# ## BCH Data: Get the set of all patients for a given .csv file

# %%
def prefix_zeros_to_six_digit_ids(patient_id):
    """
    Adds 0 to the beginning of 6-digit patient IDs.
    """
    str_id = str(patient_id)
    if len(str_id) == 6:
        # print(f"Found a 6-digit ID: {str_id}. Prefixing a '0'.")
        patient_id = "0" + str_id

    else:
        patient_id = str_id
    return patient_id

def extract_unique_patient_ids_from_csv(csv_path):
    cohort = "BCH"
    id_column = "BCH MRN"
    df = pd.read_csv(csv_path)
    ids = set(df[id_column])
 
    print(f"Length of {cohort} cohort is {len(ids)}.")
    return ids

# %%
csv_path_bch_init = "/home/jc053/GIT/mri_longitudinal_analysis/data/input/clinical/bch_filtered_88.csv"
extract_unique_patient_ids_from_csv(csv_path_bch_init)
# Out:
# Length of BCH cohort is 88.
# {135939,
#  137476,
#  233126,
#  238268,
#  298046,
#  299321,
#  335968,
#  1013946,
#  1017646,
#  1058916,
#  1138934,
#  1153221,
#  1194890,
#  1232179,
#  2001398,
#  2004560,
#  2088116,
#  2088643,
#  2103993,
#  2104688,
#  2113964,
#  2124457,
#  2147101,
#  2158479,
#  2173072,
#  2183847,
#  2249514,
#  2260520,
#  2261605,
#  2280828,
#  2297464,
#  2306428,
#  2316922,
#  4015437,
#  4052777,
#  4092758,
#  4098993,
#  4108745,
#  4132691,
#  4137900,
#  4155943,
#  4159396,
#  4179167,
#  4192047,
#  4228140,
#  4252068,
#  4303399,
#  4304956,
#  4305171,
#  4318694,
#  4319063,
#  4345209,
#  4348109,
#  4362479,
#  4393612,
#  4416410,
#  4446126,
#  4450936,
#  4455045,
#  4478592,
#  4489651,
#  4505982,
#  4565140,
#  4571440,
#  4572857,
#  4624899,
#  4635148,
#  4636143,
#  4647390,
#  4690530,
#  4695947,
#  4791484,
#  4802764,
#  4803246,
#  4857369,
#  4923951,
#  4931993,
#  4975776,
#  5002720,
#  5019569,
#  5029974,
#  5046466,
#  5048067,
#  5132625,
#  5208771,
#  5238412,
#  5412608,
#  5531498}

# %%
##############################################
# EDIT THESE VARIABLES BEFORE RUNNING SCRIPT #
##############################################
csv_path_old = Path("/home/jc053/GIT/mri_longitudinal_analysis/data/input/clinical/redcap_full_108_cohort.csv")
csv_path_new = Path("/home/jc053/GIT/mri_longitudinal_analysis/data/input/clinical/bch_filtered_88.csv")
##############################################

ids_old = extract_unique_patient_ids_from_csv(csv_path_old)
ids_new = extract_unique_patient_ids_from_csv(csv_path_new)
print(f"These are the old ids:", ids_old)
print(f"These are the new ids:", ids_new)

ids_zero_filled_old = []
ids_zero_filled_new = []
for id in ids_old:
    ids_zero_filled_old.append(prefix_zeros_to_six_digit_ids(id))
for id in ids_new:
    ids_zero_filled_new.append(prefix_zeros_to_six_digit_ids(id))
    
print(f"These are the old ids with 0s added:", ids_zero_filled_old)
print(f"These are the new ids with 0s added:", ids_zero_filled_new)

diff = list(set(ids_zero_filled_old) - set(ids_zero_filled_new))
print(f"The difference between the two lists is:", len(diff))


# Calculating the difference: IDs in the old set but not in the new set
ids_in_old_not_in_new = list(set(ids_zero_filled_old) - set(ids_zero_filled_new))
print(f"IDs in old set but not in new set: {len(ids_in_old_not_in_new)}")
print(ids_in_old_not_in_new)

# Calculating the difference: IDs in the new set but not in the old set
ids_in_new_not_in_old = list(set(ids_zero_filled_new) - set(ids_zero_filled_old))
print(f"IDs in new set but not in old set: {len(ids_in_new_not_in_old)}")
print(ids_in_new_not_in_old)
# Out:
# Length of BCH cohort is 108.
# Length of BCH cohort is 88.
# These are the old ids: {4624899, 4032520, 4635148, 4857369, 2326050, 4303399, 2260520, 4155943, 4228140, 4923951, 4394032, 4304956, 2184255, 2004560, 5029974, 4690530, 1058916, 2261605, 1182323, 2297464, 4450936, 2316922, 4478592, 4455045, 4393612, 5238412, 2173072, 4565140, 4975776, 233126, 2183847, 2124457, 1109676, 4803246, 1148595, 2088116, 2103993, 1013946, 4572857, 238268, 5046466, 2088643, 5208771, 1153221, 4802764, 4348109, 1053918, 4099295, 4179167, 4073188, 4362479, 1138934, 5412608, 135939, 137476, 5048067, 4305171, 4300567, 4490520, 4864792, 2147101, 1115940, 4052777, 2249514, 1017646, 4571440, 1232179, 4015437, 1132366, 5132625, 4132691, 4092758, 4319063, 5531498, 2104688, 2270579, 4345209, 2280828, 2306428, 4505982, 4485510, 1194890, 4695947, 2158479, 4931993, 4416410, 4022683, 2268068, 4252068, 4466091, 4137900, 2113964, 4446126, 5019569, 4098993, 4489651, 1071544, 973766, 4108745, 5210065, 1144789, 2126809, 4647390, 5002720, 4318694, 4199911, 5127658, 2001398}
# These are the new ids: {4624899, 4635148, 4857369, 4155943, 4303399, 2260520, 4228140, 4923951, 4304956, 298046, 2004560, 5029974, 335968, 4690530, 1058916, 2261605, 4450936, 2297464, 2316922, 4478592, 4455045, 4393612, 5238412, 2173072, 4565140, 4975776, 233126, 2183847, 2124457, 4803246, 2088116, 4572857, 1013946, 2103993, 238268, 4791484, 5046466, 2088643, 5208771, 1153221, 4802764, 4348109, 4179167, 4362479, 1138934, 5412608, 135939, 5048067, 137476, 4305171, 2147101, 4052777, 2249514, 1017646, 4192047, 4571440, 1232179, 299321, 4015437, 5132625, 4132691, 4092758, 4319063, 5531498, 2104688, 4345209, 2306428, 2280828, 4505982, 1194890, 4695947, 2158479, 4931993, 4416410, 4252068, 4159396, 2113964, 4137900, 4446126, 4098993, 5019569, 4489651, 4108745, 4647390, 5002720, 4318694, 4636143, 2001398}
# These are the old ids with 0s added: ['4624899', '4032520', '4635148', '4857369', '2326050', '4303399', '2260520', '4155943', '4228140', '4923951', '4394032', '4304956', '2184255', '2004560', '5029974', '4690530', '1058916', '2261605', '1182323', '2297464', '4450936', '2316922', '4478592', '4455045', '4393612', '5238412', '2173072', '4565140', '4975776', '0233126', '2183847', '2124457', '1109676', '4803246', '1148595', '2088116', '2103993', '1013946', '4572857', '0238268', '5046466', '2088643', '5208771', '1153221', '4802764', '4348109', '1053918', '4099295', '4179167', '4073188', '4362479', '1138934', '5412608', '0135939', '0137476', '5048067', '4305171', '4300567', '4490520', '4864792', '2147101', '1115940', '4052777', '2249514', '1017646', '4571440', '1232179', '4015437', '1132366', '5132625', '4132691', '4092758', '4319063', '5531498', '2104688', '2270579', '4345209', '2280828', '2306428', '4505982', '4485510', '1194890', '4695947', '2158479', '4931993', '4416410', '4022683', '2268068', '4252068', '4466091', '4137900', '2113964', '4446126', '5019569', '4098993', '4489651', '1071544', '0973766', '4108745', '5210065', '1144789', '2126809', '4647390', '5002720', '4318694', '4199911', '5127658', '2001398']
# These are the new ids with 0s added: ['4624899', '4635148', '4857369', '4155943', '4303399', '2260520', '4228140', '4923951', '4304956', '0298046', '2004560', '5029974', '0335968', '4690530', '1058916', '2261605', '4450936', '2297464', '2316922', '4478592', '4455045', '4393612', '5238412', '2173072', '4565140', '4975776', '0233126', '2183847', '2124457', '4803246', '2088116', '4572857', '1013946', '2103993', '0238268', '4791484', '5046466', '2088643', '5208771', '1153221', '4802764', '4348109', '4179167', '4362479', '1138934', '5412608', '0135939', '5048067', '0137476', '4305171', '2147101', '4052777', '2249514', '1017646', '4192047', '4571440', '1232179', '0299321', '4015437', '5132625', '4132691', '4092758', '4319063', '5531498', '2104688', '4345209', '2306428', '2280828', '4505982', '1194890', '4695947', '2158479', '4931993', '4416410', '4252068', '4159396', '2113964', '4137900', '4446126', '4098993', '5019569', '4489651', '4108745', '4647390', '5002720', '4318694', '4636143', '2001398']
# The difference between the two lists is: 27
# IDs in old set but not in new set: 27
# ['4394032', '4199911', '2326050', '1109676', '1115940', '0973766', '1148595', '5127658', '2184255', '2126809', '2270579', '1053918', '1182323', '4099295', '1132366', '2268068', '4466091', '4022683', '4864792', '4300567', '1144789', '5210065', '4073188', '4032520', '4490520', '1071544', '4485510']
# IDs in new set but not in old set: 7
# ['0335968', '4791484', '0298046', '4192047', '4159396', '4636143', '0299321']

# %% [markdown]
# ## BCH Data: Check that the set of patients has available imaging
# Available imgaging is considered when in the folder with the data there is a patient_ID.csv with the paths and metadata and a patient_ID folder with the images.

# %%
def check_missing_patient_files_and_folders(patient_ids_set, directory_path):
    # List to store the result strings for missing files/folders
    missing_items = []

    # Iterate over each unique patient ID
    for patient_id in patient_ids_set:
        # Construct the expected csv file and folder name
        expected_csv_file = os.path.join(directory_path, f"{patient_id}.csv")
        expected_folder = os.path.join(directory_path, f"{patient_id}")

        # Check for existence of the expected csv file and folder
        has_csv = os.path.isfile(expected_csv_file)
        has_folder = os.path.isdir(expected_folder)

        # Prepare the result string if items are missing
        if not has_csv or not has_folder:
            missing_str = f"Patient ID: {patient_id} -"
            if not has_csv and not has_folder:
                missing_str += " Both CSV and Folder missing"
            elif not has_csv:
                missing_str += " CSV missing"
            elif not has_folder:
                missing_str += " Folder missing"
            missing_items.append(missing_str)

    return missing_items

# %%
##############################################
# EDIT THESE VARIABLES BEFORE RUNNING SCRIPT #
##############################################
data_path = Path("/mnt/an225/Anna/longitudinal_nifti_BCH/curated_BCH/")
missing_patient_items = check_missing_patient_files_and_folders(ids_zero_filled_new, data_path)

# Output the results
if len(missing_patient_items) == 0:
    print("No missing items found.")
else:
    for missing_item in missing_patient_items:
        print(missing_item)
##############################################
# Out:
# No missing items found.

# %% [markdown]
# ## BCH Data: Pre / post treatment separation
# Requirement: Have run the sequence inference before to know the available T2 Sequences

# %%
# first take the predictions and the paths and filter according to those
def filter_csv_files(folder_path):
    for filename in os.listdir(folder_path):
        if filename == "ids.csv":
            continue
        if filename.endswith(".csv"):
            csv_path = os.path.join(folder_path, filename)
            df = pd.read_csv(csv_path)

            # Apply the filtering criteria
            filtered_df = df[((df['Prediction'] == 'T2') | df['Path'].str.contains('t2', case=False)) 
                            & ~df['Path'].str.contains('flair', case=False)  
                            & ~df['Path'].str.contains('spine', case=False)
                            & ~df['Path'].str.contains('dti', case=False) 
                            & ~df['Path'].str.contains('trace', case=False)
                            & ~df['Path'].str.contains('tensor', case=False) 
                            & (df['Prediction'] != 'NO PREDICTION - DIMS')
                            & (df['Prediction'] != 'NO PREDICTION - METADATA') 
                            & (df['Prediction'] != 'NO PREDICTION - FILE ERROR ')
                            & ~df['Path'].str.contains('dw', case=False)]


            new_filename = filename.replace(".csv", "_filtered.csv")
            new_path = os.path.join(folder_path, new_filename)
            # Save the filtered DataFrame back to the CSV file
            filtered_df.to_csv(new_path, index=False)
            print(f"Processed and saved: {filename}")

folder_path = Path("/home/jc053/GIT/mri-sequence-classification/data_csv/long/bch_longitudinal_dataset")
filter_csv_files(folder_path)
# Out:
# Processed and saved: 1017646_file_paths.csv
# Processed and saved: 5048067_file_paths.csv
# Processed and saved: 4132691_file_paths.csv
# Processed and saved: 2183847_file_paths.csv
# Processed and saved: 4015437_file_paths.csv
# Processed and saved: 4108745_file_paths.csv
# Processed and saved: 1194890_file_paths.csv
# Processed and saved: 5002720_file_paths.csv
# Processed and saved: 1232179_file_paths.csv
# Processed and saved: 5238412_file_paths.csv
# Processed and saved: 4228140_file_paths.csv
# Processed and saved: 4252068_file_paths.csv
# Processed and saved: 4348109_file_paths.csv
# Processed and saved: 4416410_file_paths.csv
# Processed and saved: 4052777_file_paths.csv
# Processed and saved: 0137476_file_paths.csv
# Processed and saved: 4923951_file_paths.csv
# Processed and saved: 4393612_file_paths.csv
# Processed and saved: 4159396_file_paths.csv
# Processed and saved: 2306428_file_paths.csv
# Processed and saved: 1013946_file_paths.csv
# Processed and saved: 5029974_file_paths.csv
# Processed and saved: 4857369_file_paths.csv
# Processed and saved: 0299321_file_paths.csv
# Processed and saved: 4635148_file_paths.csv
# Processed and saved: 2001398_file_paths.csv
# Processed and saved: 4304956_file_paths.csv
# Processed and saved: 0298046_file_paths.csv
# Processed and saved: 5019569_file_paths.csv
# Processed and saved: 4362479_file_paths.csv
# Processed and saved: 4318694_file_paths.csv
# Processed and saved: 4446126_file_paths.csv
# Processed and saved: 4791484_file_paths.csv
# Processed and saved: 4802764_file_paths.csv
# Processed and saved: 0135939_file_paths.csv
# Processed and saved: 4975776_file_paths.csv
# Processed and saved: 2261605_file_paths.csv
# Processed and saved: 4636143_file_paths.csv
# Processed and saved: 4505982_file_paths.csv
# Processed and saved: 4098993_file_paths.csv
# Processed and saved: 4155943_file_paths.csv
# Processed and saved: 4192047_file_paths.csv
# Processed and saved: 4319063_file_paths.csv
# Processed and saved: 4624899_file_paths.csv
# Processed and saved: 2104688_file_paths.csv
# Processed and saved: 4565140_file_paths.csv
# Processed and saved: 2316922_file_paths.csv
# Processed and saved: 5531498_file_paths.csv
# Processed and saved: 1138934_file_paths.csv
# Processed and saved: 5412608_file_paths.csv
# Processed and saved: 4931993_file_paths.csv
# Processed and saved: 4179167_file_paths.csv
# Processed and saved: 5208771_file_paths.csv
# Processed and saved: 2088643_file_paths.csv
# Processed and saved: 0233126_file_paths.csv
# Processed and saved: 1058916_file_paths.csv
# Processed and saved: 0335968_file_paths.csv
# Processed and saved: 2113964_file_paths.csv
# Processed and saved: 2124457_file_paths.csv
# Processed and saved: 2158479_file_paths.csv
# Processed and saved: 4489651_file_paths.csv
# Processed and saved: 5132625_file_paths.csv
# Processed and saved: 2173072_file_paths.csv
# Processed and saved: 4478592_file_paths.csv
# Processed and saved: 0238268_file_paths.csv
# Processed and saved: 2004560_file_paths.csv
# Processed and saved: 2103993_file_paths.csv
# Processed and saved: 4647390_file_paths.csv
# Processed and saved: 4092758_file_paths.csv
# Processed and saved: 4695947_file_paths.csv
# Processed and saved: 4803246_file_paths.csv
# Processed and saved: 5046466_file_paths.csv
# Processed and saved: 4303399_file_paths.csv
# Processed and saved: 1153221_file_paths.csv
# Processed and saved: 2249514_file_paths.csv
# Processed and saved: 2260520_file_paths.csv
# Processed and saved: 4305171_file_paths.csv
# Processed and saved: 4572857_file_paths.csv
# Processed and saved: 4450936_file_paths.csv
# Processed and saved: 4571440_file_paths.csv
# Processed and saved: 4690530_file_paths.csv
# Processed and saved: 2280828_file_paths.csv
# Processed and saved: 4345209_file_paths.csv
# Processed and saved: 2088116_file_paths.csv
# Processed and saved: 2147101_file_paths.csv
# Processed and saved: 4455045_file_paths.csv
# Processed and saved: 4137900_file_paths.csv
# Processed and saved: 2297464_file_paths.csv

# %%
# filter by the treatment date to get all scans before treatment
def get_first_treatment_dates(clinical_csv_path):
    clinical_df = pd.read_csv(clinical_csv_path)
    treatment_dates = {}
    for _, row in clinical_df.iterrows():
        patient_id = row['BCH MRN']
        date_str = row['First Treatment']
        if pd.isna(date_str):  # Check if treatment date is not NaN
            treatment_dates[patient_id] = None  # No treatment date recorded
        else:
            treatment_dates[patient_id] = datetime.strptime(date_str, '%d/%m/%Y')
    return treatment_dates

def filter_by_treatment_date(folder_path, treatment_dates):
    for filename in os.listdir(folder_path):
        if filename.endswith("_filtered.csv"):
            csv_path = os.path.join(folder_path, filename)
            df = pd.read_csv(csv_path)

            def is_before_treatment(row):
                path_parts = row['Path'].split('/')
                patient_id = path_parts[-3]
                treatment_date = treatment_dates.get(patient_id)

                if treatment_date is None:
                    return True
                scan_date = datetime.strptime(path_parts[-2], '%Y%m%d')
                # Compare with treatment date
                return scan_date <= treatment_dates.get(patient_id, datetime.max)

            # Apply the filtering function
            filtered_df = df[df.apply(is_before_treatment, axis=1)]

            new_path = os.path.join(folder_path, filename.replace("_filtered.csv", "_filtered_treatment.csv"))
            # Save the filtered DataFrame back to the CSV file
            filtered_df.to_csv(new_path, index=False)
            print(f"Processed and saved: {filename}")

# %%
clinical_csv_path = Path("/home/jc053/GIT/mri_longitudinal_analysis/data/input/clinical/bch_filtered_88.csv")
folder_path = Path("/home/jc053/GIT/mri-sequence-classification/data_csv/long/bch_longitudinal_dataset")
treatment_dates = get_first_treatment_dates(clinical_csv_path)
filter_by_treatment_date(folder_path, treatment_dates)
# Out:
# Processed and saved: 4802764_file_paths_filtered.csv
# Processed and saved: 5412608_file_paths_filtered.csv
# Processed and saved: 4228140_file_paths_filtered.csv
# Processed and saved: 1058916_file_paths_filtered.csv
# Processed and saved: 4572857_file_paths_filtered.csv
# Processed and saved: 2124457_file_paths_filtered.csv
# Processed and saved: 2158479_file_paths_filtered.csv
# Processed and saved: 0335968_file_paths_filtered.csv
# Processed and saved: 4362479_file_paths_filtered.csv
# Processed and saved: 5046466_file_paths_filtered.csv
# Processed and saved: 2103993_file_paths_filtered.csv
# Processed and saved: 4192047_file_paths_filtered.csv
# Processed and saved: 2173072_file_paths_filtered.csv
# Processed and saved: 2113964_file_paths_filtered.csv
# Processed and saved: 4305171_file_paths_filtered.csv
# Processed and saved: 4690530_file_paths_filtered.csv
# Processed and saved: 4565140_file_paths_filtered.csv
# Processed and saved: 2104688_file_paths_filtered.csv
# Processed and saved: 4635148_file_paths_filtered.csv
# Processed and saved: 2261605_file_paths_filtered.csv
# Processed and saved: 4975776_file_paths_filtered.csv
# Processed and saved: 4159396_file_paths_filtered.csv
# Processed and saved: 0135939_file_paths_filtered.csv
# Processed and saved: 4505982_file_paths_filtered.csv
# Processed and saved: 2088116_file_paths_filtered.csv
# Processed and saved: 4345209_file_paths_filtered.csv
# Processed and saved: 4636143_file_paths_filtered.csv
# Processed and saved: 2316922_file_paths_filtered.csv
# Processed and saved: 2147101_file_paths_filtered.csv
# Processed and saved: 4318694_file_paths_filtered.csv
# Processed and saved: 4098993_file_paths_filtered.csv
# Processed and saved: 1138934_file_paths_filtered.csv
# Processed and saved: 4455045_file_paths_filtered.csv
# Processed and saved: 5132625_file_paths_filtered.csv
# Processed and saved: 0298046_file_paths_filtered.csv
# Processed and saved: 5531498_file_paths_filtered.csv
# Processed and saved: 1194890_file_paths_filtered.csv
# Processed and saved: 4252068_file_paths_filtered.csv
# Processed and saved: 0233126_file_paths_filtered.csv
# Processed and saved: 4647390_file_paths_filtered.csv
# Processed and saved: 4052777_file_paths_filtered.csv
# Processed and saved: 4092758_file_paths_filtered.csv
# Processed and saved: 4393612_file_paths_filtered.csv
# Processed and saved: 4624899_file_paths_filtered.csv
# Processed and saved: 4179167_file_paths_filtered.csv
# Processed and saved: 2183847_file_paths_filtered.csv
# Processed and saved: 1232179_file_paths_filtered.csv
# Processed and saved: 0238268_file_paths_filtered.csv
# Processed and saved: 1153221_file_paths_filtered.csv
# Processed and saved: 4304956_file_paths_filtered.csv
# Processed and saved: 5002720_file_paths_filtered.csv
# Processed and saved: 4015437_file_paths_filtered.csv
# Processed and saved: 5238412_file_paths_filtered.csv
# Processed and saved: 4489651_file_paths_filtered.csv
# Processed and saved: 5029974_file_paths_filtered.csv
# Processed and saved: 2306428_file_paths_filtered.csv
# Processed and saved: 4923951_file_paths_filtered.csv
# Processed and saved: 4803246_file_paths_filtered.csv
# Processed and saved: 5208771_file_paths_filtered.csv
# Processed and saved: 4348109_file_paths_filtered.csv
# Processed and saved: 4303399_file_paths_filtered.csv
# Processed and saved: 2001398_file_paths_filtered.csv
# Processed and saved: 4446126_file_paths_filtered.csv
# Processed and saved: 4108745_file_paths_filtered.csv
# Processed and saved: 4132691_file_paths_filtered.csv
# Processed and saved: 4695947_file_paths_filtered.csv
# Processed and saved: 5019569_file_paths_filtered.csv
# Processed and saved: 0299321_file_paths_filtered.csv
# Processed and saved: 2249514_file_paths_filtered.csv
# Processed and saved: 4450936_file_paths_filtered.csv
# Processed and saved: 4931993_file_paths_filtered.csv
# Processed and saved: 4137900_file_paths_filtered.csv
# Processed and saved: 2280828_file_paths_filtered.csv
# Processed and saved: 2004560_file_paths_filtered.csv
# Processed and saved: 2088643_file_paths_filtered.csv
# Processed and saved: 4416410_file_paths_filtered.csv
# Processed and saved: 2260520_file_paths_filtered.csv
# Processed and saved: 4319063_file_paths_filtered.csv
# Processed and saved: 4155943_file_paths_filtered.csv
# Processed and saved: 2297464_file_paths_filtered.csv
# Processed and saved: 4571440_file_paths_filtered.csv
# Processed and saved: 1017646_file_paths_filtered.csv
# Processed and saved: 0137476_file_paths_filtered.csv
# Processed and saved: 4478592_file_paths_filtered.csv
# Processed and saved: 5048067_file_paths_filtered.csv
# Processed and saved: 4857369_file_paths_filtered.csv
# Processed and saved: 4791484_file_paths_filtered.csv
# Processed and saved: 1013946_file_paths_filtered.csv

# %%
# move filtered files to a new folder
target_dir = Path("/home/jc053/GIT/mri-sequence-classification/data_csv/long/bch_longitudinal_dataset_filtered")
os.makedirs(target_dir, exist_ok=True)
for file in os.listdir(folder_path):
    file_path = os.path.join(folder_path, file)
    if file.endswith("_filtered_treatment.csv"):
        new_file_path = os.path.join(target_dir, file)
        shutil.copyfile(file_path, new_file_path)
        

# count the new number of patients

# %%
# Optional if you want to remove the old files
# remove files if they have a _filtered.csv in their name
def remove_filtered_files(folder_path):
    for filename in os.listdir(folder_path):
        if filename.endswith("_filtered.csv") or filename.endswith("_filtered_treatment.csv"):
            file_path = os.path.join(folder_path, filename)
            os.remove(file_path)
            print(f"Removed: {filename}")
remove_filtered_files(folder_path)
# Out:
# Removed: 4802764_file_paths_filtered.csv
# Removed: 5412608_file_paths_filtered.csv
# Removed: 2183847_file_paths_filtered_treatment.csv
# Removed: 4228140_file_paths_filtered.csv
# Removed: 1058916_file_paths_filtered.csv
# Removed: 4572857_file_paths_filtered.csv
# Removed: 2173072_file_paths_filtered_treatment.csv
# Removed: 2124457_file_paths_filtered.csv
# Removed: 2297464_file_paths_filtered_treatment.csv
# Removed: 2158479_file_paths_filtered.csv
# Removed: 0335968_file_paths_filtered.csv
# Removed: 4362479_file_paths_filtered.csv
# Removed: 5046466_file_paths_filtered.csv
# Removed: 2103993_file_paths_filtered.csv
# Removed: 4695947_file_paths_filtered_treatment.csv
# Removed: 4192047_file_paths_filtered.csv
# Removed: 2173072_file_paths_filtered.csv
# Removed: 1017646_file_paths_filtered_treatment.csv
# Removed: 2113964_file_paths_filtered.csv
# Removed: 2088643_file_paths_filtered_treatment.csv
# Removed: 4505982_file_paths_filtered_treatment.csv
# Removed: 4305171_file_paths_filtered.csv
# Removed: 4446126_file_paths_filtered_treatment.csv
# Removed: 4931993_file_paths_filtered_treatment.csv
# Removed: 4690530_file_paths_filtered.csv
# Removed: 4565140_file_paths_filtered.csv
# Removed: 2104688_file_paths_filtered.csv
# Removed: 4635148_file_paths_filtered.csv
# Removed: 2261605_file_paths_filtered.csv
# Removed: 4975776_file_paths_filtered_treatment.csv
# Removed: 4319063_file_paths_filtered_treatment.csv
# Removed: 4975776_file_paths_filtered.csv
# Removed: 4159396_file_paths_filtered.csv
# Removed: 0135939_file_paths_filtered.csv
# Removed: 4505982_file_paths_filtered.csv
# Removed: 1232179_file_paths_filtered_treatment.csv
# Removed: 2001398_file_paths_filtered_treatment.csv
# Removed: 2088116_file_paths_filtered.csv
# Removed: 4345209_file_paths_filtered.csv
# Removed: 4636143_file_paths_filtered.csv
# Removed: 2316922_file_paths_filtered.csv
# Removed: 2260520_file_paths_filtered_treatment.csv
# Removed: 4305171_file_paths_filtered_treatment.csv
# Removed: 4092758_file_paths_filtered_treatment.csv
# Removed: 2147101_file_paths_filtered.csv
# Removed: 1194890_file_paths_filtered_treatment.csv
# Removed: 4318694_file_paths_filtered.csv
# Removed: 4098993_file_paths_filtered.csv
# Removed: 1138934_file_paths_filtered.csv
# Removed: 2261605_file_paths_filtered_treatment.csv
# Removed: 4455045_file_paths_filtered.csv
# Removed: 4098993_file_paths_filtered_treatment.csv
# Removed: 1153221_file_paths_filtered_treatment.csv
# Removed: 2004560_file_paths_filtered_treatment.csv
# Removed: 5132625_file_paths_filtered.csv
# Removed: 2280828_file_paths_filtered_treatment.csv
# Removed: 0298046_file_paths_filtered.csv
# Removed: 5531498_file_paths_filtered.csv
# Removed: 1194890_file_paths_filtered.csv
# Removed: 4345209_file_paths_filtered_treatment.csv
# Removed: 0298046_file_paths_filtered_treatment.csv
# Removed: 4571440_file_paths_filtered_treatment.csv
# Removed: 4252068_file_paths_filtered.csv
# Removed: 4478592_file_paths_filtered_treatment.csv
# Removed: 0233126_file_paths_filtered.csv
# Removed: 0137476_file_paths_filtered_treatment.csv
# Removed: 4647390_file_paths_filtered.csv
# Removed: 2104688_file_paths_filtered_treatment.csv
# Removed: 4052777_file_paths_filtered.csv
# Removed: 4092758_file_paths_filtered.csv
# Removed: 2124457_file_paths_filtered_treatment.csv
# Removed: 4393612_file_paths_filtered.csv
# Removed: 4624899_file_paths_filtered.csv
# Removed: 4179167_file_paths_filtered_treatment.csv
# Removed: 4179167_file_paths_filtered.csv
# Removed: 5208771_file_paths_filtered_treatment.csv
# Removed: 5046466_file_paths_filtered_treatment.csv
# Removed: 4647390_file_paths_filtered_treatment.csv
# Removed: 4857369_file_paths_filtered_treatment.csv
# Removed: 2183847_file_paths_filtered.csv
# Removed: 1232179_file_paths_filtered.csv
# Removed: 0299321_file_paths_filtered_treatment.csv
# Removed: 0238268_file_paths_filtered.csv
# Removed: 1153221_file_paths_filtered.csv
# Removed: 4635148_file_paths_filtered_treatment.csv
# Removed: 4923951_file_paths_filtered_treatment.csv
# Removed: 5002720_file_paths_filtered_treatment.csv
# Removed: 4565140_file_paths_filtered_treatment.csv
# Removed: 4304956_file_paths_filtered.csv
# Removed: 2316922_file_paths_filtered_treatment.csv
# Removed: 4803246_file_paths_filtered_treatment.csv
# Removed: 5002720_file_paths_filtered.csv
# Removed: 4015437_file_paths_filtered.csv
# Removed: 1138934_file_paths_filtered_treatment.csv
# Removed: 4791484_file_paths_filtered_treatment.csv
# Removed: 1058916_file_paths_filtered_treatment.csv
# Removed: 5238412_file_paths_filtered.csv
# Removed: 4304956_file_paths_filtered_treatment.csv
# Removed: 4348109_file_paths_filtered_treatment.csv
# Removed: 4052777_file_paths_filtered_treatment.csv
# Removed: 4489651_file_paths_filtered.csv
# Removed: 5029974_file_paths_filtered.csv
# Removed: 4362479_file_paths_filtered_treatment.csv
# Removed: 2306428_file_paths_filtered.csv
# Removed: 4489651_file_paths_filtered_treatment.csv
# Removed: 4923951_file_paths_filtered.csv
# Removed: 2158479_file_paths_filtered_treatment.csv
# Removed: 4192047_file_paths_filtered_treatment.csv
# Removed: 4636143_file_paths_filtered_treatment.csv
# Removed: 4137900_file_paths_filtered_treatment.csv
# Removed: 4416410_file_paths_filtered_treatment.csv
# Removed: 4572857_file_paths_filtered_treatment.csv
# Removed: 4624899_file_paths_filtered_treatment.csv
# Removed: 5048067_file_paths_filtered_treatment.csv
# Removed: 4803246_file_paths_filtered.csv
# Removed: 0233126_file_paths_filtered_treatment.csv
# Removed: 4108745_file_paths_filtered_treatment.csv
# Removed: 5208771_file_paths_filtered.csv
# Removed: 2103993_file_paths_filtered_treatment.csv
# Removed: 4348109_file_paths_filtered.csv
# Removed: 4303399_file_paths_filtered.csv
# Removed: 4015437_file_paths_filtered_treatment.csv
# Removed: 4690530_file_paths_filtered_treatment.csv
# Removed: 2001398_file_paths_filtered.csv
# Removed: 4446126_file_paths_filtered.csv
# Removed: 4132691_file_paths_filtered_treatment.csv
# Removed: 4450936_file_paths_filtered_treatment.csv
# Removed: 2249514_file_paths_filtered_treatment.csv
# Removed: 4108745_file_paths_filtered.csv
# Removed: 4802764_file_paths_filtered_treatment.csv
# Removed: 5019569_file_paths_filtered_treatment.csv
# Removed: 4132691_file_paths_filtered.csv
# Removed: 4695947_file_paths_filtered.csv
# Removed: 4155943_file_paths_filtered_treatment.csv
# Removed: 5019569_file_paths_filtered.csv
# Removed: 0299321_file_paths_filtered.csv
# Removed: 2249514_file_paths_filtered.csv
# Removed: 1013946_file_paths_filtered_treatment.csv
# Removed: 4450936_file_paths_filtered.csv
# Removed: 4931993_file_paths_filtered.csv
# Removed: 4137900_file_paths_filtered.csv
# Removed: 0135939_file_paths_filtered_treatment.csv
# Removed: 2280828_file_paths_filtered.csv
# Removed: 2004560_file_paths_filtered.csv
# Removed: 5029974_file_paths_filtered_treatment.csv
# Removed: 2088643_file_paths_filtered.csv
# Removed: 4318694_file_paths_filtered_treatment.csv
# Removed: 4303399_file_paths_filtered_treatment.csv
# Removed: 4416410_file_paths_filtered.csv
# Removed: 0238268_file_paths_filtered_treatment.csv
# Removed: 4228140_file_paths_filtered_treatment.csv
# Removed: 4252068_file_paths_filtered_treatment.csv
# Removed: 2260520_file_paths_filtered.csv
# Removed: 5412608_file_paths_filtered_treatment.csv
# Removed: 4319063_file_paths_filtered.csv
# Removed: 4159396_file_paths_filtered_treatment.csv
# Removed: 4393612_file_paths_filtered_treatment.csv
# Removed: 4155943_file_paths_filtered.csv
# Removed: 2147101_file_paths_filtered_treatment.csv
# Removed: 2297464_file_paths_filtered.csv
# Removed: 5132625_file_paths_filtered_treatment.csv
# Removed: 0335968_file_paths_filtered_treatment.csv
# Removed: 5531498_file_paths_filtered_treatment.csv
# Removed: 4571440_file_paths_filtered.csv
# Removed: 1017646_file_paths_filtered.csv
# Removed: 0137476_file_paths_filtered.csv
# Removed: 2306428_file_paths_filtered_treatment.csv
# Removed: 4478592_file_paths_filtered.csv
# Removed: 2113964_file_paths_filtered_treatment.csv
# Removed: 5048067_file_paths_filtered.csv
# Removed: 2088116_file_paths_filtered_treatment.csv
# Removed: 4857369_file_paths_filtered.csv
# Removed: 4791484_file_paths_filtered.csv
# Removed: 1013946_file_paths_filtered.csv
# Removed: 5238412_file_paths_filtered_treatment.csv
# Removed: 4455045_file_paths_filtered_treatment.csv

# %% [markdown]
# ## BCH Data: Obtain the best image out of the _filtered_treatment.csv files

# %%
def is_file_openable(filepath):
    """
    Check if a .nii.gz file is openable using nibabel.
    """
    try:
        nib.load(filepath)
        return True
    except Exception:
        return False

def extract_patient_id_and_scan_date(path):
    parts = path.split('/')
    patient_id = parts[-3]
    scan_date = parts[-2]
    return patient_id, scan_date

def parse_resolution(resolution_str):
    # Parse the resolution string and convert to a tuple of floats
    if isinstance(resolution_str, str):
        resolution = tuple(map(float, resolution_str.strip("()").split(',')))
        return resolution
    else:
        return (0.0, 0.0, 0.0)

def has_ax_or_tra(filename):
    return 'ax' in filename.lower() or 'tra' in filename.lower()

def select_best_image_per_scan(csv_path):
    df = pd.read_csv(csv_path)
    # Add columns for patient ID and scan date
    df[['Patient ID', 'Scan Date']] = df.apply(lambda row: pd.Series(extract_patient_id_and_scan_date(row['Path'])), axis=1)
    df['Resolution'] = df['Image Spacing (x,y,z)'].apply(parse_resolution)
    df['AxOrTra'] = df['Path'].apply(has_ax_or_tra)
    df['Openable'] = df['Path'].apply(is_file_openable)
    df = df[df['Openable']]

    df.sort_values(by=['AxOrTra', 'Resolution'], ascending=[False, False], inplace=True)
    best_images_df = df.groupby(['Patient ID', 'Scan Date']).first().reset_index()
    return best_images_df

# %%
folder_path = '/home/jc053/GIT/mri-sequence-classification/data_csv/long/bch_longitudinal_dataset_filtered'

for file in os.listdir(folder_path):
    if file.endswith("_filtered_treatment.csv"):
        csv_path = os.path.join(folder_path, file)
        best_images_df = select_best_image_per_scan(csv_path)
        best_images_file = os.path.join(folder_path, file.replace("_filtered_treatment.csv", "_filtered_treatment_best.csv"))
        best_images_df.to_csv(best_images_file, index=False)

# %%
remove_filtered_files(folder_path)
# Out:
# Removed: 2183847_file_paths_filtered_treatment.csv
# Removed: 2173072_file_paths_filtered_treatment.csv
# Removed: 2297464_file_paths_filtered_treatment.csv
# Removed: 4695947_file_paths_filtered_treatment.csv
# Removed: 1017646_file_paths_filtered_treatment.csv
# Removed: 2088643_file_paths_filtered_treatment.csv
# Removed: 4505982_file_paths_filtered_treatment.csv
# Removed: 4446126_file_paths_filtered_treatment.csv
# Removed: 4931993_file_paths_filtered_treatment.csv
# Removed: 4975776_file_paths_filtered_treatment.csv
# Removed: 4319063_file_paths_filtered_treatment.csv
# Removed: 1232179_file_paths_filtered_treatment.csv
# Removed: 2001398_file_paths_filtered_treatment.csv
# Removed: 2260520_file_paths_filtered_treatment.csv
# Removed: 4305171_file_paths_filtered_treatment.csv
# Removed: 4092758_file_paths_filtered_treatment.csv
# Removed: 1194890_file_paths_filtered_treatment.csv
# Removed: 2261605_file_paths_filtered_treatment.csv
# Removed: 4098993_file_paths_filtered_treatment.csv
# Removed: 1153221_file_paths_filtered_treatment.csv
# Removed: 2004560_file_paths_filtered_treatment.csv
# Removed: 2280828_file_paths_filtered_treatment.csv
# Removed: 4345209_file_paths_filtered_treatment.csv
# Removed: 0298046_file_paths_filtered_treatment.csv
# Removed: 4571440_file_paths_filtered_treatment.csv
# Removed: 4478592_file_paths_filtered_treatment.csv
# Removed: 0137476_file_paths_filtered_treatment.csv
# Removed: 2104688_file_paths_filtered_treatment.csv
# Removed: 2124457_file_paths_filtered_treatment.csv
# Removed: 4179167_file_paths_filtered_treatment.csv
# Removed: 5208771_file_paths_filtered_treatment.csv
# Removed: 5046466_file_paths_filtered_treatment.csv
# Removed: 4647390_file_paths_filtered_treatment.csv
# Removed: 4857369_file_paths_filtered_treatment.csv
# Removed: 0299321_file_paths_filtered_treatment.csv
# Removed: 4635148_file_paths_filtered_treatment.csv
# Removed: 4923951_file_paths_filtered_treatment.csv
# Removed: 5002720_file_paths_filtered_treatment.csv
# Removed: 4565140_file_paths_filtered_treatment.csv
# Removed: 2316922_file_paths_filtered_treatment.csv
# Removed: 4803246_file_paths_filtered_treatment.csv
# Removed: 1138934_file_paths_filtered_treatment.csv
# Removed: 4791484_file_paths_filtered_treatment.csv
# Removed: 1058916_file_paths_filtered_treatment.csv
# Removed: 4304956_file_paths_filtered_treatment.csv
# Removed: 4348109_file_paths_filtered_treatment.csv
# Removed: 4052777_file_paths_filtered_treatment.csv
# Removed: 4362479_file_paths_filtered_treatment.csv
# Removed: 4489651_file_paths_filtered_treatment.csv
# Removed: 2158479_file_paths_filtered_treatment.csv
# Removed: 4192047_file_paths_filtered_treatment.csv
# Removed: 4636143_file_paths_filtered_treatment.csv
# Removed: 4137900_file_paths_filtered_treatment.csv
# Removed: 4416410_file_paths_filtered_treatment.csv
# Removed: 4572857_file_paths_filtered_treatment.csv
# Removed: 4624899_file_paths_filtered_treatment.csv
# Removed: 5048067_file_paths_filtered_treatment.csv
# Removed: 0233126_file_paths_filtered_treatment.csv
# Removed: 4108745_file_paths_filtered_treatment.csv
# Removed: 2103993_file_paths_filtered_treatment.csv
# Removed: 4015437_file_paths_filtered_treatment.csv
# Removed: 4690530_file_paths_filtered_treatment.csv
# Removed: 4132691_file_paths_filtered_treatment.csv
# Removed: 4450936_file_paths_filtered_treatment.csv
# Removed: 2249514_file_paths_filtered_treatment.csv
# Removed: 4802764_file_paths_filtered_treatment.csv
# Removed: 5019569_file_paths_filtered_treatment.csv
# Removed: 4155943_file_paths_filtered_treatment.csv
# Removed: 1013946_file_paths_filtered_treatment.csv
# Removed: 0135939_file_paths_filtered_treatment.csv
# Removed: 5029974_file_paths_filtered_treatment.csv
# Removed: 4318694_file_paths_filtered_treatment.csv
# Removed: 4303399_file_paths_filtered_treatment.csv
# Removed: 0238268_file_paths_filtered_treatment.csv
# Removed: 4228140_file_paths_filtered_treatment.csv
# Removed: 4252068_file_paths_filtered_treatment.csv
# Removed: 5412608_file_paths_filtered_treatment.csv
# Removed: 4159396_file_paths_filtered_treatment.csv
# Removed: 4393612_file_paths_filtered_treatment.csv
# Removed: 2147101_file_paths_filtered_treatment.csv
# Removed: 5132625_file_paths_filtered_treatment.csv
# Removed: 0335968_file_paths_filtered_treatment.csv
# Removed: 5531498_file_paths_filtered_treatment.csv
# Removed: 2306428_file_paths_filtered_treatment.csv
# Removed: 2113964_file_paths_filtered_treatment.csv
# Removed: 2088116_file_paths_filtered_treatment.csv
# Removed: 5238412_file_paths_filtered_treatment.csv
# Removed: 4455045_file_paths_filtered_treatment.csv

# %%
def check_unique_scan_dates_per_patient(csv_path):
    df = pd.read_csv(csv_path)

    # Group by Patient ID and check for duplicates in Scan Date
    grouped = df.groupby('Patient ID')
    duplicate_dates = {patient_id: scans['Scan Date'].duplicated().any() 
                       for patient_id, scans in grouped}

    # Patients with duplicate scan dates
    patients_with_duplicates = [patient for patient, has_duplicates in duplicate_dates.items() if has_duplicates]

    if patients_with_duplicates:
        print(f"Patient with duplicate scan dates: {patients_with_duplicates}")
        return False
    else:
        return True

def check_all_files_in_folder(folder_path):
    all_unique = True
    for file in os.listdir(folder_path):
        if file.endswith(".csv"):
            csv_path = os.path.join(folder_path, file)
            if not check_unique_scan_dates_per_patient(csv_path):
                all_unique = False
    return all_unique

all_files_checked = check_all_files_in_folder(folder_path)
if all_files_checked:
    print("All files have unique scan dates per patient.")
else:
    print("There are files with duplicate scan dates.")
# Out:
# All files have unique scan dates per patient.

# %%
# move files from the .csv's to a new folder
target_dir = Path("/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/bch_longitudinal_dataset")
folder_path = Path('/home/jc053/GIT/mri-sequence-classification/data_csv/long/bch_longitudinal_dataset_filtered')
def move_best_images(csv_path, target_dir):
    os.makedirs(target_dir, exist_ok=True)

    # Read the CSV file
    df = pd.read_csv(csv_path)

    # Loop through each row and move the file
    for _, row in df.iterrows():
        source_path = row['Path']  # Adjust this if the column name is different
        filename = os.path.basename(source_path)
        patient_id = source_path.split('/')[-3]
        scan_id = source_path.split('/')[-2]
        new_filename = f"{patient_id}_{scan_id}_{filename}"
        destination_path = os.path.join(target_dir, new_filename)

        # Move the file
        shutil.copyfile(source_path, destination_path)
        # print(f"Copied {source_path} to {destination_path}")

for file in tqdm(os.listdir(folder_path), desc="Copying files"):
    if file.endswith("_filtered_treatment_best.csv"):
        csv_path = os.path.join(folder_path, file)
        move_best_images(csv_path, target_dir)
# Out:
# Copying files: 100%|██████████| 88/88 [02:53<00:00,  1.97s/it]

# %% [markdown]
# ## BCH Data: Manual Review of sequences
# Requirement: review all of the data with Slicer and SegmentationReview.

# %%
# get the csv with the data to review
def read_file(csv_file):
    """
    Read and return a dataframe from a CSV file.

    Args:
        csv_file (str): Path to the CSV file.

    Returns:
        pd.DataFrame: Loaded dataframe with the CSV data.
    """
    column_names = ["Image_Name", "Quality", "Empty"]
    d_f = pd.read_csv(csv_file, names=column_names, header=None, delimiter=',')
    print(d_f.head(5))
    return d_f

def delete_entries(df):
    print(df["Quality"].unique())
    cleaned_df = df[df["Quality"] ==5]
    print(cleaned_df.head(5))
    cleaned_df.to_csv("cleaned.csv", index=False, header=False)

# %%
csv_path = "/home/jc053/GIT/mri_longitudinal_analysis/mri_longitudinal_analysis/utils/annotations_after_1st_review_converted.csv"
df_cbtn = read_file(csv_path)
delete_entries(df_cbtn)

# %% [markdown]
# ## BCH Data Patient IDs after 1st and 2nd review
# Have run the review_t2w script in order to separate the folders.

# %%
unique_ids_1st_review = set()
unique_ids_2nd_review = set()
# Function to process a single directory
def process_directory(directory, unique_set):
    for filename in os.listdir(directory):
        if filename.endswith(".nii.gz"):
            # Extracting the part before the first underscore
            patient_id = filename.split('_')[0]
            # Check if the ID starts with 'C' followed by digits
            if len(patient_id) == 7:
                unique_set.add(patient_id)

def extract_unique_patient_ids(dir1, dir2, unique_set):
    # Process each directory
    process_directory(dir1, unique_set)
    process_directory(dir2, unique_set)

    return unique_set

# Example usage
dir1 = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/bch_longitudinal_dataset/new_review/1"  
dir2 = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/bch_longitudinal_dataset/new_review/5"
dir3 = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/bch_longitudinal_dataset/new_review/5 - Found replacement"

unique_patient_ids_after_1st_review = extract_unique_patient_ids(dir1, dir2, unique_ids_1st_review)
unique_patient_ids_after_2nd_review = extract_unique_patient_ids(dir1, dir3, unique_ids_2nd_review)

print(f"Unique patient IDs after 1st review: {len(unique_patient_ids_after_1st_review)}")
print(f"Unique patient IDs after 2nd review: {len(unique_patient_ids_after_2nd_review)}")
# Out:
# Unique patient IDs after 1st review: 88
# Unique patient IDs after 2nd review: 88

# %% [markdown]
# ## BCH Data: Filter patients with less than 3 scans and move to fold for pp

# %%
def has_minimum_sessions(source_dirs, min_sessions=3):
    """
    Checks if each patient has at least a minimum number of session IDs across the source directories.

    Parameters:
    source_dirs (list): List of source directory paths.
    min_sessions (int): Minimum number of sessions required for each patient.

    Returns:
    set: Set of patient IDs that meet the criteria.
    """
    session_count = defaultdict(set)
    for source_dir in source_dirs:
        for filename in os.listdir(source_dir):
            if filename.endswith(".nii.gz"):
                parts = filename.split('_')
                if len(parts) >= 2 and parts[0][1:].isdigit():
                    patient_id, session_id = parts[0], parts[1]
                    session_count[patient_id].add(session_id)

    # Filter patients who meet the minimum session requirement
    return {patient for patient, sessions in session_count.items() if len(sessions) >= min_sessions}

# copy patients after 2nd review and which meet the criteria of at least 3 folders
def copy_files_from_dirs_to_new_dir(source_dirs, target_dir, valid_patient_ids):
    """
    Copy files from the given source directories to the target directory.
    """
    if not os.path.exists(target_dir):
        os.makedirs(target_dir)
    total_files = sum([len(os.listdir(source_dir)) for source_dir in source_dirs])
    with tqdm(total= total_files,desc="Copying files") as pbar:
        for source_dir in source_dirs:
            for filename in os.listdir(source_dir):
                if filename.endswith(".nii.gz"):
                    patient_id = filename.split('_')[0]
                    if patient_id in valid_patient_ids:
                        source_file = os.path.join(source_dir, filename)
                        if os.path.isfile(source_file):
                            target_file = os.path.join(target_dir, filename)
                            shutil.copyfile(source_file, target_file)
                            pbar.update(1)  
                
source_dirs = [dir1, dir3]
target_dir = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/bch_longitudinal_dataset/new_review/after_review_before_pp"
valid_patient_ids = has_minimum_sessions(source_dirs)
copy_files_from_dirs_to_new_dir(source_dirs, target_dir, valid_patient_ids)

unique_ids_after_3_scan_filtering = set()
process_directory(target_dir, unique_ids_after_3_scan_filtering)
print(f"Unique patient IDs after 3 scan filtering: {len(unique_ids_after_3_scan_filtering)}")
# Out:
# Copying files: 100%|█████████▉| 1409/1414 [00:17<00:00, 80.41it/s]
# Unique patient IDs after 3 scan filtering: 85

# %% [markdown]
# ## BCH Data (Additional): In case a segmentation already review took place, only analyze the truly new scans

# %%
import os
import shutil

# Replace these paths with the actual paths of your directories
directory1_path = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/bch_longitudinal_dataset/new_review/after_review_before_pp/output/seg_predictions"
directory2_path = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/bch_longitudinal_dataset/old_seg_accepted"
qa_dir = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/bch_longitudinal_dataset/new_review/to_pp_before_qa"
final_dir = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/bch_longitudinal_dataset/new_review/final"
additional_dir = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/bch_longitudinal_dataset/old_seg_accepted/no_longer_included"

# Ensure the output directories exist
# os.makedirs(qa_dir, exist_ok=True)
# os.makedirs(final_dir, exist_ok=True)
# os.makedirs(additional_dir, exist_ok=True)

# Function to extract patientID and scanID
def get_identifier(file_name, from_directory1=True):
    parts = file_name.split('_')
    if from_directory1:
        # From the first directory (patientID_ScanID_hash.nii.gz)
        return parts[0], parts[1]
    else:
        # From the second directory (imageXX_patientID_scanID.nii.gz)
        return parts[1], parts[2]

# Extract identifiers from both directories
identifiers_dir1 = set()
ids_dir1 = set()
for file_name in os.listdir(directory1_path):
    if file_name.endswith(".nii.gz"):
        patid, scanid = get_identifier(file_name)
        identifiers_dir1.add((patid, scanid))
        ids_dir1.add(patid)

identifiers_dir2 = set()
ids_dir2 = set()
for file_name in os.listdir(directory2_path):
    if not file_name.endswith("_mask.nii.gz"):
        patid, scanid = get_identifier(file_name, from_directory1=False)
        identifiers_dir2.add((patid, scanid))
        ids_dir2.add(patid)

print("Number of total scans in dir 1:", len(identifiers_dir1))
print(f"Number of unique patients in Directory 1: {len(ids_dir1)}")

print("Numebr of total scans in dir 2:", len(identifiers_dir2))
print(f"Number of unique patients in Directory 2: {len(ids_dir2)}")

unique_to_dir1 = identifiers_dir1 - identifiers_dir2
unique_to_dir2 = identifiers_dir2 - identifiers_dir1
common_identifiers = identifiers_dir1.intersection(identifiers_dir2)
common_patients = ids_dir1.intersection(ids_dir2)
print(f"Unique identifiers to Directory 1: {len(unique_to_dir1)}")
print(f"Unique identifiers to Directory 2: {len(unique_to_dir2)}")
print(f"Common identifiers between the directories: {len(common_identifiers)}")
print(f"Common patients between the directories: {len(common_patients)}")

# Compare and copy files
# for file_name in tqdm(os.listdir(directory1_path), desc="Processing Directory 2 QA and FINAL"):
#     if file_name.endswith(".nii.gz"):
#         identifier = get_identifier(file_name)
#         if identifier in identifiers_dir2:
#             final_path = os.path.join(final_dir, file_name)
#             shutil.copyfile(os.path.join(directory1_path, file_name), final_path)
#         else:
#             qa_path = os.path.join(qa_dir, file_name)
#             shutil.copyfile(os.path.join(directory1_path, file_name), qa_path)

# Count files in the 'final' and 'qa' folders
#final_count = len([name for name in os.listdir(final_dir) if name.endswith(".nii.gz")])
#qa_count = len([name for name in os.listdir(qa_dir) if name.endswith(".nii.gz")])


#print(f"Total files in 'final': {final_count}")
#print(f"Total files in 'qa': {qa_count}")
#print(f"Sum of 'final' and 'qa': {final_count + qa_count}")

# Check if the sum matches
#if dir1_count == final_count + qa_count:
    #print("The sum of files in 'final' and 'qa' matches the number of files in Directory 1.")
#else:
    #print("There is a mismatch in the file counts.")
# Out:
# Number of total scans in dir 1: 1407
# Number of unique patients in Directory 1: 85
# Numebr of total scans in dir 2: 1205
# Number of unique patients in Directory 2: 91
# Unique identifiers to Directory 1: 1320
# Unique identifiers to Directory 2: 1118
# Common identifiers between the directories: 87
# Common patients between the directories: 64

# %% [markdown]
# ## BCH Data: Count patients before and after segmentation review

# %%
def count_patient_ids(folder_path):
    """counts the number of unique patient IDs in a given folder based on the filenames."""
    # Regular expression to match the patient ID in the file name
    pattern = re.compile(r"_(\d{7})_")

    # Set to store unique patient IDs
    patient_ids = set()

    # Iterate over files in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".nii.gz"):
            match = pattern.search(filename)
            if match:
                patient_ids.add(match.group(1))

    # Return the count of unique patient IDs
    return patient_ids

# %%
folder_path_bch_before_review = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/bch_longitudinal_dataset/all_files_before_review"
folder_path_bch_after_review = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/bch_longitudinal_dataset/accepted"
pat_ids_before_review = count_patient_ids(folder_path_bch_before_review)
pat_ids_after_review = count_patient_ids(folder_path_bch_after_review)
print("IDs before review:",len(pat_ids_before_review))
print("IDs after review:", len(pat_ids_after_review))
# Out:
# IDs before review: 100
# IDs after review: 88

# %%
overlapping_ids_before = pat_ids_before_review.intersection(ids_zero_filled_new)
overlapping_ids_after = pat_ids_after_review.intersection(ids_zero_filled_new)
print(f"Overlapping patient IDs Before: {len(overlapping_ids_before)}")
print(f"Overlapping patient IDs After: {len(overlapping_ids_after)}")
# Out:
# Overlapping patient IDs Before: 98
# Overlapping patient IDs After: 86

# %% [markdown]
# ## ------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## CBTN Data: Review
# Requirement: Have run the cbtn_parsing.py script before. Reviewed all of the data after the parsing script with Slicer and SegmentationReview.

# %%
# get the csv with the data to review
def read_file(csv_file):
    """
    Read and return a dataframe from a CSV file.

    Args:
        csv_file (str): Path to the CSV file.

    Returns:
        pd.DataFrame: Loaded dataframe with the CSV data.
    """
    column_names = ["Image_Name", "Quality", "Empty"]
    d_f = pd.read_csv(csv_file, names=column_names, header=None, delimiter=',')
    print(d_f.head(5))
    return d_f

def delete_entries(df):
    print(df["Quality"].unique())
    cleaned_df = df[df["Quality"] ==5]
    print(cleaned_df.head(5))
    cleaned_df.to_csv("cleaned.csv", index=False, header=False)

# %%
csv_path = "/home/jc053/GIT/mri_longitudinal_analysis/mri_longitudinal_analysis/utils/annotations_after_1st_review_converted.csv"
df_cbtn = read_file(csv_path)
delete_entries(df_cbtn)
# Out:
#                                Image_Name  Quality  Empty
# 0     0135939_19990319_2_ax_fse_t2.nii.gz        1    NaN
# 1     0135939_19990420_2_ax_fse_t2.nii.gz        1    NaN
# 2  0135939_19990811_2_axial_fse_t2.nii.gz        1    NaN
# 3  0135939_19991201_2_axial_fse_t2.nii.gz        1    NaN
# 4     0135939_20000405_2_ax_fse_t2.nii.gz        1    NaN
# [1 5]
#                                    Image_Name  Quality  Empty
# 9      0135939_20070517_8_axial_t2_tse.nii.gz        5    NaN
# 10            0135939_20070520_5_ax_t2.nii.gz        5    NaN
# 11     0135939_20090514_15_c_ax_t1_tsp.nii.gz        5    NaN
# 12    0135939_20120926_22_ax_t2_t-sp_7.nii.gz        5    NaN
# 13  0135939_20130311_22_ax_t2_frfse_t8.nii.gz        5    NaN

# %% [markdown]
# ## CBTN Data: Patient IDs after Pre / Post Separation

# %%
def extract_unique_patient_ids_from_csv(csv_path):
    cohort = "CBTN"
    id_column = "Patient_ID"
    df = pd.read_csv(csv_path)
    ids = set(df[id_column])
 
    print(f"Length of {cohort} cohort is {len(ids)}.")
    
csv_path_cbtn = "/home/jc053/GIT/mri_longitudinal_analysis/data/output/clinical_data/cbtn_pre_event.csv"
extract_unique_patient_ids_from_csv(csv_path_cbtn)
# Out:
# Length of CBTN cohort is 440.

# %% [markdown]
# ## CBTN Data: Patient IDs after 1st and 2nd review

# %%
unique_ids_1st_review = set()
unique_ids_2nd_review = set()
# Function to process a single directory
def process_directory(directory, unique_set):
    for filename in os.listdir(directory):
        if filename.endswith(".nii.gz"):
            # Extracting the part before the first underscore
            patient_id = filename.split('_')[0]
            # Check if the ID starts with 'C' followed by digits
            if patient_id.startswith('C') and patient_id[1:].isdigit():
                unique_set.add(patient_id)

def extract_unique_patient_ids(dir1, dir2, dir3, unique_set):
    # Process each directory
    process_directory(dir1, unique_set)
    process_directory(dir2, unique_set)
    process_directory(dir3, unique_set)

    return unique_set

# Example usage
dir1 = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/cbtn_longitudinal_dataset/pre_event/1"  
dir2 = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/cbtn_longitudinal_dataset/pre_event/2"
dir3 = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/cbtn_longitudinal_dataset/pre_event/5"
dir4 = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/cbtn_longitudinal_dataset/pre_event/2 - Found replacement"
dir5 = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/cbtn_longitudinal_dataset/pre_event/5 - Found replacement"

unique_patient_ids_after_1st_review = extract_unique_patient_ids(dir1, dir2, dir3, unique_ids_1st_review)
unique_patient_ids_after_2nd_review = extract_unique_patient_ids(dir1, dir4, dir5, unique_ids_2nd_review)

print(f"Unique patient IDs after 1st review: {len(unique_patient_ids_after_1st_review)}")
print(f"Unique patient IDs after 2nd review: {len(unique_patient_ids_after_2nd_review)}")
# Out:
# Unique patient IDs after 1st review: 440
# Unique patient IDs after 2nd review: 437

# %% [markdown]
# ## CBTN Data: Filter Patients with less than 3 sessions / scans and move to folder before pp

# %%
def has_minimum_sessions(source_dirs, min_sessions=3):
    """
    Checks if each patient has at least a minimum number of session IDs across the source directories.

    Parameters:
    source_dirs (list): List of source directory paths.
    min_sessions (int): Minimum number of sessions required for each patient.

    Returns:
    set: Set of patient IDs that meet the criteria.
    """
    session_count = defaultdict(set)
    for source_dir in source_dirs:
        for filename in os.listdir(source_dir):
            if filename.endswith(".nii.gz"):
                parts = filename.split('_')
                if len(parts) >= 2 and parts[0].startswith('C') and parts[0][1:].isdigit():
                    patient_id, session_id = parts[0], parts[1]
                    session_count[patient_id].add(session_id)

    # Filter patients who meet the minimum session requirement
    return {patient for patient, sessions in session_count.items() if len(sessions) >= min_sessions}

# copy patients after 2nd review and which meet the criteria of at least 3 folders
def copy_files_from_dirs_to_new_dir(source_dirs, target_dir, valid_patient_ids):
    """
    Copy files from the given source directories to the target directory.
    """
    if not os.path.exists(target_dir):
        os.makedirs(target_dir)
    total_files = sum([len(os.listdir(source_dir)) for source_dir in source_dirs])
    with tqdm(total= total_files,desc="Copying files") as pbar:
        for source_dir in source_dirs:
            for filename in os.listdir(source_dir):
                if filename.endswith(".nii.gz"):
                    patient_id = filename.split('_')[0]
                    if patient_id in valid_patient_ids:
                        source_file = os.path.join(source_dir, filename)
                        if os.path.isfile(source_file):
                            target_file = os.path.join(target_dir, filename)
                            shutil.copyfile(source_file, target_file)
                            pbar.update(1)  
                
source_dirs = [dir1, dir4, dir5]
target_dir = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/cbtn_longitudinal_dataset/pre_event/after_review_before_pp"
valid_patient_ids = has_minimum_sessions(source_dirs)
copy_files_from_dirs_to_new_dir(source_dirs, target_dir, valid_patient_ids)
# Out:
# Copying files: 100%|█████████▉| 1840/1841 [00:11<00:00, 162.35it/s]

# %%
unique_ids_after_3_scan_filtering = set()
process_directory(target_dir, unique_ids_after_3_scan_filtering)
print(f"Unique patient IDs after 3 scan filtering: {len(unique_ids_after_3_scan_filtering)}")
# Out:
# Unique patient IDs after 3 scan filtering: 115

# %% [markdown]
# ## CBTN Data: PP comparison

# %%
def compare_image_sets(path1, preprocessed_path):
    # Get the set of image file names in the first path
    images_set1 = {file for file in os.listdir(path1) if file.endswith('.nii.gz')}
    
    # Get the set of image file names in the second path
    preprocessed_images = {file.replace('.nii_0000.nii.gz', '.nii.gz') for file in os.listdir(preprocessed_path) if '.nii_0000.nii.gz' in file}    
    
    # Find the difference between the two sets
    missing_images = images_set1.difference(preprocessed_images)
    
    # Return the set of missing image file names
    return missing_images

# %%
cbtn_path_before_pp = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/cbtn_longitudinal_dataset/pre_event/after_review_before_pp"
cbtn_path_after_registration = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/cbtn_longitudinal_dataset/pre_event/output/T2W_registration/"
cbtn_path_after_brain_extraction = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/cbtn_longitudinal_dataset/pre_event/output/T2W_brain_extraction/"
missing_scans_registration = compare_image_sets(cbtn_path_before_pp, cbtn_path_after_registration)
print(f"Number of missing scans after registration: {len(missing_scans_registration)}")
print(f"Missing scans after registration: {missing_scans_registration}")
missing_scans_brain_extraction = compare_image_sets(cbtn_path_after_registration, cbtn_path_after_brain_extraction)
print(f"Number of missing scans after brain extraction: {len(missing_scans_brain_extraction)}")
print(f"Missing scans after brain extraction: {missing_scans_brain_extraction}")
# Out:
# Number of missing scans after registration: 14
# Missing scans after registration: {'C1047222_5759.nii.gz', 'C19188_4132.nii.gz', 'C62730_5329.nii.gz', 'C2647698_3958.nii.gz', 'C62730_8431.nii.gz', 'C883263_6041.nii.gz', 'C1047222_5968.nii.gz', 'C883263_5813.nii.gz', 'C3557160_2096.nii.gz', 'C1003434_3708.nii.gz', 'C3600948_1088.nii.gz', 'C3400212_695.nii.gz', 'C1003434_4182.nii.gz', 'C62730_5975.nii.gz'}
# Number of missing scans after brain extraction: 1878
# Missing scans after brain extraction: {'C3817551_1771.nii_0000.nii.gz', 'C4065273_3034.nii_0000.nii.gz', 'C88683_1357.nii_0000.nii.gz', 'C4127757_786.nii_0000.nii.gz', 'C3528132_950.nii_0000.nii.gz', 'C123861_9255.nii_0000.nii.gz', 'C140466_7588.nii_0000.nii.gz', 'C801960_5763.nii_0000.nii.gz', 'C3944610_4249.nii_0000.nii.gz', 'C38868_3284.nii_0000.nii.gz', 'C41451_1228.nii_0000.nii.gz', 'C38868_6977.nii_0000.nii.gz', 'C3422967_5355.nii_0000.nii.gz', 'C4256415_3925.nii_0000.nii.gz', 'C431607_5012.nii_0000.nii.gz', 'C36654_2992.nii_0000.nii.gz', 'C324351_2745.nii_0000.nii.gz', 'C4065273_1594.nii_0000.nii.gz', 'C62730_8255.nii_0000.nii.gz', 'C46863_5248.nii_0000.nii.gz', 'C719673_8581.nii_0000.nii.gz', 'C440832_6225.nii_0000.nii.gz', 'C136161_4499.nii_0000.nii.gz', 'C744642_2328.nii_0000.nii.gz', 'C38868_3121.nii_0000.nii.gz', 'C3399720_2697.nii_0000.nii.gz', 'C24969_2288.nii_0000.nii.gz', 'C723978_1898.nii_0000.nii.gz', 'C713892_1954.nii_0000.nii.gz', 'C36654_3237.nii_0000.nii.gz', 'C831726_260.nii_0000.nii.gz', 'C735540_4275.nii_0000.nii.gz', 'C38868_2576.nii_0000.nii.gz', 'C66420_1474.nii_0000.nii.gz', 'C123861_7337.nii_0000.nii.gz', 'C39483_8397.nii_0000.nii.gz', 'C3684711_6807.nii_0000.nii.gz', 'C1060998_6327.nii_0000.nii.gz', 'C2859135_2192.nii_0000.nii.gz', 'C88929_4725.nii_0000.nii.gz', 'C52644_5777.nii_0000.nii.gz', 'C3420507_2718.nii_0000.nii.gz', 'C38868_6788.nii_0000.nii.gz', 'C231240_1517.nii_0000.nii.gz', 'C46863_4345.nii_0000.nii.gz', 'C123861_3823.nii_0000.nii.gz', 'C1042056_3045.nii_0000.nii.gz', 'C2855076_6307.nii_0000.nii.gz', 'C3684588_5968.nii_0000.nii.gz', 'C45387_6950.nii_0000.nii.gz', 'C72201_910.nii_0000.nii.gz', 'C624471_6252.nii_0000.nii.gz', 'C28413_3309.nii_0000.nii.gz', 'C3817551_2445.nii_0000.nii.gz', 'C916473_2359.nii_0000.nii.gz', 'C33825_7936.nii_0000.nii.gz', 'C136161_6091.nii_0000.nii.gz', 'C735540_7299.nii_0000.nii.gz', 'C1032462_1159.nii_0000.nii.gz', 'C324597_5734.nii_0000.nii.gz', 'C1077234_6845.nii_0000.nii.gz', 'C2653971_8010.nii_0000.nii.gz', 'C4312872_4638.nii_0000.nii.gz', 'C3396522_3886.nii_0000.nii.gz', 'C3945102_4888.nii_0000.nii.gz', 'C66420_2416.nii_0000.nii.gz', 'C136161_3579.nii_0000.nii.gz', 'C3396522_2346.nii_0000.nii.gz', 'C2354097_2572.nii_0000.nii.gz', 'C744642_3521.nii_0000.nii.gz', 'C37638_1932.nii_0000.nii.gz', 'C17835_128.nii_0000.nii.gz', 'C854604_8542.nii_0000.nii.gz', 'C1064934_4546.nii_0000.nii.gz', 'C136161_2099.nii_0000.nii.gz', 'C744642_1769.nii_0000.nii.gz', 'C3396522_821.nii_0000.nii.gz', 'C136161_273.nii_0000.nii.gz', 'C1042056_2861.nii_0000.nii.gz', 'C3396522_2725.nii_0000.nii.gz', 'C123861_5319.nii_0000.nii.gz', 'C4002051_4494.nii_0000.nii.gz', 'C650178_809.nii_0000.nii.gz', 'C836892_4381.nii_0000.nii.gz', 'C136161_411.nii_0000.nii.gz', 'C71217_2920.nii_0000.nii.gz', 'C62730_9663.nii_0000.nii.gz', 'C38868_5908.nii_0000.nii.gz', 'C123861_7764.nii_0000.nii.gz', 'C2668362_4088.nii_0000.nii.gz', 'C3702423_3678.nii_0000.nii.gz', 'C4310289_1171.nii_0000.nii.gz', 'C46863_4166.nii_0000.nii.gz', 'C808110_3763.nii_0000.nii.gz', 'C270477_4716.nii_0000.nii.gz', 'C4280646_2138.nii_0000.nii.gz', 'C38868_4206.nii_0000.nii.gz', 'C311190_4629.nii_0000.nii.gz', 'C68634_1175.nii_0000.nii.gz', 'C883509_6079.nii_0000.nii.gz', 'C53505_3877.nii_0000.nii.gz', 'C949560_6362.nii_0000.nii.gz', 'C324351_3167.nii_0000.nii.gz', 'C136161_5291.nii_0000.nii.gz', 'C28413_4212.nii_0000.nii.gz', 'C2819898_5205.nii_0000.nii.gz', 'C46863_705.nii_0000.nii.gz', 'C28413_6058.nii_0000.nii.gz', 'C916473_1949.nii_0000.nii.gz', 'C4007955_2684.nii_0000.nii.gz', 'C854604_6541.nii_0000.nii.gz', 'C36654_5652.nii_0000.nii.gz', 'C2334663_5490.nii_0000.nii.gz', 'C883509_6149.nii_0000.nii.gz', 'C24969_174.nii_0000.nii.gz', 'C3622473_5829.nii_0000.nii.gz', 'C854604_6673.nii_0000.nii.gz', 'C719673_8953.nii_0000.nii.gz', 'C2734782_3540.nii_0000.nii.gz', 'C154980_3357.nii_0000.nii.gz', 'C62730_4744.nii_0000.nii.gz', 'C836892_3352.nii_0000.nii.gz', 'C3684711_7018.nii_0000.nii.gz', 'C3420507_5636.nii_0000.nii.gz',  ...

# %% [markdown]
# ## CBTN Data (Additional): Rename images in case pp messed up

# %%
def rename_files(directory):
    count = 0
    for filename in os.listdir(directory):
        if filename.endswith('.nii_0000.nii.gz'):
            # Construct the new file name
            new_filename = filename.replace('.nii_0000.nii.gz', '_0000.nii.gz')
            # Construct full file paths
            old_file = os.path.join(directory, filename)
            new_file = os.path.join(directory, new_filename)
            # Rename the file
            os.rename(old_file, new_file)
            print(f'Renamed: {filename} to {new_filename}')
            count += 1
    print(f"Renamed {count} files.")

# %%
#rename_files(cbtn_path_after_registration)
#rename_files(cbtn_path_after_brain_extraction)
# Out:
# Renamed: C1003434_3593.nii_0000.nii.gz to C1003434_3593_0000.nii.gz
# Renamed: C1003434_3825.nii_0000.nii.gz to C1003434_3825_0000.nii.gz
# Renamed: C1003434_4205.nii_0000.nii.gz to C1003434_4205_0000.nii.gz
# Renamed: C1003434_4260.nii_0000.nii.gz to C1003434_4260_0000.nii.gz
# Renamed: C1003434_4355.nii_0000.nii.gz to C1003434_4355_0000.nii.gz
# Renamed: C1003434_4457.nii_0000.nii.gz to C1003434_4457_0000.nii.gz
# Renamed: C1003434_4599.nii_0000.nii.gz to C1003434_4599_0000.nii.gz
# Renamed: C1003434_4817.nii_0000.nii.gz to C1003434_4817_0000.nii.gz
# Renamed: C1003434_5048.nii_0000.nii.gz to C1003434_5048_0000.nii.gz
# Renamed: C1003434_5331.nii_0000.nii.gz to C1003434_5331_0000.nii.gz
# Renamed: C1003434_5706.nii_0000.nii.gz to C1003434_5706_0000.nii.gz
# Renamed: C1003557_2317.nii_0000.nii.gz to C1003557_2317_0000.nii.gz
# Renamed: C1003680_3385.nii_0000.nii.gz to C1003680_3385_0000.nii.gz
# Renamed: C1003680_3394.nii_0000.nii.gz to C1003680_3394_0000.nii.gz
# Renamed: C102459_1983.nii_0000.nii.gz to C102459_1983_0000.nii.gz
# Renamed: C1026189_1894.nii_0000.nii.gz to C1026189_1894_0000.nii.gz
# Renamed: C1026312_2598.nii_0000.nii.gz to C1026312_2598_0000.nii.gz
# Renamed: C1026312_2840.nii_0000.nii.gz to C1026312_2840_0000.nii.gz
# Renamed: C1026312_2879.nii_0000.nii.gz to C1026312_2879_0000.nii.gz
# Renamed: C1026312_2883.nii_0000.nii.gz to C1026312_2883_0000.nii.gz
# Renamed: C1026435_7115.nii_0000.nii.gz to C1026435_7115_0000.nii.gz
# Renamed: C1026558_3287.nii_0000.nii.gz to C1026558_3287_0000.nii.gz
# Renamed: C1026558_4971.nii_0000.nii.gz to C1026558_4971_0000.nii.gz
# Renamed: C1026558_4988.nii_0000.nii.gz to C1026558_4988_0000.nii.gz
# Renamed: C1026558_4989.nii_0000.nii.gz to C1026558_4989_0000.nii.gz
# Renamed: C1031970_225.nii_0000.nii.gz to C1031970_225_0000.nii.gz
# Renamed: C1032462_1159.nii_0000.nii.gz to C1032462_1159_0000.nii.gz
# Renamed: C1032462_1161.nii_0000.nii.gz to C1032462_1161_0000.nii.gz
# Renamed: C1032585_3091.nii_0000.nii.gz to C1032585_3091_0000.nii.gz
# Renamed: C1032585_3092.nii_0000.nii.gz to C1032585_3092_0000.nii.gz
# Renamed: C1039104_1016.nii_0000.nii.gz to C1039104_1016_0000.nii.gz
# Renamed: C1039104_259.nii_0000.nii.gz to C1039104_259_0000.nii.gz
# Renamed: C1039104_568.nii_0000.nii.gz to C1039104_568_0000.nii.gz
# Renamed: C1039473_5672.nii_0000.nii.gz to C1039473_5672_0000.nii.gz
# Renamed: C1042056_2300.nii_0000.nii.gz to C1042056_2300_0000.nii.gz
# Renamed: C1042056_2383.nii_0000.nii.gz to C1042056_2383_0000.nii.gz
# Renamed: C1042056_2471.nii_0000.nii.gz to C1042056_2471_0000.nii.gz
# Renamed: C1042056_2565.nii_0000.nii.gz to C1042056_2565_0000.nii.gz
# Renamed: C1042056_2667.nii_0000.nii.gz to C1042056_2667_0000.nii.gz
# Renamed: C1042056_2777.nii_0000.nii.gz to C1042056_2777_0000.nii.gz
# Renamed: C1042056_2861.nii_0000.nii.gz to C1042056_2861_0000.nii.gz
# Renamed: C1042056_2972.nii_0000.nii.gz to C1042056_2972_0000.nii.gz
# Renamed: C1042056_3045.nii_0000.nii.gz to C1042056_3045_0000.nii.gz
# Renamed: C1042056_3118.nii_0000.nii.gz to C1042056_3118_0000.nii.gz
# Renamed: C1042056_3218.nii_0000.nii.gz to C1042056_3218_0000.nii.gz
# Renamed: C1042056_3332.nii_0000.nii.gz to C1042056_3332_0000.nii.gz
# Renamed: C1042056_3430.nii_0000.nii.gz to C1042056_3430_0000.nii.gz
# Renamed: C1042056_3597.nii_0000.nii.gz to C1042056_3597_0000.nii.gz
# Renamed: C1042056_3790.nii_0000.nii.gz to C1042056_3790_0000.nii.gz
# Renamed: C1042056_4087.nii_0000.nii.gz to C1042056_4087_0000.nii.gz
# Renamed: C1042056_4169.nii_0000.nii.gz to C1042056_4169_0000.nii.gz
# Renamed: C1042179_1256.nii_0000.nii.gz to C1042179_1256_0000.nii.gz
# Renamed: C1042179_1265.nii_0000.nii.gz to C1042179_1265_0000.nii.gz
# Renamed: C1042179_1319.nii_0000.nii.gz to C1042179_1319_0000.nii.gz
# Renamed: C1042179_1320.nii_0000.nii.gz to C1042179_1320_0000.nii.gz
# Renamed: C1046730_2384.nii_0000.nii.gz to C1046730_2384_0000.nii.gz
# Renamed: C1047222_5220.nii_0000.nii.gz to C1047222_5220_0000.nii.gz
# Renamed: C1047222_6079.nii_0000.nii.gz to C1047222_6079_0000.nii.gz
# Renamed: C1060998_6312.nii_0000.nii.gz to C1060998_6312_0000.nii.gz
# Renamed: C1060998_6327.nii_0000.nii.gz to C1060998_6327_0000.nii.gz
# Renamed: C1060998_6338.nii_0000.nii.gz to C1060998_6338_0000.nii.gz
# Renamed: C1064934_4527.nii_0000.nii.gz to C1064934_4527_0000.nii.gz
# Renamed: C1064934_4546.nii_0000.nii.gz to C1064934_4546_0000.nii.gz
# Renamed: C1064934_4587.nii_0000.nii.gz to C1064934_4587_0000.nii.gz
# Renamed: C1072314_303.nii_0000.nii.gz to C1072314_303_0000.nii.gz
# Renamed: C1072314_305.nii_0000.nii.gz to C1072314_305_0000.nii.gz
# Renamed: C1077234_5012.nii_0000.nii.gz to C1077234_5012_0000.nii.gz
# Renamed: C1077234_5377.nii_0000.nii.gz to C1077234_5377_0000.nii.gz
# Renamed: C1077234_5742.nii_0000.nii.gz to C1077234_5742_0000.nii.gz
# Renamed: C1077234_6111.nii_0000.nii.gz to C1077234_6111_0000.nii.gz
# Renamed: C1077234_6284.nii_0000.nii.gz to C1077234_6284_0000.nii.gz
# Renamed: C1077234_6285.nii_0000.nii.gz to C1077234_6285_0000.nii.gz
# Renamed: C1077234_6372.nii_0000.nii.gz to C1077234_6372_0000.nii.gz
# Renamed: C1077234_6474.nii_0000.nii.gz to C1077234_6474_0000.nii.gz
# Renamed: C1077234_6664.nii_0000.nii.gz to C1077234_6664_0000.nii.gz
# Renamed: C1077234_6845.nii_0000.nii.gz to C1077234_6845_0000.nii.gz
# Renamed: C1077234_7021.nii_0000.nii.gz to C1077234_7021_0000.nii.gz
# Renamed: C1077234_7223.nii_0000.nii.gz to C1077234_7223_0000.nii.gz
# Renamed: C1077234_7398.nii_0000.nii.gz to C1077234_7398_0000.nii.gz
# Renamed: C1077234_7762.nii_0000.nii.gz to C1077234_7762_0000.nii.gz
# Renamed: C1077234_8133.nii_0000.nii.gz to C1077234_8133_0000.nii.gz
# Renamed: C1077357_3034.nii_0000.nii.gz to C1077357_3034_0000.nii.gz
# Renamed: C1077357_3040.nii_0000.nii.gz to C1077357_3040_0000.nii.gz
# Renamed: C1077357_3076.nii_0000.nii.gz to C1077357_3076_0000.nii.gz
# Renamed: C1077357_3083.nii_0000.nii.gz to C1077357_3083_0000.nii.gz
# Renamed: C1077357_3104.nii_0000.nii.gz to C1077357_3104_0000.nii.gz
# Renamed: C1077357_3195.nii_0000.nii.gz to C1077357_3195_0000.nii.gz
# Renamed: C1077357_3279.nii_0000.nii.gz to C1077357_3279_0000.nii.gz
# Renamed: C1077357_3363.nii_0000.nii.gz to C1077357_3363_0000.nii.gz
# Renamed: C1077480_4062.nii_0000.nii.gz to C1077480_4062_0000.nii.gz
# Renamed: C1095315_3085.nii_0000.nii.gz to C1095315_3085_0000.nii.gz
# Renamed: C1095315_3270.nii_0000.nii.gz to C1095315_3270_0000.nii.gz
# Renamed: C1095315_3469.nii_0000.nii.gz to C1095315_3469_0000.nii.gz
# Renamed: C1095315_6260.nii_0000.nii.gz to C1095315_6260_0000.nii.gz
# Renamed: C1095315_6276.nii_0000.nii.gz to C1095315_6276_0000.nii.gz
# Renamed: C1095315_6373.nii_0000.nii.gz to C1095315_6373_0000.nii.gz
# Renamed: C1095315_6463.nii_0000.nii.gz to C1095315_6463_0000.nii.gz
# Renamed: C1095315_6554.nii_0000.nii.gz to C1095315_6554_0000.nii.gz
# Renamed: C1095315_6722.nii_0000.nii.gz to C1095315_6722_0000.nii.gz
# Renamed: C1095315_6827.nii_0000.nii.gz to C1095315_6827_0000.nii.gz
# Renamed: C1095315_6917.nii_0000.nii.gz to C1095315_6917_0000.nii.gz
# Renamed: C1095315_7166.nii_0000.nii.gz to C1095315_7166_0000.nii.gz
# Renamed: C1095315_7257.nii_0000.nii.gz to C1095315_7257_0000.nii.gz
# Renamed: C1095315_7362.nii_0000.nii.gz to C1095315_7362_0000.nii.gz
# Renamed: C1095315_7449.nii_0000.nii.gz to C1095315_7449_0000.nii.gz
# Renamed: C1095315_7537.nii_0000.nii.gz to C1095315_7537_0000.nii.gz
# Renamed: C1095315_7621.nii_0000.nii.gz to C1095315_7621_0000.nii.gz
# Renamed: C1095315_7712.nii_0000.nii.gz to C1095315_7712_0000.nii.gz
# Renamed: C1100727_2000.nii_0000.nii.gz to C1100727_2000_0000.nii.gz
# Renamed: C111684_4128.nii_0000.nii.gz to C111684_4128_0000.nii.gz
# Renamed: C111930_194.nii_0000.nii.gz to C111930_194_0000.nii.gz
# Renamed: C114759_551.nii_0000.nii.gz to C114759_551_0000.nii.gz
# Renamed: C1152018_5241.nii_0000.nii.gz to C1152018_5241_0000.nii.gz
# Renamed: C1152018_5242.nii_0000.nii.gz to C1152018_5242_0000.nii.gz
# Renamed: C115251_5801.nii_0000.nii.gz to C115251_5801_0000.nii.gz
# Renamed: C1152633_1804.nii_0000.nii.gz to C1152633_1804_0000.nii.gz
# Renamed: C1152633_1805.nii_0000.nii.gz to C1152633_1805_0000.nii.gz
# Renamed: C116850_484.nii_0000.nii.gz to C116850_484_0000.nii.gz
# Renamed: C116850_614.nii_0000.nii.gz to C116850_614_0000.nii.gz
# Renamed: C1173297_4936.nii_0000.nii.gz to C1173297_4936_0000.nii.gz
# Renamed: C1173297_4937.nii_0000.nii.gz to C1173297_4937_0000.nii.gz
# Renamed: C1173420_693.nii_0000.nii.gz to C1173420_693_0000.nii.gz
# Renamed: C1191378_4669.nii_0000.nii.gz to C1191378_4669_0000.nii.gz
# Renamed: C1191501_1547.nii_0000.nii.gz to C1191501_1547_0000.nii.gz
# Renamed: C1191501_1548.nii_0000.nii.gz to C1191501_1548_0000.nii.gz
# Renamed: C1191993_4800.nii_0000.nii.gz to C1191993_4800_0000.nii.gz
# Renamed: C1191993_4833.nii_0000.nii.gz to C1191993_4833_0000.nii.gz
# Renamed: C1191993_4853.nii_0000.nii.gz to C1191993_4853_0000.nii.gz
# Renamed: C1198758_2227.nii_0000.nii.gz to C1198758_2227_0000.nii.gz
# Renamed: C1198758_2228.nii_0000.nii.gz to C1198758_2228_0000.nii.gz
# Renamed: C1198881_1994.nii_0000.nii.gz to C1198881_1994_0000.nii.gz
# Renamed: C1198881_1995.nii_0000.nii.gz to C1198881_1995_0000.nii.gz
# Renamed: C1199004_3408.nii_0000.nii.gz to C1199004_3408_0000.nii.gz
# Renamed: C1199004_3409.nii_0000.nii.gz to C1199004_3409_0000.nii.gz
# Renamed: C121524_1388.nii_0000.nii.gz to C121524_1388_0000.nii.gz
# Renamed: C1222743_4577.nii_0000.nii.gz to C1222743_4577_0000.nii.gz
# Renamed: C1232829_1778.nii_0000.nii.gz to C1232829_1778_0000.nii.gz
# Renamed: C1232829_2030.nii_0000.nii.gz to C1232829_2030_0000.nii.gz
# Renamed: C1232829_3077.nii_0000.nii.gz to C1232829_3077_0000.nii.gz
# Renamed: C1232829_3145.nii_0000.nii.gz to C1232829_3145_0000.nii.gz
# Renamed: C1232829_3146.nii_0000.nii.gz to C1232829_3146_0000.nii.gz
# Renamed: C1232829_3246.nii_0000.nii.gz to C1232829_3246_0000.nii.gz
# Renamed: C1232829_3427.nii_0000.nii.gz to C1232829_3427_0000.nii.gz
# Renamed: C1232829_3561.nii_0000.nii.gz to C1232829_3561_0000.nii.gz
# Renamed: C1232829_3751.nii_0000.nii.gz to C1232829_3751_0000.nii.gz
# Renamed: C1232829_3930.nii_0000.nii.gz to C1232829_3930_0000.nii.gz
# Renamed: C1232829_4057.nii_0000.nii.gz to C1232829_4057_0000.nii.gz
# Renamed: C1232829_4141.nii_0000.nii.gz to C1232829_4141_0000.nii.gz
# Renamed: C1232829_4146.nii_0000.nii.gz to C1232829_4146_0000.nii.gz
# Renamed: C1232829_4273.nii_0000.nii.gz to C1232829_4273_0000.nii.gz
# Renamed: C1232829_4384.nii_0000.nii.gz to C1232829_4384_0000.nii.gz
# Renamed: C1232829_4497.nii_0000.nii.gz to C1232829_4497_0000.nii.gz
# Renamed: C1232829_4653.nii_0000.nii.gz to C1232829_4653_0000.nii.gz
# Renamed: C1232829_4850.nii_0000.nii.gz to C1232829_4850_0000.nii.gz
# Renamed: C1233198_3121.nii_0000.nii.gz to C1233198_3121_0000.nii.gz
# Renamed: C123861_3185.nii_0000.nii.gz to C123861_3185_0000.nii.gz
# Renamed: C123861_3234.nii_0000.nii.gz to C123861_3234_0000.nii.gz
# Renamed: C123861_3319.nii_0000.nii.gz to C123861_3319_0000.nii.gz
# Renamed: C123861_3421.nii_0000.nii.gz to C123861_3421_0000.nii.gz
# Renamed: C123861_3501.nii_0000.nii.gz to C123861_3501_0000.nii.gz
# Renamed: C123861_3680.nii_0000.nii.gz to C123861_3680_0000.nii.gz
# Renamed: C123861_3823.nii_0000.nii.gz to C123861_3823_0000.nii.gz
# Renamed: C123861_4026.nii_0000.nii.gz to C123861_4026_0000.nii.gz
# Renamed: C123861_4236.nii_0000.nii.gz to C123861_4236_0000.nii.gz
# Renamed: C123861_4422.nii_0000.nii.gz to C123861_4422_0000.nii.gz
# Renamed: C123861_4614.nii_0000.nii.gz to C123861_4614_0000.nii.gz
# Renamed: C123861_4929.nii_0000.nii.gz to C123861_4929_0000.nii.gz
# Renamed: C123861_5319.nii_0000.nii.gz to C123861_5319_0000.nii.gz
# Renamed: C123861_5671.nii_0000.nii.gz to C123861_5671_0000.nii.gz
# Renamed: C123861_6056.nii_0000.nii.gz to C123861_6056_0000.nii.gz
# Renamed: C123861_7328.nii_0000.nii.gz to C123861_7328_0000.nii.gz
# Renamed: C123861_7337.nii_0000.nii.gz to C123861_7337_0000.nii.gz
# Renamed: C123861_7341.nii_0000.nii.gz to C123861_7341_0000.nii.gz
# Renamed: C123861_7461.nii_0000.nii.gz to C123861_7461_0000.nii.gz
# Renamed: C123861_7523.nii_0000.nii.gz to C123861_7523_0000.nii.gz
# Renamed: C123861_7579.nii_0000.nii.gz to C123861_7579_0000.nii.gz
# Renamed: C123861_7677.nii_0000.nii.gz to C123861_7677_0000.nii.gz
# Renamed: C123861_7764.nii_0000.nii.gz to C123861_7764_0000.nii.gz
# Renamed: C123861_7894.nii_0000.nii.gz to C123861_7894_0000.nii.gz
# Renamed: C123861_8044.nii_0000.nii.gz to C123861_8044_0000.nii.gz
# Renamed: C123861_8175.nii_0000.nii.gz to C123861_8175_0000.nii.gz
# Renamed: C123861_8538.nii_0000.nii.gz to C123861_8538_0000.nii.gz
# Renamed: C123861_8709.nii_0000.nii.gz to C123861_8709_0000.nii.gz
# Renamed: C123861_8891.nii_0000.nii.gz to C123861_8891_0000.nii.gz
# Renamed: C123861_9073.nii_0000.nii.gz to C123861_9073_0000.nii.gz
# Renamed: C123861_9255.nii_0000.nii.gz to C123861_9255_0000.nii.gz
# Renamed: C123861_9393.nii_0000.nii.gz to C123861_9393_0000.nii.gz
# Renamed: C123861_9616.nii_0000.nii.gz to C123861_9616_0000.nii.gz
# Renamed: C123861_9981.nii_0000.nii.gz to C123861_9981_0000.nii.gz
# Renamed: C1248081_1176.nii_0000.nii.gz to C1248081_1176_0000.nii.gz
# Renamed: C1248081_1179.nii_0000.nii.gz to C1248081_1179_0000.nii.gz
# Renamed: C1263456_4412.nii_0000.nii.gz to C1263456_4412_0000.nii.gz
# Renamed: C1264686_4277.nii_0000.nii.gz to C1264686_4277_0000.nii.gz
# Renamed: C1264686_4286.nii_0000.nii.gz to C1264686_4286_0000.nii.gz
# Renamed: C1264809_6547.nii_0000.nii.gz to C1264809_6547_0000.nii.gz
# Renamed: C1264809_6551.nii_0000.nii.gz to C1264809_6551_0000.nii.gz
# Renamed: C1264809_6552.nii_0000.nii.gz to C1264809_6552_0000.nii.gz
# Renamed: C1264932_1793.nii_0000.nii.gz to C1264932_1793_0000.nii.gz
# Renamed: C1277724_4762.nii_0000.nii.gz to C1277724_4762_0000.nii.gz
# Renamed: C1277724_4763.nii_0000.nii.gz to C1277724_4763_0000.nii.gz
# Renamed: C136161_1101.nii_0000.nii.gz to C136161_1101_0000.nii.gz
# Renamed: C136161_1225.nii_0000.nii.gz to C136161_1225_0000.nii.gz
# Renamed: C136161_1329.nii_0000.nii.gz to C136161_1329_0000.nii.gz
# Renamed: C136161_1475.nii_0000.nii.gz to C136161_1475_0000.nii.gz
# Renamed: C136161_1598.nii_0000.nii.gz to C136161_1598_0000.nii.gz
# Renamed: C136161_1728.nii_0000.nii.gz to C136161_1728_0000.nii.gz
# Renamed: C136161_1778.nii_0000.nii.gz to C136161_1778_0000.nii.gz
# Renamed: C136161_1867.nii_0000.nii.gz to C136161_1867_0000.nii.gz
# Renamed: C136161_2010.nii_0000.nii.gz to C136161_2010_0000.nii.gz
# Renamed: C136161_2099.nii_0000.nii.gz to C136161_2099_0000.nii.gz
# Renamed: C136161_2200.nii_0000.nii.gz to C136161_2200_0000.nii.gz
# Renamed: C136161_229.nii_0000.nii.gz to C136161_229_0000.nii.gz
# Renamed: C136161_2331.nii_0000.nii.gz to C136161_2331_0000.nii.gz
# Renamed: C136161_2399.nii_0000.nii.gz to C136161_2399_0000.nii.gz
# Renamed: C136161_2472.nii_0000.nii.gz to C136161_2472_0000.nii.gz
# Renamed: C136161_2485.nii_0000.nii.gz to C136161_2485_0000.nii.gz
# Renamed: C136161_2504.nii_0000.nii.gz to C136161_2504_0000.nii.gz
# Renamed: C136161_2515.nii_0000.nii.gz to C136161_2515_0000.nii.gz
# Renamed: C136161_2528.nii_0000.nii.gz to C136161_2528_0000.nii.gz
# Renamed: C136161_2634.nii_0000.nii.gz to C136161_2634_0000.nii.gz
# Renamed: C136161_273.nii_0000.nii.gz to C136161_273_0000.nii.gz
# Renamed: C136161_2752.nii_0000.nii.gz to C136161_2752_0000.nii.gz
# Renamed: C136161_2833.nii_0000.nii.gz to C136161_2833_0000.nii.gz
# Renamed: C136161_2933.nii_0000.nii.gz to C136161_2933_0000.nii.gz
# Renamed: C136161_3004.nii_0000.nii.gz to C136161_3004_0000.nii.gz
# Renamed: C136161_3102.nii_0000.nii.gz to C136161_3102_0000.nii.gz
# Renamed: C136161_3152.nii_0000.nii.gz to C136161_3152_0000.nii.gz
# Renamed: C136161_316.nii_0000.nii.gz to C136161_316_0000.nii.gz
# Renamed: C136161_3242.nii_0000.nii.gz to C136161_3242_0000.nii.gz
# Renamed: C136161_3353.nii_0000.nii.gz to C136161_3353_0000.nii.gz
# Renamed: C136161_3436.nii_0000.nii.gz to C136161_3436_0000.nii.gz
# Renamed: C136161_355.nii_0000.nii.gz to C136161_355_0000.nii.gz
# Renamed: C136161_3579.nii_0000.nii.gz to C136161_3579_0000.nii.gz
# Renamed: C136161_3661.nii_0000.nii.gz to C136161_3661_0000.nii.gz
# Renamed: C136161_3781.nii_0000.nii.gz to C136161_3781_0000.nii.gz
# Renamed: C136161_3849.nii_0000.nii.gz to C136161_3849_0000.nii.gz
# Renamed: C136161_3931.nii_0000.nii.gz to C136161_3931_0000.nii.gz
# Renamed: C136161_3936.nii_0000.nii.gz to C136161_3936_0000.nii.gz
# Renamed: C136161_3978.nii_0000.nii.gz to C136161_3978_0000.nii.gz
# Renamed: C136161_4026.nii_0000.nii.gz to C136161_4026_0000.nii.gz
# Renamed: C136161_4094.nii_0000.nii.gz to C136161_4094_0000.nii.gz
# Renamed: C136161_411.nii_0000.nii.gz to C136161_411_0000.nii.gz
# Renamed: C136161_4206.nii_0000.nii.gz to C136161_4206_0000.nii.gz
# Renamed: C136161_4334.nii_0000.nii.gz to C136161_4334_0000.nii.gz
# Renamed: C136161_4499.nii_0000.nii.gz to C136161_4499_0000.nii.gz
# Renamed: C136161_4516.nii_0000.nii.gz to C136161_4516_0000.nii.gz
# Renamed: C136161_4521.nii_0000.nii.gz to C136161_4521_0000.nii.gz
# Renamed: C136161_4584.nii_0000.nii.gz to C136161_4584_0000.nii.gz
# Renamed: C136161_4634.nii_0000.nii.gz to C136161_4634_0000.nii.gz
# Renamed: C136161_465.nii_0000.nii.gz to C136161_465_0000.nii.gz
# Renamed: C136161_4663.nii_0000.nii.gz to C136161_4663_0000.nii.gz
# Renamed: C136161_4677.nii_0000.nii.gz to C136161_4677_0000.nii.gz
# Renamed: C136161_4727.nii_0000.nii.gz to C136161_4727_0000.nii.gz
# Renamed: C136161_4797.nii_0000.nii.gz to C136161_4797_0000.nii.gz
# Renamed: C136161_4830.nii_0000.nii.gz to C136161_4830_0000.nii.gz
# Renamed: C136161_4929.nii_0000.nii.gz to C136161_4929_0000.nii.gz
# Renamed: C136161_5032.nii_0000.nii.gz to C136161_5032_0000.nii.gz
# Renamed: C136161_5091.nii_0000.nii.gz to C136161_5091_0000.nii.gz
# Renamed: C136161_5157.nii_0000.nii.gz to C136161_5157_0000.nii.gz
# Renamed: C136161_5291.nii_0000.nii.gz to C136161_5291_0000.nii.gz
# Renamed: C136161_532.nii_0000.nii.gz to C136161_532_0000.nii.gz
# Renamed: C136161_5425.nii_0000.nii.gz to C136161_5425_0000.nii.gz
# Renamed: C136161_5511.nii_0000.nii.gz to C136161_5511_0000.nii.gz
# Renamed: C136161_5670.nii_0000.nii.gz to C136161_5670_0000.nii.gz
# Renamed: C136161_5759.nii_0000.nii.gz to C136161_5759_0000.nii.gz
# Renamed: C136161_5872.nii_0000.nii.gz to C136161_5872_0000.nii.gz
# Renamed: C136161_5981.nii_0000.nii.gz to C136161_5981_0000.nii.gz
# Renamed: C136161_601.nii_0000.nii.gz to C136161_601_0000.nii.gz
# Renamed: C136161_6091.nii_0000.nii.gz to C136161_6091_0000.nii.gz
# Renamed: C136161_6187.nii_0000.nii.gz to C136161_6187_0000.nii.gz
# Renamed: C136161_6244.nii_0000.nii.gz to C136161_6244_0000.nii.gz
# Renamed: C136161_6401.nii_0000.nii.gz to C136161_6401_0000.nii.gz
# Renamed: C136161_6532.nii_0000.nii.gz to C136161_6532_0000.nii.gz
# Renamed: C136161_6645.nii_0000.nii.gz to C136161_6645_0000.nii.gz
# Renamed: C136161_6750.nii_0000.nii.gz to C136161_6750_0000.nii.gz
# Renamed: C136161_685.nii_0000.nii.gz to C136161_685_0000.nii.gz
# Renamed: C136161_6886.nii_0000.nii.gz to C136161_6886_0000.nii.gz
# Renamed: C136161_6988.nii_0000.nii.gz to C136161_6988_0000.nii.gz
# Renamed: C136161_811.nii_0000.nii.gz to C136161_811_0000.nii.gz
# Renamed: C136161_917.nii_0000.nii.gz to C136161_917_0000.nii.gz
# Renamed: C136161_994.nii_0000.nii.gz to C136161_994_0000.nii.gz
# Renamed: C136284_5674.nii_0000.nii.gz to C136284_5674_0000.nii.gz
# Renamed: C136284_5732.nii_0000.nii.gz to C136284_5732_0000.nii.gz
# Renamed: C136530_792.nii_0000.nii.gz to C136530_792_0000.nii.gz
# Renamed: C140097_4258.nii_0000.nii.gz to C140097_4258_0000.nii.gz
# Renamed: C140466_5531.nii_0000.nii.gz to C140466_5531_0000.nii.gz
# Renamed: C140466_5762.nii_0000.nii.gz to C140466_5762_0000.nii.gz
# Renamed: C140466_5857.nii_0000.nii.gz to C140466_5857_0000.nii.gz
# Renamed: C140466_5905.nii_0000.nii.gz to C140466_5905_0000.nii.gz
# Renamed: C140466_6010.nii_0000.nii.gz to C140466_6010_0000.nii.gz
# Renamed: C140466_6081.nii_0000.nii.gz to C140466_6081_0000.nii.gz
# Renamed: C140466_6132.nii_0000.nii.gz to C140466_6132_0000.nii.gz
# Renamed: C140466_6237.nii_0000.nii.gz to C140466_6237_0000.nii.gz
# Renamed: C140466_6325.nii_0000.nii.gz to C140466_6325_0000.nii.gz
# Renamed: C140466_6430.nii_0000.nii.gz to C140466_6430_0000.nii.gz
# Renamed: C140466_6535.nii_0000.nii.gz to C140466_6535_0000.nii.gz
# Renamed: C140466_6549.nii_0000.nii.gz to C140466_6549_0000.nii.gz
# Renamed: C140466_6553.nii_0000.nii.gz to C140466_6553_0000.nii.gz
# Renamed: C140466_6640.nii_0000.nii.gz to C140466_6640_0000.nii.gz
# Renamed: C140466_6685.nii_0000.nii.gz to C140466_6685_0000.nii.gz
# Renamed: C140466_6724.nii_0000.nii.gz to C140466_6724_0000.nii.gz
# Renamed: C140466_6799.nii_0000.nii.gz to C140466_6799_0000.nii.gz
# Renamed: C140466_6888.nii_0000.nii.gz to C140466_6888_0000.nii.gz
# Renamed: C140466_6983.nii_0000.nii.gz to C140466_6983_0000.nii.gz
# Renamed: C140466_7056.nii_0000.nii.gz to C140466_7056_0000.nii.gz
# Renamed: C140466_7140.nii_0000.nii.gz to C140466_7140_0000.nii.gz
# Renamed: C140466_7238.nii_0000.nii.gz to C140466_7238_0000.nii.gz
# Renamed: C140466_7336.nii_0000.nii.gz to C140466_7336_0000.nii.gz
# Renamed: C140466_7418.nii_0000.nii.gz to C140466_7418_0000.nii.gz
# Renamed: C140466_7509.nii_0000.nii.gz to C140466_7509_0000.nii.gz
# Renamed: C140466_7588.nii_0000.nii.gz to C140466_7588_0000.nii.gz
# Renamed: C140466_7642.nii_0000.nii.gz to C140466_7642_0000.nii.gz
# Renamed: C140466_7797.nii_0000.nii.gz to C140466_7797_0000.nii.gz
# Renamed: C140466_7876.nii_0000.nii.gz to C140466_7876_0000.nii.gz
# Renamed: C140466_7981.nii_0000.nii.gz to C140466_7981_0000.nii.gz
# Renamed: C140466_8092.nii_0000.nii.gz to C140466_8092_0000.nii.gz
# Renamed: C140466_8253.nii_0000.nii.gz to C140466_8253_0000.nii.gz
# Renamed: C140466_8442.nii_0000.nii.gz to C140466_8442_0000.nii.gz
# Renamed: C140466_8659.nii_0000.nii.gz to C140466_8659_0000.nii.gz
# Renamed: C140466_8995.nii_0000.nii.gz to C140466_8995_0000.nii.gz
# Renamed: C140466_9450.nii_0000.nii.gz to C140466_9450_0000.nii.gz
# Renamed: C140466_9632.nii_0000.nii.gz to C140466_9632_0000.nii.gz
# Renamed: C146124_5182.nii_0000.nii.gz to C146124_5182_0000.nii.gz
# Renamed: C146124_5203.nii_0000.nii.gz to C146124_5203_0000.nii.gz
# Renamed: C154980_3286.nii_0000.nii.gz to C154980_3286_0000.nii.gz
# Renamed: C154980_3287.nii_0000.nii.gz to C154980_3287_0000.nii.gz
# Renamed: C154980_3357.nii_0000.nii.gz to C154980_3357_0000.nii.gz
# Renamed: C155103_734.nii_0000.nii.gz to C155103_734_0000.nii.gz
# Renamed: C15867_4687.nii_0000.nii.gz to C15867_4687_0000.nii.gz
# Renamed: C16482_1921.nii_0000.nii.gz to C16482_1921_0000.nii.gz
# Renamed: C16482_1943.nii_0000.nii.gz to C16482_1943_0000.nii.gz
# Renamed: C16851_471.nii_0000.nii.gz to C16851_471_0000.nii.gz
# Renamed: C16851_472.nii_0000.nii.gz to C16851_472_0000.nii.gz
# Renamed: C16974_1298.nii_0000.nii.gz to C16974_1298_0000.nii.gz
# Renamed: C17097_5867.nii_0000.nii.gz to C17097_5867_0000.nii.gz
# Renamed: C17835_128.nii_0000.nii.gz to C17835_128_0000.nii.gz
# Renamed: C18204_476.nii_0000.nii.gz to C18204_476_0000.nii.gz
# Renamed: C182409_6105.nii_0000.nii.gz to C182409_6105_0000.nii.gz
# Renamed: C182655_1817.nii_0000.nii.gz to C182655_1817_0000.nii.gz
# Renamed: C18327_2591.nii_0000.nii.gz to C18327_2591_0000.nii.gz
# Renamed: C18327_2593.nii_0000.nii.gz to C18327_2593_0000.nii.gz
# Renamed: C186714_2960.nii_0000.nii.gz to C186714_2960_0000.nii.gz
# Renamed: C186714_2964.nii_0000.nii.gz to C186714_2964_0000.nii.gz
# Renamed: C186960_4270.nii_0000.nii.gz to C186960_4270_0000.nii.gz
# Renamed: C187083_2808.nii_0000.nii.gz to C187083_2808_0000.nii.gz
# Renamed: C19065_6225.nii_0000.nii.gz to C19065_6225_0000.nii.gz
# Renamed: C19065_6259.nii_0000.nii.gz to C19065_6259_0000.nii.gz
# Renamed: C19188_4133.nii_0000.nii.gz to C19188_4133_0000.nii.gz
# Renamed: C19188_4138.nii_0000.nii.gz to C19188_4138_0000.nii.gz
# Renamed: C19557_428.nii_0000.nii.gz to C19557_428_0000.nii.gz
# Renamed: C19557_526.nii_0000.nii.gz to C19557_526_0000.nii.gz
# Renamed: C19557_610.nii_0000.nii.gz to C19557_610_0000.nii.gz
# Renamed: C19557_701.nii_0000.nii.gz to C19557_701_0000.nii.gz
# Renamed: C19557_743.nii_0000.nii.gz to C19557_743_0000.nii.gz
# Renamed: C19557_752.nii_0000.nii.gz to C19557_752_0000.nii.gz
# Renamed: C19680_165.nii_0000.nii.gz to C19680_165_0000.nii.gz
# Renamed: C19680_3997.nii_0000.nii.gz to C19680_3997_0000.nii.gz
# Renamed: C216111_3672.nii_0000.nii.gz to C216111_3672_0000.nii.gz
# Renamed: C216111_3673.nii_0000.nii.gz to C216111_3673_0000.nii.gz
# Renamed: C216234_5208.nii_0000.nii.gz to C216234_5208_0000.nii.gz
# Renamed: C22509_1468.nii_0000.nii.gz to C22509_1468_0000.nii.gz
# Renamed: C230871_5212.nii_0000.nii.gz to C230871_5212_0000.nii.gz
# Renamed: C231240_1517.nii_0000.nii.gz to C231240_1517_0000.nii.gz
# Renamed: C231240_1535.nii_0000.nii.gz to C231240_1535_0000.nii.gz
# Renamed: C2313384_2605.nii_0000.nii.gz to C2313384_2605_0000.nii.gz
# Renamed: C2313384_2839.nii_0000.nii.gz to C2313384_2839_0000.nii.gz
# Renamed: C2313384_4728.nii_0000.nii.gz to C2313384_4728_0000.nii.gz
# Renamed: C2313384_5863.nii_0000.nii.gz to C2313384_5863_0000.nii.gz
# Renamed: C2313384_5919.nii_0000.nii.gz to C2313384_5919_0000.nii.gz
# Renamed: C2313384_5967.nii_0000.nii.gz to C2313384_5967_0000.nii.gz
# Renamed: C2313384_5971.nii_0000.nii.gz to C2313384_5971_0000.nii.gz
# Renamed: C2313876_4898.nii_0000.nii.gz to C2313876_4898_0000.nii.gz
# Renamed: C2313876_4908.nii_0000.nii.gz to C2313876_4908_0000.nii.gz
# Renamed: C2313876_4912.nii_0000.nii.gz to C2313876_4912_0000.nii.gz
# Renamed: C2318181_4909.nii_0000.nii.gz to C2318181_4909_0000.nii.gz
# Renamed: C2318181_4935.nii_0000.nii.gz to C2318181_4935_0000.nii.gz
# Renamed: C2318181_4937.nii_0000.nii.gz to C2318181_4937_0000.nii.gz
# Renamed: C2321994_6090.nii_0000.nii.gz to C2321994_6090_0000.nii.gz
# Renamed: C2321994_6110.nii_0000.nii.gz to C2321994_6110_0000.nii.gz
# Renamed: C2334663_5455.nii_0000.nii.gz to C2334663_5455_0000.nii.gz
# Renamed: C2334663_5490.nii_0000.nii.gz to C2334663_5490_0000.nii.gz
# Renamed: C2334663_5566.nii_0000.nii.gz to C2334663_5566_0000.nii.gz
# Renamed: C2334663_5657.nii_0000.nii.gz to C2334663_5657_0000.nii.gz
# Renamed: C2334663_5743.nii_0000.nii.gz to C2334663_5743_0000.nii.gz
# Renamed: C2334663_5925.nii_0000.nii.gz to C2334663_5925_0000.nii.gz
# Renamed: C2334663_6114.nii_0000.nii.gz to C2334663_6114_0000.nii.gz
# Renamed: C2334663_6218.nii_0000.nii.gz to C2334663_6218_0000.nii.gz
# Renamed: C2334663_6275.nii_0000.nii.gz to C2334663_6275_0000.nii.gz
# Renamed: C2334663_6278.nii_0000.nii.gz to C2334663_6278_0000.nii.gz
# Renamed: C2334663_6366.nii_0000.nii.gz to C2334663_6366_0000.nii.gz
# Renamed: C2334663_6471.nii_0000.nii.gz to C2334663_6471_0000.nii.gz
# Renamed: C2334663_6632.nii_0000.nii.gz to C2334663_6632_0000.nii.gz
# Renamed: C2334663_6835.nii_0000.nii.gz to C2334663_6835_0000.nii.gz
# Renamed: C2334663_6996.nii_0000.nii.gz to C2334663_6996_0000.nii.gz
# Renamed: C2334786_831.nii_0000.nii.gz to C2334786_831_0000.nii.gz
# Renamed: C2334909_5305.nii_0000.nii.gz to C2334909_5305_0000.nii.gz
# Renamed: C2334909_5596.nii_0000.nii.gz to C2334909_5596_0000.nii.gz
# Renamed: C2334909_5795.nii_0000.nii.gz to C2334909_5795_0000.nii.gz
# Renamed: C2334909_5796.nii_0000.nii.gz to C2334909_5796_0000.nii.gz
# Renamed: C2335032_1093.nii_0000.nii.gz to C2335032_1093_0000.nii.gz
# Renamed: C2335155_925.nii_0000.nii.gz to C2335155_925_0000.nii.gz
# Renamed: C2345856_1115.nii_0000.nii.gz to C2345856_1115_0000.nii.gz
# Renamed: C2345856_1117.nii_0000.nii.gz to C2345856_1117_0000.nii.gz
# Renamed: C23493_3799.nii_0000.nii.gz to C23493_3799_0000.nii.gz
# Renamed: C2353605_828.nii_0000.nii.gz to C2353605_828_0000.nii.gz
# Renamed: C2353605_855.nii_0000.nii.gz to C2353605_855_0000.nii.gz
# Renamed: C2354097_2572.nii_0000.nii.gz to C2354097_2572_0000.nii.gz
# Renamed: C2354097_2574.nii_0000.nii.gz to C2354097_2574_0000.nii.gz
# Renamed: C2354097_2612.nii_0000.nii.gz to C2354097_2612_0000.nii.gz
# Renamed: C2354097_2656.nii_0000.nii.gz to C2354097_2656_0000.nii.gz
# Renamed: C2354097_2667.nii_0000.nii.gz to C2354097_2667_0000.nii.gz
# Renamed: C2354097_2737.nii_0000.nii.gz to C2354097_2737_0000.nii.gz
# Renamed: C2354097_2748.nii_0000.nii.gz to C2354097_2748_0000.nii.gz
# Renamed: C2354097_2842.nii_0000.nii.gz to C2354097_2842_0000.nii.gz
# Renamed: C2354097_2950.nii_0000.nii.gz to C2354097_2950_0000.nii.gz
# Renamed: C2354097_3076.nii_0000.nii.gz to C2354097_3076_0000.nii.gz
# Renamed: C2354097_3213.nii_0000.nii.gz to C2354097_3213_0000.nii.gz
# Renamed: C2354097_3402.nii_0000.nii.gz to C2354097_3402_0000.nii.gz
# Renamed: C2354097_3591.nii_0000.nii.gz to C2354097_3591_0000.nii.gz
# Renamed: C2354097_3769.nii_0000.nii.gz to C2354097_3769_0000.nii.gz
# Renamed: C2354097_3955.nii_0000.nii.gz to C2354097_3955_0000.nii.gz
# Renamed: C2354097_4133.nii_0000.nii.gz to C2354097_4133_0000.nii.gz
# Renamed: C2354097_4231.nii_0000.nii.gz to C2354097_4231_0000.nii.gz
# Renamed: C2354097_4403.nii_0000.nii.gz to C2354097_4403_0000.nii.gz
# Renamed: C2354097_4511.nii_0000.nii.gz to C2354097_4511_0000.nii.gz
# Renamed: C2354097_4547.nii_0000.nii.gz to C2354097_4547_0000.nii.gz
# Renamed: C2354097_4552.nii_0000.nii.gz to C2354097_4552_0000.nii.gz
# Renamed: C2354097_4657.nii_0000.nii.gz to C2354097_4657_0000.nii.gz
# Renamed: C2354097_4789.nii_0000.nii.gz to C2354097_4789_0000.nii.gz
# Renamed: C2354097_4880.nii_0000.nii.gz to C2354097_4880_0000.nii.gz
# Renamed: C2354097_5028.nii_0000.nii.gz to C2354097_5028_0000.nii.gz
# Renamed: C2354097_5286.nii_0000.nii.gz to C2354097_5286_0000.nii.gz
# Renamed: C2354097_5497.nii_0000.nii.gz to C2354097_5497_0000.nii.gz
# Renamed: C2354097_5646.nii_0000.nii.gz to C2354097_5646_0000.nii.gz
# Renamed: C2354097_5853.nii_0000.nii.gz to C2354097_5853_0000.nii.gz
# Renamed: C2354097_6000.nii_0000.nii.gz to C2354097_6000_0000.nii.gz
# Renamed: C23616_4257.nii_0000.nii.gz to C23616_4257_0000.nii.gz
# Renamed: C23739_4382.nii_0000.nii.gz to C23739_4382_0000.nii.gz
# Renamed: C23739_4391.nii_0000.nii.gz to C23739_4391_0000.nii.gz
# Renamed: C2380419_332.nii_0000.nii.gz to C2380419_332_0000.nii.gz
# Renamed: C2380788_1318.nii_0000.nii.gz to C2380788_1318_0000.nii.gz
# Renamed: C2380788_1430.nii_0000.nii.gz to C2380788_1430_0000.nii.gz
# Renamed: C2380788_1534.nii_0000.nii.gz to C2380788_1534_0000.nii.gz
# Renamed: C2380788_1842.nii_0000.nii.gz to C2380788_1842_0000.nii.gz
# Renamed: C2380788_2099.nii_0000.nii.gz to C2380788_2099_0000.nii.gz
# Renamed: C2380788_2171.nii_0000.nii.gz to C2380788_2171_0000.nii.gz
# Renamed: C2380788_2176.nii_0000.nii.gz to C2380788_2176_0000.nii.gz
# Renamed: C2380788_2386.nii_0000.nii.gz to C2380788_2386_0000.nii.gz
# Renamed: C23862_3469.nii_0000.nii.gz to C23862_3469_0000.nii.gz
# Renamed: C2409078_4231.nii_0000.nii.gz to C2409078_4231_0000.nii.gz
# Renamed: C2421501_4203.nii_0000.nii.gz to C2421501_4203_0000.nii.gz
# Renamed: C2421501_4205.nii_0000.nii.gz to C2421501_4205_0000.nii.gz
# Renamed: C2421747_4560.nii_0000.nii.gz to C2421747_4560_0000.nii.gz
# Renamed: C242679_4253.nii_0000.nii.gz to C242679_4253_0000.nii.gz
# Renamed: C243540_529.nii_0000.nii.gz to C243540_529_0000.nii.gz
# Renamed: C243540_557.nii_0000.nii.gz to C243540_557_0000.nii.gz
# Renamed: C243540_608.nii_0000.nii.gz to C243540_608_0000.nii.gz
# Renamed: C243540_635.nii_0000.nii.gz to C243540_635_0000.nii.gz
# Renamed: C243540_659.nii_0000.nii.gz to C243540_659_0000.nii.gz
# Renamed: C2439951_6222.nii_0000.nii.gz to C2439951_6222_0000.nii.gz
# Renamed: C244032_5480.nii_0000.nii.gz to C244032_5480_0000.nii.gz
# Renamed: C244032_5519.nii_0000.nii.gz to C244032_5519_0000.nii.gz
# Renamed: C245631_1065.nii_0000.nii.gz to C245631_1065_0000.nii.gz
# Renamed: C2466519_4104.nii_0000.nii.gz to C2466519_4104_0000.nii.gz
# Renamed: C2479803_6042.nii_0000.nii.gz to C2479803_6042_0000.nii.gz
# Renamed: C24969_174.nii_0000.nii.gz to C24969_174_0000.nii.gz
# Renamed: C24969_2288.nii_0000.nii.gz to C24969_2288_0000.nii.gz
# Renamed: C24969_2337.nii_0000.nii.gz to C24969_2337_0000.nii.gz
# Renamed: C24969_2456.nii_0000.nii.gz to C24969_2456_0000.nii.gz
# Renamed: C24969_2570.nii_0000.nii.gz to C24969_2570_0000.nii.gz
# Renamed: C24969_2611.nii_0000.nii.gz to C24969_2611_0000.nii.gz
# Renamed: C24969_2616.nii_0000.nii.gz to C24969_2616_0000.nii.gz
# Renamed: C24969_410.nii_0000.nii.gz to C24969_410_0000.nii.gz
# Renamed: C24969_806.nii_0000.nii.gz to C24969_806_0000.nii.gz
# Renamed: C2498130_1481.nii_0000.nii.gz to C2498130_1481_0000.nii.gz
# Renamed: C2501082_2501.nii_0000.nii.gz to C2501082_2501_0000.nii.gz
# Renamed: C2501328_2656.nii_0000.nii.gz to C2501328_2656_0000.nii.gz
# Renamed: C2536629_5080.nii_0000.nii.gz to C2536629_5080_0000.nii.gz
# Renamed: C2554341_3636.nii_0000.nii.gz to C2554341_3636_0000.nii.gz
# Renamed: C2555325_3749.nii_0000.nii.gz to C2555325_3749_0000.nii.gz
# Renamed: C2555448_1004.nii_0000.nii.gz to C2555448_1004_0000.nii.gz
# Renamed: C2555817_1376.nii_0000.nii.gz to C2555817_1376_0000.nii.gz
# Renamed: C2556432_5570.nii_0000.nii.gz to C2556432_5570_0000.nii.gz
# Renamed: C25584_1858.nii_0000.nii.gz to C25584_1858_0000.nii.gz
# Renamed: C25584_2200.nii_0000.nii.gz to C25584_2200_0000.nii.gz
# Renamed: C25584_2437.nii_0000.nii.gz to C25584_2437_0000.nii.gz
# Renamed: C25584_2472.nii_0000.nii.gz to C25584_2472_0000.nii.gz
# Renamed: C2563689_6298.nii_0000.nii.gz to C2563689_6298_0000.nii.gz
# Renamed: C2563689_6662.nii_0000.nii.gz to C2563689_6662_0000.nii.gz
# Renamed: C2563689_6767.nii_0000.nii.gz to C2563689_6767_0000.nii.gz
# Renamed: C2568486_6556.nii_0000.nii.gz to C2568486_6556_0000.nii.gz
# Renamed: C2568486_6557.nii_0000.nii.gz to C2568486_6557_0000.nii.gz
# Renamed: C2568978_3518.nii_0000.nii.gz to C2568978_3518_0000.nii.gz
# Renamed: C2568978_3561.nii_0000.nii.gz to C2568978_3561_0000.nii.gz
# Renamed: C2568978_3890.nii_0000.nii.gz to C2568978_3890_0000.nii.gz
# Renamed: C2568978_4135.nii_0000.nii.gz to C2568978_4135_0000.nii.gz
# Renamed: C2568978_4176.nii_0000.nii.gz to C2568978_4176_0000.nii.gz
# Renamed: C2568978_4267.nii_0000.nii.gz to C2568978_4267_0000.nii.gz
# Renamed: C2572299_5047.nii_0000.nii.gz to C2572299_5047_0000.nii.gz
# Renamed: C2578326_3834.nii_0000.nii.gz to C2578326_3834_0000.nii.gz
# Renamed: C2578326_3838.nii_0000.nii.gz to C2578326_3838_0000.nii.gz
# Renamed: C2587797_4952.nii_0000.nii.gz to C2587797_4952_0000.nii.gz
# Renamed: C2587797_4953.nii_0000.nii.gz to C2587797_4953_0000.nii.gz
# Renamed: C25953_6141.nii_0000.nii.gz to C25953_6141_0000.nii.gz
# Renamed: C25953_6142.nii_0000.nii.gz to C25953_6142_0000.nii.gz
# Renamed: C2617194_5332.nii_0000.nii.gz to C2617194_5332_0000.nii.gz
# Renamed: C2617194_5333.nii_0000.nii.gz to C2617194_5333_0000.nii.gz
# Renamed: C2617194_5335.nii_0000.nii.gz to C2617194_5335_0000.nii.gz
# Renamed: C2617194_5351.nii_0000.nii.gz to C2617194_5351_0000.nii.gz
# Renamed: C2617194_5356.nii_0000.nii.gz to C2617194_5356_0000.nii.gz
# Renamed: C262605_777.nii_0000.nii.gz to C262605_777_0000.nii.gz
# Renamed: C26322_2454.nii_0000.nii.gz to C26322_2454_0000.nii.gz
# Renamed: C2647575_5603.nii_0000.nii.gz to C2647575_5603_0000.nii.gz
# Renamed: C2647698_3341.nii_0000.nii.gz to C2647698_3341_0000.nii.gz
# Renamed: C2647698_3392.nii_0000.nii.gz to C2647698_3392_0000.nii.gz
# Renamed: C2647698_3509.nii_0000.nii.gz to C2647698_3509_0000.nii.gz
# Renamed: C2647698_3650.nii_0000.nii.gz to C2647698_3650_0000.nii.gz
# Renamed: C2647698_3829.nii_0000.nii.gz to C2647698_3829_0000.nii.gz
# Renamed: C2647698_4091.nii_0000.nii.gz to C2647698_4091_0000.nii.gz
# Renamed: C2647698_4174.nii_0000.nii.gz to C2647698_4174_0000.nii.gz
# Renamed: C2647698_4216.nii_0000.nii.gz to C2647698_4216_0000.nii.gz
# Renamed: C2647698_4222.nii_0000.nii.gz to C2647698_4222_0000.nii.gz
# Renamed: C2647698_4226.nii_0000.nii.gz to C2647698_4226_0000.nii.gz
# Renamed: C2647698_4258.nii_0000.nii.gz to C2647698_4258_0000.nii.gz
# Renamed: C2647698_4341.nii_0000.nii.gz to C2647698_4341_0000.nii.gz
# Renamed: C2647698_4455.nii_0000.nii.gz to C2647698_4455_0000.nii.gz
# Renamed: C2647698_4894.nii_0000.nii.gz to C2647698_4894_0000.nii.gz
# Renamed: C2653971_2885.nii_0000.nii.gz to C2653971_2885_0000.nii.gz
# Renamed: C2653971_4056.nii_0000.nii.gz to C2653971_4056_0000.nii.gz
# Renamed: C2653971_7969.nii_0000.nii.gz to C2653971_7969_0000.nii.gz
# Renamed: C2653971_8010.nii_0000.nii.gz to C2653971_8010_0000.nii.gz
# Renamed: C2653971_8016.nii_0000.nii.gz to C2653971_8016_0000.nii.gz
# Renamed: C2654217_2444.nii_0000.nii.gz to C2654217_2444_0000.nii.gz
# Renamed: C2668362_4088.nii_0000.nii.gz to C2668362_4088_0000.nii.gz
# Renamed: C2688165_2277.nii_0000.nii.gz to C2688165_2277_0000.nii.gz
# Renamed: C2697882_5452.nii_0000.nii.gz to C2697882_5452_0000.nii.gz
# Renamed: C2697882_5456.nii_0000.nii.gz to C2697882_5456_0000.nii.gz
# Renamed: C2697882_5457.nii_0000.nii.gz to C2697882_5457_0000.nii.gz
# Renamed: C270477_4623.nii_0000.nii.gz to C270477_4623_0000.nii.gz
# Renamed: C270477_4716.nii_0000.nii.gz to C270477_4716_0000.nii.gz
# Renamed: C270477_4768.nii_0000.nii.gz to C270477_4768_0000.nii.gz
# Renamed: C2720022_2682.nii_0000.nii.gz to C2720022_2682_0000.nii.gz
# Renamed: C2720022_2708.nii_0000.nii.gz to C2720022_2708_0000.nii.gz
# Renamed: C2720022_2710.nii_0000.nii.gz to C2720022_2710_0000.nii.gz
# Renamed: C2734290_1788.nii_0000.nii.gz to C2734290_1788_0000.nii.gz
# Renamed: C2734290_1791.nii_0000.nii.gz to C2734290_1791_0000.nii.gz
# Renamed: C2734536_1013.nii_0000.nii.gz to C2734536_1013_0000.nii.gz
# Renamed: C2734536_996.nii_0000.nii.gz to C2734536_996_0000.nii.gz
# Renamed: C2734782_3539.nii_0000.nii.gz to C2734782_3539_0000.nii.gz
# Renamed: C2734782_3540.nii_0000.nii.gz to C2734782_3540_0000.nii.gz
# Renamed: C2735028_1601.nii_0000.nii.gz to C2735028_1601_0000.nii.gz
# Renamed: C2760612_1358.nii_0000.nii.gz to C2760612_1358_0000.nii.gz
# Renamed: C2760858_2075.nii_0000.nii.gz to C2760858_2075_0000.nii.gz
# Renamed: C2760858_2077.nii_0000.nii.gz to C2760858_2077_0000.nii.gz
# Renamed: C27798_4452.nii_0000.nii.gz to C27798_4452_0000.nii.gz
# Renamed: C2795544_1275.nii_0000.nii.gz to C2795544_1275_0000.nii.gz
# Renamed: C2795544_1315.nii_0000.nii.gz to C2795544_1315_0000.nii.gz
# Renamed: C2795544_1372.nii_0000.nii.gz to C2795544_1372_0000.nii.gz
# Renamed: C2819037_694.nii_0000.nii.gz to C2819037_694_0000.nii.gz
# Renamed: C2819652_3450.nii_0000.nii.gz to C2819652_3450_0000.nii.gz
# Renamed: C2819652_3463.nii_0000.nii.gz to C2819652_3463_0000.nii.gz
# Renamed: C2819775_2760.nii_0000.nii.gz to C2819775_2760_0000.nii.gz
# Renamed: C2819775_2795.nii_0000.nii.gz to C2819775_2795_0000.nii.gz
# Renamed: C2819775_2824.nii_0000.nii.gz to C2819775_2824_0000.nii.gz
# Renamed: C2819898_5077.nii_0000.nii.gz to C2819898_5077_0000.nii.gz
# Renamed: C2819898_5187.nii_0000.nii.gz to C2819898_5187_0000.nii.gz
# Renamed: C2819898_5205.nii_0000.nii.gz to C2819898_5205_0000.nii.gz
# Renamed: C2820021_5746.nii_0000.nii.gz to C2820021_5746_0000.nii.gz
# Renamed: C2820021_5770.nii_0000.nii.gz to C2820021_5770_0000.nii.gz
# Renamed: C2832936_5937.nii_0000.nii.gz to C2832936_5937_0000.nii.gz
# Renamed: C2832936_5949.nii_0000.nii.gz to C2832936_5949_0000.nii.gz
# Renamed: C2832936_5974.nii_0000.nii.gz to C2832936_5974_0000.nii.gz
# Renamed: C2837733_4051.nii_0000.nii.gz to C2837733_4051_0000.nii.gz
# Renamed: C2837733_4052.nii_0000.nii.gz to C2837733_4052_0000.nii.gz
# Renamed: C2839701_3377.nii_0000.nii.gz to C2839701_3377_0000.nii.gz
# Renamed: C2839701_3437.nii_0000.nii.gz to C2839701_3437_0000.nii.gz
# Renamed: C28413_1017.nii_0000.nii.gz to C28413_1017_0000.nii.gz
# Renamed: C28413_1125.nii_0000.nii.gz to C28413_1125_0000.nii.gz
# Renamed: C28413_1451.nii_0000.nii.gz to C28413_1451_0000.nii.gz
# Renamed: C28413_1654.nii_0000.nii.gz to C28413_1654_0000.nii.gz
# Renamed: C28413_1783.nii_0000.nii.gz to C28413_1783_0000.nii.gz
# Renamed: C28413_1997.nii_0000.nii.gz to C28413_1997_0000.nii.gz
# Renamed: C28413_2207.nii_0000.nii.gz to C28413_2207_0000.nii.gz
# Renamed: C28413_2301.nii_0000.nii.gz to C28413_2301_0000.nii.gz
# Renamed: C28413_2420.nii_0000.nii.gz to C28413_2420_0000.nii.gz
# Renamed: C28413_2508.nii_0000.nii.gz to C28413_2508_0000.nii.gz
# Renamed: C28413_253.nii_0000.nii.gz to C28413_253_0000.nii.gz
# Renamed: C28413_2620.nii_0000.nii.gz to C28413_2620_0000.nii.gz
# Renamed: C28413_2732.nii_0000.nii.gz to C28413_2732_0000.nii.gz
# Renamed: C28413_2837.nii_0000.nii.gz to C28413_2837_0000.nii.gz
# Renamed: C28413_2931.nii_0000.nii.gz to C28413_2931_0000.nii.gz
# Renamed: C28413_3026.nii_0000.nii.gz to C28413_3026_0000.nii.gz
# Renamed: C28413_3127.nii_0000.nii.gz to C28413_3127_0000.nii.gz
# Renamed: C28413_3218.nii_0000.nii.gz to C28413_3218_0000.nii.gz
# Renamed: C28413_3309.nii_0000.nii.gz to C28413_3309_0000.nii.gz
# Renamed: C28413_3393.nii_0000.nii.gz to C28413_3393_0000.nii.gz
# Renamed: C28413_3488.nii_0000.nii.gz to C28413_3488_0000.nii.gz
# Renamed: C28413_3673.nii_0000.nii.gz to C28413_3673_0000.nii.gz
# Renamed: C28413_3848.nii_0000.nii.gz to C28413_3848_0000.nii.gz
# Renamed: C28413_4079.nii_0000.nii.gz to C28413_4079_0000.nii.gz
# Renamed: C28413_4173.nii_0000.nii.gz to C28413_4173_0000.nii.gz
# Renamed: C28413_4212.nii_0000.nii.gz to C28413_4212_0000.nii.gz
# Renamed: C28413_4218.nii_0000.nii.gz to C28413_4218_0000.nii.gz
# Renamed: C28413_4309.nii_0000.nii.gz to C28413_4309_0000.nii.gz
# Renamed: C28413_4518.nii_0000.nii.gz to C28413_4518_0000.nii.gz
# Renamed: C28413_4740.nii_0000.nii.gz to C28413_4740_0000.nii.gz
# Renamed: C28413_5147.nii_0000.nii.gz to C28413_5147_0000.nii.gz
# Renamed: C28413_5322.nii_0000.nii.gz to C28413_5322_0000.nii.gz
# Renamed: C28413_5679.nii_0000.nii.gz to C28413_5679_0000.nii.gz
# Renamed: C28413_599.nii_0000.nii.gz to C28413_599_0000.nii.gz
# Renamed: C28413_6058.nii_0000.nii.gz to C28413_6058_0000.nii.gz
# Renamed: C28413_6423.nii_0000.nii.gz to C28413_6423_0000.nii.gz
# Renamed: C28413_6809.nii_0000.nii.gz to C28413_6809_0000.nii.gz
# Renamed: C28413_731.nii_0000.nii.gz to C28413_731_0000.nii.gz
# Renamed: C28413_7509.nii_0000.nii.gz to C28413_7509_0000.nii.gz
# Renamed: C28413_8209.nii_0000.nii.gz to C28413_8209_0000.nii.gz
# Renamed: C28413_844.nii_0000.nii.gz to C28413_844_0000.nii.gz
# Renamed: C28413_946.nii_0000.nii.gz to C28413_946_0000.nii.gz
# Renamed: C28536_834.nii_0000.nii.gz to C28536_834_0000.nii.gz
# Renamed: C2855076_5608.nii_0000.nii.gz to C2855076_5608_0000.nii.gz
# Renamed: C2855076_5672.nii_0000.nii.gz to C2855076_5672_0000.nii.gz
# Renamed: C2855076_5854.nii_0000.nii.gz to C2855076_5854_0000.nii.gz
# Renamed: C2855076_6029.nii_0000.nii.gz to C2855076_6029_0000.nii.gz
# Renamed: C2855076_6290.nii_0000.nii.gz to C2855076_6290_0000.nii.gz
# Renamed: C2855076_6307.nii_0000.nii.gz to C2855076_6307_0000.nii.gz
# Renamed: C2855076_6342.nii_0000.nii.gz to C2855076_6342_0000.nii.gz
# Renamed: C2855076_6432.nii_0000.nii.gz to C2855076_6432_0000.nii.gz
# Renamed: C2855076_6535.nii_0000.nii.gz to C2855076_6535_0000.nii.gz
# Renamed: C2859135_2167.nii_0000.nii.gz to C2859135_2167_0000.nii.gz
# Renamed: C2859135_2189.nii_0000.nii.gz to C2859135_2189_0000.nii.gz
# Renamed: C2859135_2192.nii_0000.nii.gz to C2859135_2192_0000.nii.gz
# Renamed: C2864670_2161.nii_0000.nii.gz to C2864670_2161_0000.nii.gz
# Renamed: C28659_4266.nii_0000.nii.gz to C28659_4266_0000.nii.gz
# Renamed: C28659_4287.nii_0000.nii.gz to C28659_4287_0000.nii.gz
# Renamed: C2879184_1137.nii_0000.nii.gz to C2879184_1137_0000.nii.gz
# Renamed: C2879184_1507.nii_0000.nii.gz to C2879184_1507_0000.nii.gz
# Renamed: C2879184_1696.nii_0000.nii.gz to C2879184_1696_0000.nii.gz
# Renamed: C2879184_1885.nii_0000.nii.gz to C2879184_1885_0000.nii.gz
# Renamed: C2879184_2061.nii_0000.nii.gz to C2879184_2061_0000.nii.gz
# Renamed: C2879184_2469.nii_0000.nii.gz to C2879184_2469_0000.nii.gz
# Renamed: C2879184_2677.nii_0000.nii.gz to C2879184_2677_0000.nii.gz
# Renamed: C2879184_2782.nii_0000.nii.gz to C2879184_2782_0000.nii.gz
# Renamed: C2879184_2881.nii_0000.nii.gz to C2879184_2881_0000.nii.gz
# Renamed: C2879184_2991.nii_0000.nii.gz to C2879184_2991_0000.nii.gz
# Renamed: C2879184_3267.nii_0000.nii.gz to C2879184_3267_0000.nii.gz
# Renamed: C2879184_3368.nii_0000.nii.gz to C2879184_3368_0000.nii.gz
# Renamed: C2879184_3453.nii_0000.nii.gz to C2879184_3453_0000.nii.gz
# Renamed: C2879184_3532.nii_0000.nii.gz to C2879184_3532_0000.nii.gz
# Renamed: C2879184_3629.nii_0000.nii.gz to C2879184_3629_0000.nii.gz
# Renamed: C2879184_3869.nii_0000.nii.gz to C2879184_3869_0000.nii.gz
# Renamed: C2879184_4006.nii_0000.nii.gz to C2879184_4006_0000.nii.gz
# Renamed: C2879184_4096.nii_0000.nii.gz to C2879184_4096_0000.nii.gz
# Renamed: C2879184_603.nii_0000.nii.gz to C2879184_603_0000.nii.gz
# Renamed: C2879184_820.nii_0000.nii.gz to C2879184_820_0000.nii.gz
# Renamed: C2879184_948.nii_0000.nii.gz to C2879184_948_0000.nii.gz
# Renamed: C288681_3795.nii_0000.nii.gz to C288681_3795_0000.nii.gz
# Renamed: C29151_647.nii_0000.nii.gz to C29151_647_0000.nii.gz
# Renamed: C29397_3353.nii_0000.nii.gz to C29397_3353_0000.nii.gz
# Renamed: C29520_1072.nii_0000.nii.gz to C29520_1072_0000.nii.gz
# Renamed: C311067_4165.nii_0000.nii.gz to C311067_4165_0000.nii.gz
# Renamed: C311067_4181.nii_0000.nii.gz to C311067_4181_0000.nii.gz
# Renamed: C311190_4621.nii_0000.nii.gz to C311190_4621_0000.nii.gz
# Renamed: C311190_4629.nii_0000.nii.gz to C311190_4629_0000.nii.gz
# Renamed: C311190_4633.nii_0000.nii.gz to C311190_4633_0000.nii.gz
# Renamed: C311436_4510.nii_0000.nii.gz to C311436_4510_0000.nii.gz
# Renamed: C311559_7148.nii_0000.nii.gz to C311559_7148_0000.nii.gz
# Renamed: C311559_7149.nii_0000.nii.gz to C311559_7149_0000.nii.gz
# Renamed: C313035_5196.nii_0000.nii.gz to C313035_5196_0000.nii.gz
# Renamed: C3153843_1540.nii_0000.nii.gz to C3153843_1540_0000.nii.gz
# Renamed: C3156795_1803.nii_0000.nii.gz to C3156795_1803_0000.nii.gz
# Renamed: C3171063_2485.nii_0000.nii.gz to C3171063_2485_0000.nii.gz
# Renamed: C3171186_6572.nii_0000.nii.gz to C3171186_6572_0000.nii.gz
# Renamed: C3185577_4254.nii_0000.nii.gz to C3185577_4254_0000.nii.gz
# Renamed: C3185577_4255.nii_0000.nii.gz to C3185577_4255_0000.nii.gz
# Renamed: C3208332_3827.nii_0000.nii.gz to C3208332_3827_0000.nii.gz
# Renamed: C3236130_2478.nii_0000.nii.gz to C3236130_2478_0000.nii.gz
# Renamed: C324351_1569.nii_0000.nii.gz to C324351_1569_0000.nii.gz
# Renamed: C324351_1609.nii_0000.nii.gz to C324351_1609_0000.nii.gz
# Renamed: C324351_1653.nii_0000.nii.gz to C324351_1653_0000.nii.gz
# Renamed: C324351_1878.nii_0000.nii.gz to C324351_1878_0000.nii.gz
# Renamed: C324351_2072.nii_0000.nii.gz to C324351_2072_0000.nii.gz
# Renamed: C324351_2164.nii_0000.nii.gz to C324351_2164_0000.nii.gz
# Renamed: C324351_2484.nii_0000.nii.gz to C324351_2484_0000.nii.gz
# Renamed: C324351_2745.nii_0000.nii.gz to C324351_2745_0000.nii.gz
# Renamed: C324351_3167.nii_0000.nii.gz to C324351_3167_0000.nii.gz
# Renamed: C324351_3363.nii_0000.nii.gz to C324351_3363_0000.nii.gz
# Renamed: C324351_3391.nii_0000.nii.gz to C324351_3391_0000.nii.gz
# Renamed: C324351_3529.nii_0000.nii.gz to C324351_3529_0000.nii.gz
# Renamed: C324351_3532.nii_0000.nii.gz to C324351_3532_0000.nii.gz
# Renamed: C324351_3818.nii_0000.nii.gz to C324351_3818_0000.nii.gz
# Renamed: C324351_4157.nii_0000.nii.gz to C324351_4157_0000.nii.gz
# Renamed: C324351_4652.nii_0000.nii.gz to C324351_4652_0000.nii.gz
# Renamed: C324351_5530.nii_0000.nii.gz to C324351_5530_0000.nii.gz
# Renamed: C324351_5882.nii_0000.nii.gz to C324351_5882_0000.nii.gz
# Renamed: C324597_3154.nii_0000.nii.gz to C324597_3154_0000.nii.gz
# Renamed: C324597_4128.nii_0000.nii.gz to C324597_4128_0000.nii.gz
# Renamed: C324597_4288.nii_0000.nii.gz to C324597_4288_0000.nii.gz
# Renamed: C324597_4305.nii_0000.nii.gz to C324597_4305_0000.nii.gz
# Renamed: C324597_4310.nii_0000.nii.gz to C324597_4310_0000.nii.gz
# Renamed: C324597_4375.nii_0000.nii.gz to C324597_4375_0000.nii.gz
# Renamed: C324597_4505.nii_0000.nii.gz to C324597_4505_0000.nii.gz
# Renamed: C324597_4597.nii_0000.nii.gz to C324597_4597_0000.nii.gz
# Renamed: C324597_4690.nii_0000.nii.gz to C324597_4690_0000.nii.gz
# Renamed: C324597_4816.nii_0000.nii.gz to C324597_4816_0000.nii.gz
# Renamed: C324597_4940.nii_0000.nii.gz to C324597_4940_0000.nii.gz
# Renamed: C324597_5171.nii_0000.nii.gz to C324597_5171_0000.nii.gz
# Renamed: C324597_5325.nii_0000.nii.gz to C324597_5325_0000.nii.gz
# Renamed: C324597_5503.nii_0000.nii.gz to C324597_5503_0000.nii.gz
# Renamed: C324597_5734.nii_0000.nii.gz to C324597_5734_0000.nii.gz
# Renamed: C324597_5954.nii_0000.nii.gz to C324597_5954_0000.nii.gz
# Renamed: C324597_6084.nii_0000.nii.gz to C324597_6084_0000.nii.gz
# Renamed: C324597_6311.nii_0000.nii.gz to C324597_6311_0000.nii.gz
# Renamed: C324597_6559.nii_0000.nii.gz to C324597_6559_0000.nii.gz
# Renamed: C324597_6917.nii_0000.nii.gz to C324597_6917_0000.nii.gz
# Renamed: C324597_726.nii_0000.nii.gz to C324597_726_0000.nii.gz
# Renamed: C3301689_1507.nii_0000.nii.gz to C3301689_1507_0000.nii.gz
# Renamed: C3351750_1376.nii_0000.nii.gz to C3351750_1376_0000.nii.gz
# Renamed: C3351750_1378.nii_0000.nii.gz to C3351750_1378_0000.nii.gz
# Renamed: C3365895_1167.nii_0000.nii.gz to C3365895_1167_0000.nii.gz
# Renamed: C33825_7936.nii_0000.nii.gz to C33825_7936_0000.nii.gz
# ...
# Renamed: C805896_6351.nii_0000.nii.gz to C805896_6351_0000.nii.gz
# Renamed: C806019_207.nii_0000.nii.gz to C806019_207_0000.nii.gz
# Renamed: C808110_3763.nii_0000.nii.gz to C808110_3763_0000.nii.gz
# Renamed: C808233_1026.nii_0000.nii.gz to C808233_1026_0000.nii.gz
# Renamed: C808233_1037.nii_0000.nii.gz to C808233_1037_0000.nii.gz
# Renamed: C808971_2746.nii_0000.nii.gz to C808971_2746_0000.nii.gz
# Renamed: C808971_4215.nii_0000.nii.gz to C808971_4215_0000.nii.gz
# Renamed: C808971_4273.nii_0000.nii.gz to C808971_4273_0000.nii.gz
# Renamed: C808971_4397.nii_0000.nii.gz to C808971_4397_0000.nii.gz
# Renamed: C808971_4474.nii_0000.nii.gz to C808971_4474_0000.nii.gz
# Renamed: C808971_4492.nii_0000.nii.gz to C808971_4492_0000.nii.gz
# Renamed: C808971_4496.nii_0000.nii.gz to C808971_4496_0000.nii.gz
# Renamed: C808971_4589.nii_0000.nii.gz to C808971_4589_0000.nii.gz
# Renamed: C808971_4733.nii_0000.nii.gz to C808971_4733_0000.nii.gz
# Renamed: C808971_4908.nii_0000.nii.gz to C808971_4908_0000.nii.gz
# Renamed: C808971_5118.nii_0000.nii.gz to C808971_5118_0000.nii.gz
# Renamed: C808971_5296.nii_0000.nii.gz to C808971_5296_0000.nii.gz
# Renamed: C808971_5660.nii_0000.nii.gz to C808971_5660_0000.nii.gz
# Renamed: C808971_6182.nii_0000.nii.gz to C808971_6182_0000.nii.gz
# Renamed: C809340_485.nii_0000.nii.gz to C809340_485_0000.nii.gz
# Renamed: C809340_498.nii_0000.nii.gz to C809340_498_0000.nii.gz
# Renamed: C818688_1610.nii_0000.nii.gz to C818688_1610_0000.nii.gz
# Renamed: C818811_4330.nii_0000.nii.gz to C818811_4330_0000.nii.gz
# Renamed: C818811_4341.nii_0000.nii.gz to C818811_4341_0000.nii.gz
# Renamed: C818811_4366.nii_0000.nii.gz to C818811_4366_0000.nii.gz
# Renamed: C829266_978.nii_0000.nii.gz to C829266_978_0000.nii.gz
# Renamed: C829512_4931.nii_0000.nii.gz to C829512_4931_0000.nii.gz
# Renamed: C831726_260.nii_0000.nii.gz to C831726_260_0000.nii.gz
# Renamed: C831726_298.nii_0000.nii.gz to C831726_298_0000.nii.gz
# Renamed: C831849_1327.nii_0000.nii.gz to C831849_1327_0000.nii.gz
# Renamed: C831849_1338.nii_0000.nii.gz to C831849_1338_0000.nii.gz
# Renamed: C83271_376.nii_0000.nii.gz to C83271_376_0000.nii.gz
# Renamed: C83271_378.nii_0000.nii.gz to C83271_378_0000.nii.gz
# Renamed: C83640_1196.nii_0000.nii.gz to C83640_1196_0000.nii.gz
# Renamed: C83640_1561.nii_0000.nii.gz to C83640_1561_0000.nii.gz
# Renamed: C83640_1973.nii_0000.nii.gz to C83640_1973_0000.nii.gz
# Renamed: C83640_2336.nii_0000.nii.gz to C83640_2336_0000.nii.gz
# Renamed: C83640_3058.nii_0000.nii.gz to C83640_3058_0000.nii.gz
# Renamed: C83640_3099.nii_0000.nii.gz to C83640_3099_0000.nii.gz
# Renamed: C83640_868.nii_0000.nii.gz to C83640_868_0000.nii.gz
# Renamed: C83640_980.nii_0000.nii.gz to C83640_980_0000.nii.gz
# Renamed: C836892_1969.nii_0000.nii.gz to C836892_1969_0000.nii.gz
# Renamed: C836892_2709.nii_0000.nii.gz to C836892_2709_0000.nii.gz
# Renamed: C836892_3255.nii_0000.nii.gz to C836892_3255_0000.nii.gz
# Renamed: C836892_3352.nii_0000.nii.gz to C836892_3352_0000.nii.gz
# Renamed: C836892_3437.nii_0000.nii.gz to C836892_3437_0000.nii.gz
# Renamed: C836892_3508.nii_0000.nii.gz to C836892_3508_0000.nii.gz
# Renamed: C836892_3513.nii_0000.nii.gz to C836892_3513_0000.nii.gz
# Renamed: C836892_3654.nii_0000.nii.gz to C836892_3654_0000.nii.gz
# Renamed: C836892_3815.nii_0000.nii.gz to C836892_3815_0000.nii.gz
# Renamed: C836892_384.nii_0000.nii.gz to C836892_384_0000.nii.gz
# Renamed: C836892_3920.nii_0000.nii.gz to C836892_3920_0000.nii.gz
# Renamed: C836892_4150.nii_0000.nii.gz to C836892_4150_0000.nii.gz
# Renamed: C836892_4255.nii_0000.nii.gz to C836892_4255_0000.nii.gz
# Renamed: C836892_4381.nii_0000.nii.gz to C836892_4381_0000.nii.gz
# Renamed: C836892_4479.nii_0000.nii.gz to C836892_4479_0000.nii.gz
# Renamed: C836892_4668.nii_0000.nii.gz to C836892_4668_0000.nii.gz
# Renamed: C836892_4790.nii_0000.nii.gz to C836892_4790_0000.nii.gz
# Renamed: C836892_4969.nii_0000.nii.gz to C836892_4969_0000.nii.gz
# Renamed: C836892_4994.nii_0000.nii.gz to C836892_4994_0000.nii.gz
# Renamed: C836892_5081.nii_0000.nii.gz to C836892_5081_0000.nii.gz
# Renamed: C836892_5305.nii_0000.nii.gz to C836892_5305_0000.nii.gz
# Renamed: C836892_5417.nii_0000.nii.gz to C836892_5417_0000.nii.gz
# Renamed: C836892_5648.nii_0000.nii.gz to C836892_5648_0000.nii.gz
# Renamed: C836892_854.nii_0000.nii.gz to C836892_854_0000.nii.gz
# Renamed: C841443_2717.nii_0000.nii.gz to C841443_2717_0000.nii.gz
# Renamed: C84378_3726.nii_0000.nii.gz to C84378_3726_0000.nii.gz
# Renamed: C84501_6510.nii_0000.nii.gz to C84501_6510_0000.nii.gz
# Renamed: C854481_4073.nii_0000.nii.gz to C854481_4073_0000.nii.gz
# Renamed: C854604_6044.nii_0000.nii.gz to C854604_6044_0000.nii.gz
# Renamed: C854604_6149.nii_0000.nii.gz to C854604_6149_0000.nii.gz
# Renamed: C854604_6259.nii_0000.nii.gz to C854604_6259_0000.nii.gz
# Renamed: C854604_6345.nii_0000.nii.gz to C854604_6345_0000.nii.gz
# Renamed: C854604_6436.nii_0000.nii.gz to C854604_6436_0000.nii.gz
# Renamed: C854604_6541.nii_0000.nii.gz to C854604_6541_0000.nii.gz
# Renamed: C854604_6673.nii_0000.nii.gz to C854604_6673_0000.nii.gz
# Renamed: C854604_6910.nii_0000.nii.gz to C854604_6910_0000.nii.gz
# Renamed: C854604_7008.nii_0000.nii.gz to C854604_7008_0000.nii.gz
# Renamed: C854604_7091.nii_0000.nii.gz to C854604_7091_0000.nii.gz
# Renamed: C854604_7192.nii_0000.nii.gz to C854604_7192_0000.nii.gz
# Renamed: C854604_7277.nii_0000.nii.gz to C854604_7277_0000.nii.gz
# Renamed: C854604_7358.nii_0000.nii.gz to C854604_7358_0000.nii.gz
# Renamed: C854604_7452.nii_0000.nii.gz to C854604_7452_0000.nii.gz
# Renamed: C854604_7555.nii_0000.nii.gz to C854604_7555_0000.nii.gz
# Renamed: C854604_7647.nii_0000.nii.gz to C854604_7647_0000.nii.gz
# Renamed: C854604_7728.nii_0000.nii.gz to C854604_7728_0000.nii.gz
# Renamed: C854604_7821.nii_0000.nii.gz to C854604_7821_0000.nii.gz
# Renamed: C854604_7910.nii_0000.nii.gz to C854604_7910_0000.nii.gz
# Renamed: C854604_8005.nii_0000.nii.gz to C854604_8005_0000.nii.gz
# Renamed: C854604_8092.nii_0000.nii.gz to C854604_8092_0000.nii.gz
# Renamed: C854604_8185.nii_0000.nii.gz to C854604_8185_0000.nii.gz
# Renamed: C854604_8277.nii_0000.nii.gz to C854604_8277_0000.nii.gz
# Renamed: C854604_8369.nii_0000.nii.gz to C854604_8369_0000.nii.gz
# Renamed: C854604_8457.nii_0000.nii.gz to C854604_8457_0000.nii.gz
# Renamed: C854604_8512.nii_0000.nii.gz to C854604_8512_0000.nii.gz
# Renamed: C854604_8533.nii_0000.nii.gz to C854604_8533_0000.nii.gz
# Renamed: C854604_8536.nii_0000.nii.gz to C854604_8536_0000.nii.gz
# Renamed: C854604_8542.nii_0000.nii.gz to C854604_8542_0000.nii.gz
# Renamed: C854604_8680.nii_0000.nii.gz to C854604_8680_0000.nii.gz
# Renamed: C857679_1275.nii_0000.nii.gz to C857679_1275_0000.nii.gz
# Renamed: C85977_4739.nii_0000.nii.gz to C85977_4739_0000.nii.gz
# Renamed: C85977_4746.nii_0000.nii.gz to C85977_4746_0000.nii.gz
# Renamed: C860508_2846.nii_0000.nii.gz to C860508_2846_0000.nii.gz
# Renamed: C860508_2850.nii_0000.nii.gz to C860508_2850_0000.nii.gz
# Renamed: C860508_2976.nii_0000.nii.gz to C860508_2976_0000.nii.gz
# Renamed: C860508_3131.nii_0000.nii.gz to C860508_3131_0000.nii.gz
# Renamed: C860508_3235.nii_0000.nii.gz to C860508_3235_0000.nii.gz
# Renamed: C860508_3331.nii_0000.nii.gz to C860508_3331_0000.nii.gz
# Renamed: C860508_3435.nii_0000.nii.gz to C860508_3435_0000.nii.gz
# Renamed: C860508_3523.nii_0000.nii.gz to C860508_3523_0000.nii.gz
# Renamed: C860508_3692.nii_0000.nii.gz to C860508_3692_0000.nii.gz
# Renamed: C860508_3796.nii_0000.nii.gz to C860508_3796_0000.nii.gz
# Renamed: C860508_386.nii_0000.nii.gz to C860508_386_0000.nii.gz
# Renamed: C860508_3879.nii_0000.nii.gz to C860508_3879_0000.nii.gz
# Renamed: C860508_4094.nii_0000.nii.gz to C860508_4094_0000.nii.gz
# Renamed: C860508_4143.nii_0000.nii.gz to C860508_4143_0000.nii.gz
# Renamed: C860508_4275.nii_0000.nii.gz to C860508_4275_0000.nii.gz
# Renamed: C860508_4348.nii_0000.nii.gz to C860508_4348_0000.nii.gz
# Renamed: C860508_4915.nii_0000.nii.gz to C860508_4915_0000.nii.gz
# Renamed: C860508_5003.nii_0000.nii.gz to C860508_5003_0000.nii.gz
# Renamed: C86100_4043.nii_0000.nii.gz to C86100_4043_0000.nii.gz
# Renamed: C868872_3098.nii_0000.nii.gz to C868872_3098_0000.nii.gz
# Renamed: C868872_3101.nii_0000.nii.gz to C868872_3101_0000.nii.gz
# Renamed: C871578_6324.nii_0000.nii.gz to C871578_6324_0000.nii.gz
# Renamed: C871578_6337.nii_0000.nii.gz to C871578_6337_0000.nii.gz
# Renamed: C871578_6344.nii_0000.nii.gz to C871578_6344_0000.nii.gz
# Renamed: C880926_2233.nii_0000.nii.gz to C880926_2233_0000.nii.gz
# Renamed: C883263_5892.nii_0000.nii.gz to C883263_5892_0000.nii.gz
# Renamed: C883263_6017.nii_0000.nii.gz to C883263_6017_0000.nii.gz
# Renamed: C883263_6081.nii_0000.nii.gz to C883263_6081_0000.nii.gz
# Renamed: C883263_6089.nii_0000.nii.gz to C883263_6089_0000.nii.gz
# Renamed: C883263_6112.nii_0000.nii.gz to C883263_6112_0000.nii.gz
# Renamed: C883263_6120.nii_0000.nii.gz to C883263_6120_0000.nii.gz
# Renamed: C883263_6147.nii_0000.nii.gz to C883263_6147_0000.nii.gz
# Renamed: C883263_6149.nii_0000.nii.gz to C883263_6149_0000.nii.gz
# Renamed: C883263_6162.nii_0000.nii.gz to C883263_6162_0000.nii.gz
# Renamed: C883263_6169.nii_0000.nii.gz to C883263_6169_0000.nii.gz
# Renamed: C883263_6171.nii_0000.nii.gz to C883263_6171_0000.nii.gz
# Renamed: C883263_6331.nii_0000.nii.gz to C883263_6331_0000.nii.gz
# Renamed: C883263_6423.nii_0000.nii.gz to C883263_6423_0000.nii.gz
# Renamed: C883263_6511.nii_0000.nii.gz to C883263_6511_0000.nii.gz
# Renamed: C883509_4297.nii_0000.nii.gz to C883509_4297_0000.nii.gz
# Renamed: C883509_4676.nii_0000.nii.gz to C883509_4676_0000.nii.gz
# Renamed: C883509_4932.nii_0000.nii.gz to C883509_4932_0000.nii.gz
# Renamed: C883509_5128.nii_0000.nii.gz to C883509_5128_0000.nii.gz
# Renamed: C883509_5533.nii_0000.nii.gz to C883509_5533_0000.nii.gz
# Renamed: C883509_6079.nii_0000.nii.gz to C883509_6079_0000.nii.gz
# Renamed: C883509_6145.nii_0000.nii.gz to C883509_6145_0000.nii.gz
# Renamed: C883509_6149.nii_0000.nii.gz to C883509_6149_0000.nii.gz
# Renamed: C883509_6236.nii_0000.nii.gz to C883509_6236_0000.nii.gz
# Renamed: C883509_6556.nii_0000.nii.gz to C883509_6556_0000.nii.gz
# Renamed: C883509_7196.nii_0000.nii.gz to C883509_7196_0000.nii.gz
# Renamed: C883632_1982.nii_0000.nii.gz to C883632_1982_0000.nii.gz
# Renamed: C883755_4361.nii_0000.nii.gz to C883755_4361_0000.nii.gz
# Renamed: C88683_1357.nii_0000.nii.gz to C88683_1357_0000.nii.gz
# Renamed: C88929_4486.nii_0000.nii.gz to C88929_4486_0000.nii.gz
# Renamed: C88929_4544.nii_0000.nii.gz to C88929_4544_0000.nii.gz
# Renamed: C88929_4725.nii_0000.nii.gz to C88929_4725_0000.nii.gz
# Renamed: C88929_4790.nii_0000.nii.gz to C88929_4790_0000.nii.gz
# Renamed: C88929_4905.nii_0000.nii.gz to C88929_4905_0000.nii.gz
# Renamed: C88929_5080.nii_0000.nii.gz to C88929_5080_0000.nii.gz
# Renamed: C88929_5088.nii_0000.nii.gz to C88929_5088_0000.nii.gz
# Renamed: C88929_5094.nii_0000.nii.gz to C88929_5094_0000.nii.gz
# Renamed: C90159_2220.nii_0000.nii.gz to C90159_2220_0000.nii.gz
# Renamed: C90159_2223.nii_0000.nii.gz to C90159_2223_0000.nii.gz
# Renamed: C90405_4657.nii_0000.nii.gz to C90405_4657_0000.nii.gz
# Renamed: C90405_4658.nii_0000.nii.gz to C90405_4658_0000.nii.gz
# Renamed: C90528_2209.nii_0000.nii.gz to C90528_2209_0000.nii.gz
# Renamed: C907371_4476.nii_0000.nii.gz to C907371_4476_0000.nii.gz
# Renamed: C907371_4482.nii_0000.nii.gz to C907371_4482_0000.nii.gz
# Renamed: C907617_3446.nii_0000.nii.gz to C907617_3446_0000.nii.gz
# Renamed: C916473_1942.nii_0000.nii.gz to C916473_1942_0000.nii.gz
# Renamed: C916473_1949.nii_0000.nii.gz to C916473_1949_0000.nii.gz
# Renamed: C916473_1956.nii_0000.nii.gz to C916473_1956_0000.nii.gz
# Renamed: C916473_2054.nii_0000.nii.gz to C916473_2054_0000.nii.gz
# Renamed: C916473_2150.nii_0000.nii.gz to C916473_2150_0000.nii.gz
# Renamed: C916473_2255.nii_0000.nii.gz to C916473_2255_0000.nii.gz
# Renamed: C916473_2359.nii_0000.nii.gz to C916473_2359_0000.nii.gz
# Renamed: C916473_2548.nii_0000.nii.gz to C916473_2548_0000.nii.gz
# Renamed: C916473_2711.nii_0000.nii.gz to C916473_2711_0000.nii.gz
# Renamed: C916473_2887.nii_0000.nii.gz to C916473_2887_0000.nii.gz
# Renamed: C916473_3123.nii_0000.nii.gz to C916473_3123_0000.nii.gz
# Renamed: C916473_3503.nii_0000.nii.gz to C916473_3503_0000.nii.gz
# Renamed: C916473_4077.nii_0000.nii.gz to C916473_4077_0000.nii.gz
# Renamed: C916719_4381.nii_0000.nii.gz to C916719_4381_0000.nii.gz
# Renamed: C924714_5108.nii_0000.nii.gz to C924714_5108_0000.nii.gz
# Renamed: C924714_5304.nii_0000.nii.gz to C924714_5304_0000.nii.gz
# Renamed: C924714_5734.nii_0000.nii.gz to C924714_5734_0000.nii.gz
# Renamed: C924714_5908.nii_0000.nii.gz to C924714_5908_0000.nii.gz
# Renamed: C924714_6640.nii_0000.nii.gz to C924714_6640_0000.nii.gz
# Renamed: C924714_7013.nii_0000.nii.gz to C924714_7013_0000.nii.gz
# Renamed: C924714_7378.nii_0000.nii.gz to C924714_7378_0000.nii.gz
# Renamed: C949560_6362.nii_0000.nii.gz to C949560_6362_0000.nii.gz
# Renamed: C949560_6417.nii_0000.nii.gz to C949560_6417_0000.nii.gz
# Renamed: C949683_5382.nii_0000.nii.gz to C949683_5382_0000.nii.gz
# Renamed: C949683_5403.nii_0000.nii.gz to C949683_5403_0000.nii.gz
# Renamed: C95079_1463.nii_0000.nii.gz to C95079_1463_0000.nii.gz
# Renamed: C95079_1465.nii_0000.nii.gz to C95079_1465_0000.nii.gz
# Renamed: C95079_1652.nii_0000.nii.gz to C95079_1652_0000.nii.gz
# Renamed: C95079_1735.nii_0000.nii.gz to C95079_1735_0000.nii.gz
# Renamed: C95079_1828.nii_0000.nii.gz to C95079_1828_0000.nii.gz
# Renamed: C95079_279.nii_0000.nii.gz to C95079_279_0000.nii.gz
# Renamed: C952881_263.nii_0000.nii.gz to C952881_263_0000.nii.gz
# Renamed: C953127_2898.nii_0000.nii.gz to C953127_2898_0000.nii.gz
# Renamed: C953127_3135.nii_0000.nii.gz to C953127_3135_0000.nii.gz
# Renamed: C953127_3866.nii_0000.nii.gz to C953127_3866_0000.nii.gz
# Renamed: C953127_4243.nii_0000.nii.gz to C953127_4243_0000.nii.gz
# Renamed: C953127_4370.nii_0000.nii.gz to C953127_4370_0000.nii.gz
# Renamed: C953127_4664.nii_0000.nii.gz to C953127_4664_0000.nii.gz
# Renamed: C953127_4685.nii_0000.nii.gz to C953127_4685_0000.nii.gz
# Renamed: C953127_4698.nii_0000.nii.gz to C953127_4698_0000.nii.gz
# Renamed: C953127_4716.nii_0000.nii.gz to C953127_4716_0000.nii.gz
# Renamed: C953127_4724.nii_0000.nii.gz to C953127_4724_0000.nii.gz
# Renamed: C953127_4846.nii_0000.nii.gz to C953127_4846_0000.nii.gz
# Renamed: C953127_5024.nii_0000.nii.gz to C953127_5024_0000.nii.gz
# Renamed: C953127_5228.nii_0000.nii.gz to C953127_5228_0000.nii.gz
# Renamed: C953127_5441.nii_0000.nii.gz to C953127_5441_0000.nii.gz
# Renamed: C953127_5529.nii_0000.nii.gz to C953127_5529_0000.nii.gz
# Renamed: C953127_5614.nii_0000.nii.gz to C953127_5614_0000.nii.gz
# Renamed: C953127_5865.nii_0000.nii.gz to C953127_5865_0000.nii.gz
# Renamed: C953127_6364.nii_0000.nii.gz to C953127_6364_0000.nii.gz
# Renamed: C953127_6538.nii_0000.nii.gz to C953127_6538_0000.nii.gz
# Renamed: C953127_6726.nii_0000.nii.gz to C953127_6726_0000.nii.gz
# Renamed: C96186_5391.nii_0000.nii.gz to C96186_5391_0000.nii.gz
# Renamed: C972192_1923.nii_0000.nii.gz to C972192_1923_0000.nii.gz
# Renamed: C972192_2033.nii_0000.nii.gz to C972192_2033_0000.nii.gz
# Renamed: C972192_2264.nii_0000.nii.gz to C972192_2264_0000.nii.gz
# Renamed: C972192_2645.nii_0000.nii.gz to C972192_2645_0000.nii.gz
# Renamed: C972192_3282.nii_0000.nii.gz to C972192_3282_0000.nii.gz
# Renamed: C972192_4388.nii_0000.nii.gz to C972192_4388_0000.nii.gz
# Renamed: C972192_5045.nii_0000.nii.gz to C972192_5045_0000.nii.gz
# Renamed: C972192_5108.nii_0000.nii.gz to C972192_5108_0000.nii.gz
# Renamed: C972192_5354.nii_0000.nii.gz to C972192_5354_0000.nii.gz
# Renamed: C972684_3226.nii_0000.nii.gz to C972684_3226_0000.nii.gz
# Renamed: C972684_3242.nii_0000.nii.gz to C972684_3242_0000.nii.gz
# Renamed: C974898_4039.nii_0000.nii.gz to C974898_4039_0000.nii.gz
# Renamed: C974898_4040.nii_0000.nii.gz to C974898_4040_0000.nii.gz
# Renamed: C974898_4043.nii_0000.nii.gz to C974898_4043_0000.nii.gz
# Renamed: C975636_6075.nii_0000.nii.gz to C975636_6075_0000.nii.gz
# Renamed: C975636_6079.nii_0000.nii.gz to C975636_6079_0000.nii.gz
# Renamed: C98031_5257.nii_0000.nii.gz to C98031_5257_0000.nii.gz
# Renamed: C98031_5258.nii_0000.nii.gz to C98031_5258_0000.nii.gz
# Renamed: C98154_3824.nii_0000.nii.gz to C98154_3824_0000.nii.gz
# Renamed 1878 files.

# %% [markdown]
# ## CBTN Data: Histologies
