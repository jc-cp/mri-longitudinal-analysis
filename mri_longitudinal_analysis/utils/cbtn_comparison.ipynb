# %%
import os
import re
import pandas as pd
from pathlib import Path
import numpy as np
import shutil
import nibabel as nib
from tqdm import tqdm
from collections import defaultdict
from datetime import datetime

# %% [markdown]
# ### Helper functions

# %%
# get patient_ids from a csv file
def extract_unique_patient_ids_from_csv(csv_path):
    cohort = "CBTN"
    id_column = "CBTN Subject ID"
    df = pd.read_csv(csv_path)
    ids = set(df[id_column])
 
    print(f"Length of {cohort} cohort is {len(ids)}.")
    return ids

# get the treatment date for all scans before treatment
def get_first_treatment_dates_new(clinical_csv_path):
    clinical_df = pd.read_csv(clinical_csv_path)
    treatment_ages = {}
    for _, row in clinical_df.iterrows():
        patient_id = row['CBTN Subject ID']
        age = row['Age at First Treatment']
        if pd.isna(age):  # Check if treatment date is not NaN
            treatment_ages[patient_id] = None  # No treatment date recorded
        else: treatment_ages[patient_id] = int(age)
    return treatment_ages

# get the unique ids from the directory where the files were moved
def extract_unique_patient_ids_from_directory(directory_path):
    """
    Extracts the unique patient IDs from the directory where the files were moved.
    """
    patient_ids = set()
    for file in os.listdir(directory_path):
        if file.endswith(".nii.gz"):
            patient_id = file.split("_")[1]
            patient_ids.add(patient_id)
    return patient_ids

def count_files(directory):
    return len([name for name in os.listdir(directory) if os.path.isfile(os.path.join(directory, name))])


proccessed_dir = Path("/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/cbtn_longitudinal_dataset/pre_event/accepted")
ids = extract_unique_patient_ids_from_directory(proccessed_dir)
print(f"Length of processed cohort is {len(ids)}.")
files = count_files(proccessed_dir)
scans = int(files/2)
print(f"Length of processed files is {files}, {scans} scans.")
# Out:
# Length of processed cohort is 0.
# Length of processed files is 0, 0 scans.

# %% [markdown]
# ### Get the treatment dates from csv, compare set of IDs in directory with the ones

# %%
def move_files_to_treatment_folders(clinical_csv_path, source_directory, destination_directory, treatment_ages):
    clinical_df = pd.read_csv(clinical_csv_path)
    os.makedirs(os.path.join(destination_directory, 'pre_treatment'), exist_ok=True)
    os.makedirs(os.path.join(destination_directory, 'post_treatment'), exist_ok=True)
    count = 0 
    pats_failed = set()
    clinical_df['CBTN Subject ID'] = clinical_df['CBTN Subject ID'].astype(str)
    # print(clinical_df['CBTN Subject ID'].values)
    for file_name in os.listdir(source_directory):
        if file_name.endswith('.nii.gz') or file_name.endswith('_mask.nii.gz'):
            parts = file_name.split('_')
            patient_id = parts[1]
            scan_id = parts[2]
            if scan_id.endswith('_mask.nii.gz'):
                scan_id = int(scan_id.split('_')[0])
            else:
                scan_id = int(scan_id.split('.')[0])
            
            #scan_id = age !
                                                                     
            if str(patient_id) not in clinical_df['CBTN Subject ID'].values:
                print(f"Patient ID {patient_id} not found in clinical data. Skipping file {file_name}.")
                count = count + 1
                pats_failed.add(patient_id)
                continue
            
            first_treatment_date = treatment_ages[patient_id]
            if first_treatment_date is None:
                treatment_period = 'pre_treatment'
            else:
                treatment_period = 'pre_treatment' if scan_id < first_treatment_date else 'post_treatment'
                
            # Move the file to the appropriate subfolder
            src_path = os.path.join(source_directory, file_name)
            dest_path = os.path.join(destination_directory, treatment_period, file_name)
            shutil.move(src_path, dest_path)
            print(f"Moved {file_name} to {treatment_period} folder.")
    print(f"Failed on {count} files.  {len(pats_failed)} patients failed: {pats_failed}")


clinical_csv_path = Path("/home/jc053/GIT/mri_longitudinal_analysis/data/input/clinical/cbtn_filtered_pruned_treatment_513.csv")
source_directory = destination_directory = Path("/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/cbtn_longitudinal_dataset/pre_event/accepted")
treatment_ages = get_first_treatment_dates_new(clinical_csv_path)
move_files_to_treatment_folders(clinical_csv_path, source_directory, destination_directory, treatment_ages)
# Out:
# Moved image65_C1077234_6664_mask.nii.gz to pre_treatment folder.
# Moved image57_C1077234_5012_mask.nii.gz to pre_treatment folder.
# Moved image9_C1003434_4457_mask.nii.gz to pre_treatment folder.
# Moved image33_C1042056_2972_mask.nii.gz to pre_treatment folder.
# Moved image73_C1077357_3040_mask.nii.gz to pre_treatment folder.
# Moved image137_C123861_7461_mask.nii.gz to pre_treatment folder.
# Moved image169_C136161_2399_mask.nii.gz to post_treatment folder.
# Moved image49_C1047222_5968_mask.nii.gz to pre_treatment folder.
# Moved image145_C123861_8538_mask.nii.gz to pre_treatment folder.
# Moved image1_C136161_4634_mask.nii.gz to post_treatment folder.
# Moved image289_C2313384_5967_mask.nii.gz to pre_treatment folder.
# Moved image225_C136161_6244_mask.nii.gz to post_treatment folder.
# Moved image241_C140466_6132_mask.nii.gz to post_treatment folder.
# Moved image257_C140466_7336_mask.nii.gz to post_treatment folder.
# Moved image209_C136161_4830_mask.nii.gz to post_treatment folder.
# Moved image281_C19557_701_mask.nii.gz to pre_treatment folder.
# Moved image329_C2354097_3769_mask.nii.gz to pre_treatment folder.
# Moved image313_C2334909_5596_mask.nii.gz to pre_treatment folder.
# Moved image121_C123861_3319_mask.nii.gz to pre_treatment folder.
# Moved image361_C24969_2616_mask.nii.gz to post_treatment folder.
# Moved image345_C2380788_1430_mask.nii.gz to pre_treatment folder.
# Moved image321_C2354097_2737_mask.nii.gz to pre_treatment folder.
# Moved image337_C2354097_4789_mask.nii.gz to pre_treatment folder.
# Moved image129_C123861_4614_mask.nii.gz to pre_treatment folder.
# Moved image26_C1042056_2300_mask.nii.gz to pre_treatment folder.
# Moved image74_C1077357_3076_mask.nii.gz to pre_treatment folder.
# Moved image177_C136161_2752_mask.nii.gz to post_treatment folder.
# Moved image377_C2617194_5332_mask.nii.gz to pre_treatment folder.
# Moved image41_C1042056_4087_mask.nii.gz to pre_treatment folder.
# Moved image34_C1042056_3045_mask.nii.gz to pre_treatment folder.
# Moved image282_C19557_743_mask.nii.gz to pre_treatment folder.
# Moved image217_C136161_5511_mask.nii.gz to post_treatment folder.
# Moved image97_C1095315_7712_mask.nii.gz to pre_treatment folder.
# Moved image50_C1047222_6079_mask.nii.gz to pre_treatment folder.
# Moved image249_C140466_6685_mask.nii.gz to post_treatment folder.
# Moved image153_C1264809_6547_mask.nii.gz to pre_treatment folder.
# Moved image18_C1026312_2883_mask.nii.gz to post_treatment folder.
# Moved image81_C1095315_3270_mask.nii.gz to pre_treatment folder.
# Moved image185_C136161_3353_mask.nii.gz to post_treatment folder.
# Moved image233_C136161_811_mask.nii.gz to post_treatment folder.
# Moved image201_C136161_4516_mask.nii.gz to post_treatment folder.
# Moved image122_C123861_3421_mask.nii.gz to pre_treatment folder.
# Moved image66_C1077234_6845_mask.nii.gz to pre_treatment folder.
# Moved image314_C2334909_5795_mask.nii.gz to pre_treatment folder.
# Moved image210_C136161_4929_mask.nii.gz to post_treatment folder.
# Moved image258_C140466_7418_mask.nii.gz to post_treatment folder.
# Moved image290_C2313384_5971_mask.nii.gz to post_treatment folder.
# Moved image170_C136161_2472_mask.nii.gz to post_treatment folder.
# Moved image27_C1042056_2383_mask.nii.gz to pre_treatment folder.
# Moved image147_C123861_8891_mask.nii.gz to pre_treatment folder.
# Moved image171_C136161_2485_mask.nii.gz to post_treatment folder.
# Moved image28_C1042056_2471_mask.nii.gz to pre_treatment folder.
# Moved image138_C123861_7523_mask.nii.gz to pre_treatment folder.
# Moved image226_C136161_6401_mask.nii.gz to post_treatment folder.
# Moved image242_C140466_6237_mask.nii.gz to post_treatment folder.
# Moved image186_C136161_3436_mask.nii.gz to post_treatment folder.
# Moved image35_C1042056_3118_mask.nii.gz to pre_treatment folder.
# Moved image243_C140466_6325_mask.nii.gz to post_treatment folder.
# Moved image378_C2617194_5333_mask.nii.gz to pre_treatment folder.
# Moved image275_C19188_4132_mask.nii.gz to pre_treatment folder.
# Moved image20_C1026558_4971_mask.nii.gz to pre_treatment folder.
# Moved image67_C1077234_7021_mask.nii.gz to pre_treatment folder.
# Moved image123_C123861_3501_mask.nii.gz to pre_treatment folder.
# Moved image244_C140466_6430_mask.nii.gz to post_treatment folder.
# Moved image211_C136161_5032_mask.nii.gz to post_treatment folder.
# Moved image234_C136161_917_mask.nii.gz to post_treatment folder.
# Moved image330_C2354097_3955_mask.nii.gz to pre_treatment folder.
# Moved image379_C2617194_5335_mask.nii.gz to pre_treatment folder.
# Moved image178_C136161_2833_mask.nii.gz to post_treatment folder.
# Moved image194_C136161_3978_mask.nii.gz to post_treatment folder.
# Moved image315_C2334909_5796_mask.nii.gz to post_treatment folder.
# Moved image338_C2354097_4880_mask.nii.gz to pre_treatment folder.
# Moved image68_C1077234_7223_mask.nii.gz to pre_treatment folder.
# Moved image346_C2380788_1534_mask.nii.gz to pre_treatment folder.
# Moved image218_C136161_5670_mask.nii.gz to post_treatment folder.
# Moved image283_C19557_752_mask.nii.gz to post_treatment folder.
# Moved image250_C140466_6724_mask.nii.gz to post_treatment folder.
# Moved image322_C2354097_2748_mask.nii.gz to pre_treatment folder.
# Moved image172_C136161_2504_mask.nii.gz to post_treatment folder.
# Moved image29_C1042056_2565_mask.nii.gz to pre_treatment folder.
# Moved image227_C136161_6532_mask.nii.gz to post_treatment folder.
# Moved image139_C123861_7579_mask.nii.gz to pre_treatment folder.
# Moved image51_C1060998_6312_mask.nii.gz to pre_treatment folder.
# Moved image316_C2354097_2572_mask.nii.gz to pre_treatment folder.
# Moved image347_C2380788_1842_mask.nii.gz to pre_treatment folder.
# Moved image202_C136161_4521_mask.nii.gz to post_treatment folder.
# Moved image187_C136161_355_mask.nii.gz to post_treatment folder.
# Moved image371_C2568978_3518_mask.nii.gz to pre_treatment folder.
# Moved image291_C2313876_4898_mask.nii.gz to pre_treatment folder.
# Moved image42_C1042056_4169_mask.nii.gz to pre_treatment folder.
# Moved image259_C140466_7509_mask.nii.gz to post_treatment folder.
# Moved image292_C2313876_4908_mask.nii.gz to pre_treatment folder.
# Moved image130_C123861_4929_mask.nii.gz to pre_treatment folder.
# Moved image212_C136161_5091_mask.nii.gz to post_treatment folder.
# Moved image131_C123861_5319_mask.nii.gz to pre_treatment folder.
# Moved image75_C1077357_3083_mask.nii.gz to pre_treatment folder.
# Moved image355_C243540_635_mask.nii.gz to pre_treatment folder.
# Moved image339_C2354097_5028_mask.nii.gz to pre_treatment folder.
# Moved image251_C140466_6799_mask.nii.gz to post_treatment folder.
# Moved image36_C1042056_3218_mask.nii.gz to pre_treatment folder.
# Moved image3_C1003434_3708_mask.nii.gz to pre_treatment folder.
# Moved image30_C1042056_2667_mask.nii.gz to pre_treatment folder.
# Moved image132_C123861_5671_mask.nii.gz to pre_treatment folder.
# Moved image348_C2380788_2099_mask.nii.gz to pre_treatment folder.
# Moved image140_C123861_7677_mask.nii.gz to pre_treatment folder.
# Moved image228_C136161_6645_mask.nii.gz to post_treatment folder.
# Moved image188_C136161_3579_mask.nii.gz to post_treatment folder.
# Moved image21_C1026558_4988_mask.nii.gz to pre_treatment folder.
# Moved image276_C19188_4133_mask.nii.gz to pre_treatment folder.
# Moved image317_C2354097_2574_mask.nii.gz to pre_treatment folder.
# Moved image124_C123861_3680_mask.nii.gz to pre_treatment folder.
# Moved image31_C1042056_2777_mask.nii.gz to pre_treatment folder.
# Moved image156_C136161_1101_mask.nii.gz to post_treatment folder.
# Moved image380_C2617194_5351_mask.nii.gz to pre_treatment folder.
# Moved image245_C140466_6535_mask.nii.gz to post_treatment folder.
# Moved image277_C19188_4138_mask.nii.gz to post_treatment folder.
# Moved image43_C1042179_1256_mask.nii.gz to pre_treatment folder.
# Moved image173_C136161_2515_mask.nii.gz to post_treatment folder.
# Moved image331_C2354097_4133_mask.nii.gz to pre_treatment folder.
# Moved image179_C136161_2933_mask.nii.gz to post_treatment folder.
# Moved image84_C1095315_6276_mask.nii.gz to pre_treatment folder.
# Moved image125_C123861_3823_mask.nii.gz to pre_treatment folder.
# Moved image61_C1077234_6284_mask.nii.gz to pre_treatment folder.
# Moved image236_C140466_5762_mask.nii.gz to post_treatment folder.
# Moved image219_C136161_5759_mask.nii.gz to post_treatment folder.
# Moved image69_C1077234_7398_mask.nii.gz to pre_treatment folder.
# Moved image381_C2617194_5356_mask.nii.gz to post_treatment folder.
# Moved image323_C2354097_2842_mask.nii.gz to pre_treatment folder.
# Moved image174_C136161_2528_mask.nii.gz to post_treatment folder.
# Moved image356_C243540_659_mask.nii.gz to pre_treatment folder.
# Moved image340_C2354097_5286_mask.nii.gz to pre_treatment folder.
# Moved image203_C136161_4584_mask.nii.gz to post_treatment folder.
# Moved image372_C2568978_3561_mask.nii.gz to pre_treatment folder.
# Moved image294_C2318181_4909_mask.nii.gz to pre_treatment folder.
# Moved image382_C2647698_3341_mask.nii.gz to pre_treatment folder.
# Moved image373_C2568978_3890_mask.nii.gz to pre_treatment folder.
# Moved image300_C2334663_5657_mask.nii.gz to pre_treatment folder.
# Moved image229_C136161_6750_mask.nii.gz to post_treatment folder.
# Moved image252_C140466_6888_mask.nii.gz to post_treatment folder.
# Moved image383_C2647698_3392_mask.nii.gz to pre_treatment folder.
# Moved image22_C1026558_4989_mask.nii.gz to post_treatment folder.
# Moved image157_C136161_1225_mask.nii.gz to post_treatment folder.
# Moved image213_C136161_5157_mask.nii.gz to post_treatment folder.
# Moved image301_C2334663_5743_mask.nii.gz to pre_treatment folder.
# Moved image52_C1060998_6327_mask.nii.gz to pre_treatment folder.
# Moved image332_C2354097_4231_mask.nii.gz to pre_treatment folder.
# Moved image196_C136161_4094_mask.nii.gz to post_treatment folder.
# Moved image62_C1077234_6285_mask.nii.gz to pre_treatment folder.
# Moved image246_C140466_6549_mask.nii.gz to post_treatment folder.
# Moved image85_C1095315_6373_mask.nii.gz to pre_treatment folder.
# Moved image44_C1042179_1265_mask.nii.gz to pre_treatment folder.
# Moved image150_C123861_9393_mask.nii.gz to pre_treatment folder.
# Moved image220_C136161_5872_mask.nii.gz to post_treatment folder.
# Moved image37_C1042056_3332_mask.nii.gz to pre_treatment folder.
# Moved image204_C136161_465_mask.nii.gz to post_treatment folder.
# Moved image101_C1232829_1778_mask.nii.gz to pre_treatment folder.
# Moved image133_C123861_6056_mask.nii.gz to pre_treatment folder.
# Moved image341_C2354097_5497_mask.nii.gz to pre_treatment folder.
# Moved image189_C136161_3661_mask.nii.gz to post_treatment folder.
# Moved image318_C2354097_2612_mask.nii.gz to pre_treatment folder.
# Moved image221_C136161_5981_mask.nii.gz to post_treatment folder.
# Moved image374_C2568978_4135_mask.nii.gz to pre_treatment folder.
# Moved image237_C140466_5857_mask.nii.gz to post_treatment folder.
# Moved image158_C136161_1329_mask.nii.gz to post_treatment folder.
# Moved image214_C136161_5291_mask.nii.gz to post_treatment folder.
# Moved image384_C2647698_3509_mask.nii.gz to post_treatment folder.
# Moved image385_C2647698_3650_mask.nii.gz to post_treatment folder.
# Moved image159_C136161_1475_mask.nii.gz to post_treatment folder.
# Moved image333_C2354097_4403_mask.nii.gz to pre_treatment folder.
# Moved image197_C136161_411_mask.nii.gz to post_treatment folder.
# Moved image324_C2354097_2950_mask.nii.gz to pre_treatment folder.
# Moved image180_C136161_3004_mask.nii.gz to post_treatment folder.
# Moved image215_C136161_532_mask.nii.gz to post_treatment folder.
# Moved image254_C140466_7056_mask.nii.gz to post_treatment folder.
# Moved image70_C1077234_7762_mask.nii.gz to pre_treatment folder.
# Moved image45_C1042179_1319_mask.nii.gz to pre_treatment folder.
# Moved image77_C1077357_3195_mask.nii.gz to pre_treatment folder.
# Moved image216_C136161_5425_mask.nii.gz to post_treatment folder.
# Moved image350_C2380788_2176_mask.nii.gz to pre_treatment folder.
# Moved image175_C136161_2634_mask.nii.gz to post_treatment folder.
# Moved image71_C1077234_8133_mask.nii.gz to pre_treatment folder.
# Moved image295_C2318181_4935_mask.nii.gz to pre_treatment folder.
# Moved image342_C2354097_5853_mask.nii.gz to pre_treatment folder.
# Moved image230_C136161_685_mask.nii.gz to post_treatment folder.
# Moved image142_C123861_7894_mask.nii.gz to pre_treatment folder.
# Moved image351_C2380788_2386_mask.nii.gz to pre_treatment folder.
# Moved image190_C136161_3781_mask.nii.gz to post_treatment folder.
# Moved image375_C2568978_4176_mask.nii.gz to pre_treatment folder.
# Moved image302_C2334663_5925_mask.nii.gz to pre_treatment folder.
# Moved image191_C136161_3849_mask.nii.gz to post_treatment folder.
# Moved image167_C136161_229_mask.nii.gz to post_treatment folder.
# Moved image386_C2647698_3829_mask.nii.gz to post_treatment folder.
# Moved image334_C2354097_4511_mask.nii.gz to pre_treatment folder.
# Moved image38_C1042056_3430_mask.nii.gz to pre_treatment folder.
# Moved image127_C123861_4236_mask.nii.gz to pre_treatment folder.
# Moved image325_C2354097_3076_mask.nii.gz to pre_treatment folder.
# Moved image205_C136161_4663_mask.nii.gz to post_treatment folder.
# Moved image192_C136161_3931_mask.nii.gz to post_treatment folder.
# Moved image387_C2647698_3958_mask.nii.gz to post_treatment folder.
# Moved image64_C1077234_6474_mask.nii.gz to pre_treatment folder.
# Moved image102_C1232829_2030_mask.nii.gz to pre_treatment folder.
# Moved image54_C1064934_4527_mask.nii.gz to pre_treatment folder.
# Moved image401_C2697882_5452_mask.nii.gz to pre_treatment folder.
# Moved image255_C140466_7140_mask.nii.gz to post_treatment folder.
# Moved image134_C123861_7328_mask.nii.gz to pre_treatment folder.
# Moved image198_C136161_4206_mask.nii.gz to post_treatment folder.
# Moved image176_C136161_273_mask.nii.gz to post_treatment folder.
# Moved image222_C136161_601_mask.nii.gz to post_treatment folder.
# Moved image72_C1077357_3034_mask.nii.gz to pre_treatment folder.
# Moved image343_C2354097_6000_mask.nii.gz to pre_treatment folder.
# Moved image238_C140466_5905_mask.nii.gz to post_treatment folder.
# Moved image231_C136161_6886_mask.nii.gz to post_treatment folder.
# Moved image256_C140466_7238_mask.nii.gz to post_treatment folder.
# Moved image181_C136161_3102_mask.nii.gz to post_treatment folder.
# Moved image303_C2334663_6114_mask.nii.gz to pre_treatment folder.
# Moved image239_C140466_6010_mask.nii.gz to post_treatment folder.
# Moved image280_C19557_610_mask.nii.gz to pre_treatment folder.
# Moved image128_C123861_4422_mask.nii.gz to pre_treatment folder.
# Moved image335_C2354097_4547_mask.nii.gz to pre_treatment folder.
# Moved image223_C136161_6091_mask.nii.gz to post_treatment folder.
# Moved image119_C123861_3185_mask.nii.gz to pre_treatment folder.
# Moved image240_C140466_6081_mask.nii.gz to post_treatment folder.
# Moved image304_C2334663_6218_mask.nii.gz to pre_treatment folder.
# Moved image388_C2647698_4091_mask.nii.gz to post_treatment folder.
# Moved image55_C1064934_4546_mask.nii.gz to pre_treatment folder.
# Moved image206_C136161_4677_mask.nii.gz to post_treatment folder.
# Moved image143_C123861_8044_mask.nii.gz to pre_treatment folder.
# Moved image224_C136161_6187_mask.nii.gz to post_treatment folder.
# Moved image103_C1232829_3077_mask.nii.gz to pre_treatment folder.
# Moved image376_C2568978_4267_mask.nii.gz to pre_treatment folder.
# Moved image207_C136161_4727_mask.nii.gz to post_treatment folder.
# Moved image410_C2795544_1275_mask.nii.gz to pre_treatment folder.
# Moved image232_C136161_6988_mask.nii.gz to post_treatment folder.
# Moved image481_C2879184_2677_mask.nii.gz to post_treatment folder.
# Moved image489_C2879184_3629_mask.nii.gz to post_treatment folder.
# Moved image497_C311190_4629_mask.nii.gz to pre_treatment folder.
# Moved image272_C154980_3286_mask.nii.gz to pre_treatment folder.
# Moved image8_C1003434_4355_mask.nii.gz to pre_treatment folder.
# Moved image521_C324597_4310_mask.nii.gz to pre_treatment folder.
# Moved image326_C2354097_3213_mask.nii.gz to pre_treatment folder.
# Moved image553_C3396522_2181_mask.nii.gz to pre_treatment folder.
# Moved image498_C311190_4633_mask.nii.gz to post_treatment folder.
# Moved image465_C2855076_5672_mask.nii.gz to pre_treatment folder.
# Moved image336_C2354097_4657_mask.nii.gz to pre_treatment folder.
# Moved image39_C1042056_3597_mask.nii.gz to pre_treatment folder.
# Moved image577_C3396522_905_mask.nii.gz to pre_treatment folder.
# Moved image402_C2697882_5456_mask.nii.gz to pre_treatment folder.
# Moved image593_C3400212_752_mask.nii.gz to pre_treatment folder.
# Moved image120_C123861_3234_mask.nii.gz to pre_treatment folder.
# Moved image199_C136161_4334_mask.nii.gz to post_treatment folder.
# Moved image104_C1232829_3145_mask.nii.gz to pre_treatment folder.
# Moved image144_C123861_8175_mask.nii.gz to pre_treatment folder.
# Moved image135_C123861_7337_mask.nii.gz to pre_treatment folder.
# Moved image473_C2859135_2189_mask.nii.gz to pre_treatment folder.
# Moved image344_C2380788_1318_mask.nii.gz to pre_treatment folder.
# Moved image505_C324351_2484_mask.nii.gz to pre_treatment folder.
# Moved image513_C324351_4157_mask.nii.gz to pre_treatment folder.
# Moved image529_C324597_5325_mask.nii.gz to pre_treatment folder.
# Moved image200_C136161_4499_mask.nii.gz to post_treatment folder.
# Moved image490_C2879184_3869_mask.nii.gz to post_treatment folder.
# Moved image545_C3396522_1416_mask.nii.gz to pre_treatment folder.
# Moved image633_C3557160_1849_mask.nii.gz to pre_treatment folder.
# Moved image626_C3420507_5419_mask.nii.gz to post_treatment folder.
# Moved image561_C3396522_2952_mask.nii.gz to pre_treatment folder.
# Moved image491_C2879184_4006_mask.nii.gz to post_treatment folder.
# Moved image554_C3396522_2258_mask.nii.gz to pre_treatment folder.
# Moved image182_C136161_3152_mask.nii.gz to post_treatment folder.
# Moved image585_C3399720_2914_mask.nii.gz to pre_treatment folder.
# Moved image418_C2819898_5205_mask.nii.gz to post_treatment folder.
# Moved image389_C2647698_4174_mask.nii.gz to post_treatment folder.
# Moved image578_C3396522_999_mask.nii.gz to pre_treatment folder.
# Moved image48_C1047222_5759_mask.nii.gz to pre_treatment folder.
# Moved image360_C24969_2611_mask.nii.gz to pre_treatment folder.
# Moved image390_C2647698_4222_mask.nii.gz to post_treatment folder.
# Moved image459_C28413_731_mask.nii.gz to pre_treatment folder.
# Moved image609_C3420507_2809_mask.nii.gz to post_treatment folder.
# Moved image208_C136161_4797_mask.nii.gz to post_treatment folder.
# Moved image95_C1095315_7537_mask.nii.gz to pre_treatment folder.
# Moved image419_C2832936_5937_mask.nii.gz to pre_treatment folder.
# Moved image411_C2795544_1315_mask.nii.gz to pre_treatment folder.
# Moved image136_C123861_7341_mask.nii.gz to pre_treatment folder.
# Moved image689_C3684711_6009_mask.nii.gz to pre_treatment folder.
# Moved image530_C324597_5503_mask.nii.gz to pre_treatment folder.
# Moved image506_C324351_2745_mask.nii.gz to pre_treatment folder.
# Moved image412_C2795544_1372_mask.nii.gz to post_treatment folder.
# Moved image546_C3396522_1542_mask.nii.gz to pre_treatment folder.
# Moved image562_C3396522_3071_mask.nii.gz to pre_treatment folder.
# Moved image499_C324351_1569_mask.nii.gz to pre_treatment folder.
# Moved image327_C2354097_3402_mask.nii.gz to pre_treatment folder.
# Moved image483_C2879184_2881_mask.nii.gz to post_treatment folder.
# Moved image40_C1042056_3790_mask.nii.gz to pre_treatment folder.
# Moved image705_C3790368_1870_mask.nii.gz to post_treatment folder.
# Moved image183_C136161_316_mask.nii.gz to post_treatment folder.
# Moved image555_C3396522_2346_mask.nii.gz to pre_treatment folder.
# Moved image713_C3790368_518_mask.nii.gz to post_treatment folder.
# Moved image579_C3399720_1953_mask.nii.gz to pre_treatment folder.
# Moved image665_C36654_2829_mask.nii.gz to pre_treatment folder.
# Moved image714_C3790368_606_mask.nii.gz to post_treatment folder.
# Moved image610_C3420507_2947_mask.nii.gz to post_treatment folder.
# Moved image405_C270477_4716_mask.nii.gz to pre_treatment folder.
# Moved image474_C2859135_2192_mask.nii.gz to post_treatment folder.
# Moved image391_C2647698_4226_mask.nii.gz to post_treatment folder.
# Moved image611_C3420507_3043_mask.nii.gz to post_treatment folder.
# Moved image538_C33825_7936_mask.nii.gz to pre_treatment folder.
# Moved image634_C3557160_1912_mask.nii.gz to pre_treatment folder.
# Moved image627_C3420507_5636_mask.nii.gz to post_treatment folder.
# Moved image539_C33825_7943_mask.nii.gz to pre_treatment folder.
# Moved image619_C3420507_4602_mask.nii.gz to post_treatment folder.
# Moved image531_C324597_5734_mask.nii.gz to pre_treatment folder.
# Moved image492_C2879184_4096_mask.nii.gz to post_treatment folder.
# Moved image500_C324351_1609_mask.nii.gz to pre_treatment folder.
# Moved image697_C3790368_1055_mask.nii.gz to post_treatment folder.
# Moved image484_C2879184_2991_mask.nii.gz to post_treatment folder.
# Moved image586_C3399720_3073_mask.nii.gz to pre_treatment folder.
# Moved image706_C3790368_1965_mask.nii.gz to post_treatment folder.
# Moved image184_C136161_3242_mask.nii.gz to post_treatment folder.
# Moved image556_C3396522_2430_mask.nii.gz to pre_treatment folder.
# Moved image467_C2855076_6029_mask.nii.gz to pre_treatment folder.
# Moved image420_C2832936_5949_mask.nii.gz to pre_treatment folder.
# Moved image573_C3396522_604_mask.nii.gz to pre_treatment folder.
# Moved image666_C36654_2899_mask.nii.gz to pre_treatment folder.
# Moved image730_C38868_1357_mask.nii.gz to pre_treatment folder.
# Moved image523_C324597_4505_mask.nii.gz to pre_treatment folder.
# Moved image398_C2653971_7969_mask.nii.gz to pre_treatment folder.
# Moved image690_C3684711_6172_mask.nii.gz to pre_treatment folder.
# Moved image507_C324351_3167_mask.nii.gz to pre_treatment folder.
# Moved image392_C2647698_4258_mask.nii.gz to post_treatment folder.
# Moved image682_C3684588_5876_mask.nii.gz to pre_treatment folder.
# Moved image635_C3557160_2030_mask.nii.gz to pre_treatment folder.
# Moved image328_C2354097_3591_mask.nii.gz to pre_treatment folder.
# Moved image540_C33825_7945_mask.nii.gz to post_treatment folder.
# Moved image563_C3396522_3208_mask.nii.gz to pre_treatment folder.
# Moved image508_C324351_3363_mask.nii.gz to pre_treatment folder.
# Moved image620_C3420507_4784_mask.nii.gz to post_treatment folder.
# Moved image691_C3684711_6255_mask.nii.gz to pre_treatment folder.
# Moved image547_C3396522_1647_mask.nii.gz to pre_treatment folder.
# Moved image532_C324597_5954_mask.nii.gz to pre_treatment folder.
# Moved image501_C324351_1653_mask.nii.gz to pre_treatment folder.
# Moved image548_C3396522_1733_mask.nii.gz to pre_treatment folder.
# Moved image485_C2879184_3267_mask.nii.gz to post_treatment folder.
# Moved image414_C2819775_2795_mask.nii.gz to pre_treatment folder.
# Moved image722_C3817551_3136_mask.nii.gz to pre_treatment folder.
# Moved image549_C3396522_1818_mask.nii.gz to pre_treatment folder.
# Moved image580_C3399720_2044_mask.nii.gz to pre_treatment folder.
# Moved image723_C3817551_3177_mask.nii.gz to pre_treatment folder.
# Moved image557_C3396522_2528_mask.nii.gz to pre_treatment folder.
# Moved image574_C3396522_638_mask.nii.gz to pre_treatment folder.
# Moved image475_C2879184_1137_mask.nii.gz to post_treatment folder.
# Moved image550_C3396522_1909_mask.nii.gz to pre_treatment folder.
# Moved image667_C36654_2992_mask.nii.gz to pre_treatment folder.
# Moved image659_C36654_2549_mask.nii.gz to pre_treatment folder.
# Moved image612_C3420507_3166_mask.nii.gz to post_treatment folder.
# Moved image731_C38868_1447_mask.nii.gz to pre_treatment folder.
# Moved image575_C3396522_722_mask.nii.gz to pre_treatment folder.
# Moved image628_C3420507_5838_mask.nii.gz to post_treatment folder.
# Moved image668_C36654_3123_mask.nii.gz to pre_treatment folder.
# Moved image753_C38868_4938_mask.nii.gz to pre_treatment folder.
# Moved image660_C36654_2601_mask.nii.gz to pre_treatment folder.
# Moved image754_C38868_5031_mask.nii.gz to pre_treatment folder.
# Moved image669_C36654_3237_mask.nii.gz to pre_treatment folder.
# Moved image564_C3396522_3302_mask.nii.gz to pre_treatment folder.
# Moved image493_C2879184_603_mask.nii.gz to post_treatment folder.
# Moved image683_C3684588_5918_mask.nii.gz to pre_treatment folder.
# Moved image509_C324351_3391_mask.nii.gz to pre_treatment folder.
# Moved image541_C3396522_1087_mask.nii.gz to pre_treatment folder.
# Moved image761_C38868_5496_mask.nii.gz to pre_treatment folder.
# Moved image565_C3396522_3406_mask.nii.gz to post_treatment folder.
# Moved image533_C324597_6084_mask.nii.gz to pre_treatment folder.
# Moved image692_C3684711_6441_mask.nii.gz to pre_treatment folder.
# Moved image707_C3790368_2062_mask.nii.gz to post_treatment folder.
# Moved image542_C3396522_1171_mask.nii.gz to pre_treatment folder.
# Moved image486_C2879184_3368_mask.nii.gz to post_treatment folder.
# Moved image415_C2819775_2824_mask.nii.gz to post_treatment folder.
# Moved image607_C3420507_2533_mask.nii.gz to post_treatment folder.
# Moved image581_C3399720_2134_mask.nii.gz to pre_treatment folder.
# Moved image708_C3790368_2146_mask.nii.gz to post_treatment folder.
# Moved image770_C38868_6056_mask.nii.gz to pre_treatment folder.
# Moved image582_C3399720_2317_mask.nii.gz to pre_treatment folder.
# Moved image524_C324597_4597_mask.nii.gz to pre_treatment folder.
# Moved image399_C2653971_8010_mask.nii.gz to pre_treatment folder.
# Moved image613_C3420507_3276_mask.nii.gz to post_treatment folder.
# Moved image738_C38868_2106_mask.nii.gz to pre_treatment folder.
# Moved image732_C38868_1549_mask.nii.gz to pre_treatment folder.
# Moved image583_C3399720_2501_mask.nii.gz to pre_treatment folder.
# Moved image576_C3396522_821_mask.nii.gz to pre_treatment folder.
# Moved image636_C3557160_2096_mask.nii.gz to pre_treatment folder.
# Moved image755_C38868_5075_mask.nii.gz to pre_treatment folder.
# Moved image670_C36654_3447_mask.nii.gz to pre_treatment folder.
# Moved image621_C3420507_5015_mask.nii.gz to post_treatment folder.
# Moved image494_C2879184_820_mask.nii.gz to post_treatment folder.
# Moved image502_C324351_1878_mask.nii.gz to pre_treatment folder.
# Moved image510_C324351_3529_mask.nii.gz to pre_treatment folder.
# Moved image756_C38868_5122_mask.nii.gz to pre_treatment folder.
# Moved image762_C38868_5498_mask.nii.gz to pre_treatment folder.
# Moved image543_C3396522_1248_mask.nii.gz to pre_treatment folder.
# Moved image693_C3684711_6628_mask.nii.gz to pre_treatment folder.
# Moved image588_C3399720_4069_mask.nii.gz to pre_treatment folder.
# Moved image469_C2855076_6342_mask.nii.gz to pre_treatment folder.
# Moved image608_C3420507_2718_mask.nii.gz to post_treatment folder.
# Moved image416_C2819898_5077_mask.nii.gz to pre_treatment folder.
# Moved image558_C3396522_2627_mask.nii.gz to pre_treatment folder.
# Moved image709_C3790368_2248_mask.nii.gz to post_treatment folder.
# Moved image476_C2879184_1507_mask.nii.gz to post_treatment folder.
# Moved image739_C38868_2191_mask.nii.gz to pre_treatment folder.
# Moved image551_C3396522_1999_mask.nii.gz to pre_treatment folder.
# Moved image718_C3790368_925_mask.nii.gz to post_treatment folder.
# Moved image661_C36654_2637_mask.nii.gz to pre_treatment folder.
# Moved image629_C3420507_6057_mask.nii.gz to post_treatment folder.
# Moved image777_C38868_6620_mask.nii.gz to pre_treatment folder.
# Moved image637_C3615216_4140_mask.nii.gz to pre_treatment folder.
# Moved image566_C3396522_3491_mask.nii.gz to post_treatment folder.
# Moved image778_C38868_6704_mask.nii.gz to pre_treatment folder.
# Moved image495_C2879184_948_mask.nii.gz to post_treatment folder.
# Moved image503_C324351_2072_mask.nii.gz to pre_treatment folder.
# Moved image757_C38868_5209_mask.nii.gz to pre_treatment folder.
# Moved image686_C3684711_5895_mask.nii.gz to pre_treatment folder.
# Moved image694_C3684711_6807_mask.nii.gz to pre_treatment folder.
# Moved image779_C38868_6788_mask.nii.gz to pre_treatment folder.
# Moved image758_C38868_5308_mask.nii.gz to pre_treatment folder.
# Moved image589_C3399720_4089_mask.nii.gz to pre_treatment folder.
# Moved image785_C38868_7313_mask.nii.gz to pre_treatment folder.
# Moved image525_C324597_4690_mask.nii.gz to pre_treatment folder.
# Moved image559_C3396522_2725_mask.nii.gz to pre_treatment folder.
# Moved image687_C3684711_5899_mask.nii.gz to pre_treatment folder.
# Moved image793_C38868_8183_mask.nii.gz to pre_treatment folder.
# Moved image772_C38868_6160_mask.nii.gz to pre_treatment folder.
# Moved image801_C393477_5083_mask.nii.gz to post_treatment folder.
# Moved image488_C2879184_3532_mask.nii.gz to post_treatment folder.
# Moved image478_C2879184_1885_mask.nii.gz to post_treatment folder.
# Moved image584_C3399720_2697_mask.nii.gz to pre_treatment folder.
# Moved image740_C38868_2365_mask.nii.gz to pre_treatment folder.
# Moved image552_C3396522_2083_mask.nii.gz to pre_treatment folder.
# Moved image662_C36654_2642_mask.nii.gz to pre_treatment folder.
# Moved image622_C3420507_5141_mask.nii.gz to post_treatment folder.
# Moved image833_C4065273_1594_mask.nii.gz to pre_treatment folder.
# Moved image841_C4065273_2335_mask.nii.gz to pre_treatment folder.
# Moved image638_C3615216_4144_mask.nii.gz to pre_treatment folder.
# Moved image518_C324597_4128_mask.nii.gz to pre_treatment folder.
# Moved image511_C324351_3532_mask.nii.gz to pre_treatment folder.
# Moved image663_C36654_2700_mask.nii.gz to pre_treatment folder.
# Moved image567_C3396522_3575_mask.nii.gz to post_treatment folder.
# Moved image544_C3396522_1332_mask.nii.gz to pre_treatment folder.
# Moved image623_C3420507_5372_mask.nii.gz to post_treatment folder.
# Moved image470_C2855076_6432_mask.nii.gz to pre_treatment folder.
# Moved image504_C324351_2164_mask.nii.gz to pre_treatment folder.
# Moved image780_C38868_6887_mask.nii.gz to pre_treatment folder.
# Moved image590_C3399720_4103_mask.nii.gz to post_treatment folder.
# Moved image786_C38868_7443_mask.nii.gz to pre_treatment folder.
# Moved image526_C324597_4816_mask.nii.gz to pre_treatment folder.
# Moved image560_C3396522_2812_mask.nii.gz to pre_treatment folder.
# Moved image463_C28413_946_mask.nii.gz to pre_treatment folder.
# Moved image817_C3971547_6552_mask.nii.gz to pre_treatment folder.
# Moved image858_C4095900_2075_mask.nii.gz to pre_treatment folder.
# Moved image479_C2879184_2061_mask.nii.gz to post_treatment folder.
# Moved image741_C38868_2576_mask.nii.gz to pre_treatment folder.
# Moved image639_C3615216_4146_mask.nii.gz to post_treatment folder.
# Moved image496_C311190_4621_mask.nii.gz to pre_treatment folder.
# Moved image860_C4095900_2439_mask.nii.gz to pre_treatment folder.
# Moved image834_C4065273_1690_mask.nii.gz to pre_treatment folder.
# Moved image519_C324597_4288_mask.nii.gz to pre_treatment folder.
# Moved image512_C324351_3818_mask.nii.gz to pre_treatment folder.
# Moved image664_C36654_2740_mask.nii.gz to pre_treatment folder.
# Moved image568_C3396522_3663_mask.nii.gz to post_treatment folder.
# Moved image695_C3684711_6990_mask.nii.gz to pre_treatment folder.
# Moved image835_C4065273_1781_mask.nii.gz to pre_treatment folder.
# Moved image836_C4065273_1868_mask.nii.gz to pre_treatment folder.
# Moved image759_C38868_5402_mask.nii.gz to pre_treatment folder.
# Moved image688_C3684711_5912_mask.nii.gz to pre_treatment folder.
# Moved image591_C3400212_676_mask.nii.gz to pre_treatment folder.
# Moved image773_C38868_6249_mask.nii.gz to pre_treatment folder.
# Moved image794_C38868_8284_mask.nii.gz to pre_treatment folder.
# Moved image774_C38868_6335_mask.nii.gz to pre_treatment folder.
# Moved image472_C2859135_2167_mask.nii.gz to pre_treatment folder.
# Moved image712_C3790368_417_mask.nii.gz to post_treatment folder.
# Moved image865_C4095900_3790_mask.nii.gz to pre_treatment folder.
# Moved image480_C2879184_2469_mask.nii.gz to post_treatment folder.
# Moved image735_C38868_1825_mask.nii.gz to pre_treatment folder.
# Moved image937_C4311150_7035_mask.nii.gz to pre_treatment folder.
# Moved image874_C41082_1300_mask.nii.gz to pre_treatment folder.
# Moved image842_C4065273_2433_mask.nii.gz to pre_treatment folder.
# Moved image961_C46863_4227_mask.nii.gz to pre_treatment folder.
# Moved image969_C46863_4627_mask.nii.gz to pre_treatment folder.
# Moved image520_C324597_4305_mask.nii.gz to pre_treatment folder.
# Moved image624_C3420507_5414_mask.nii.gz to post_treatment folder.
# Moved image696_C3684711_7018_mask.nii.gz to pre_treatment folder.
# Moved image1001_C52644_5667_mask.nii.gz to pre_treatment folder.
# Moved image781_C38868_6977_mask.nii.gz to pre_treatment folder.
# Moved image787_C38868_7558_mask.nii.gz to pre_treatment folder.
# Moved image837_C4065273_1950_mask.nii.gz to pre_treatment folder.
# Moved image527_C324597_4940_mask.nii.gz to pre_treatment folder.
# Moved image1010_C53013_5086_mask.nii.gz to pre_treatment folder.
# Moved image795_C38868_8463_mask.nii.gz to pre_treatment folder.
# Moved image775_C38868_6433_mask.nii.gz to pre_treatment folder.
# Moved image1011_C53013_5363_mask.nii.gz to pre_treatment folder.
# Moved image796_C38868_8560_mask.nii.gz to pre_treatment folder.
# Moved image1033_C62730_7556_mask.nii.gz to pre_treatment folder.
# Moved image751_C38868_4933_mask.nii.gz to pre_treatment folder.
# Moved image1012_C53013_5636_mask.nii.gz to pre_treatment folder.
# Moved image1049_C63099_3197_mask.nii.gz to pre_treatment folder.
# Moved image938_C4311150_7039_mask.nii.gz to post_treatment folder.
# Moved image1013_C53013_6371_mask.nii.gz to pre_treatment folder.
# Moved image962_C46863_4240_mask.nii.gz to pre_treatment folder.
# Moved image970_C46863_4722_mask.nii.gz to pre_treatment folder.
# Moved image760_C38868_5488_mask.nii.gz to pre_treatment folder.
# Moved image782_C38868_7075_mask.nii.gz to pre_treatment folder.
# Moved image592_C3400212_695_mask.nii.gz to pre_treatment folder.
# Moved image838_C4065273_2066_mask.nii.gz to pre_treatment folder.
# Moved image528_C324597_5171_mask.nii.gz to pre_treatment folder.
# Moved image819_C3971547_6902_mask.nii.gz to pre_treatment folder.
# Moved image1025_C62730_5579_mask.nii.gz to pre_treatment folder.
# Moved image804_C39483_8422_mask.nii.gz to post_treatment folder.
# Moved image776_C38868_6529_mask.nii.gz to pre_treatment folder.
# Moved image1041_C62730_9467_mask.nii.gz to pre_treatment folder.
# Moved image797_C38868_8651_mask.nii.gz to pre_treatment folder.
# Moved image883_C4127757_626_mask.nii.gz to pre_treatment folder.
# Moved image1081_C719673_8315_mask.nii.gz to pre_treatment folder.
# Moved image875_C41082_1394_mask.nii.gz to pre_treatment folder.
# Moved image1089_C719673_8953_mask.nii.gz to pre_treatment folder.
# Moved image1057_C66420_1293_mask.nii.gz to pre_treatment folder.
# Moved image1034_C62730_7563_mask.nii.gz to pre_treatment folder.
# Moved image843_C4065273_3506_mask.nii.gz to pre_treatment folder.
# Moved image1090_C719673_9036_mask.nii.gz to pre_treatment folder.
# Moved image1014_C53013_6412_mask.nii.gz to pre_treatment folder.
# Moved image971_C46863_4813_mask.nii.gz to pre_treatment folder.
# Moved image1065_C66420_1939_mask.nii.gz to pre_treatment folder.
# Moved image1002_C52644_5777_mask.nii.gz to pre_treatment folder.
# Moved image788_C38868_7674_mask.nii.gz to pre_treatment folder.
# Moved image1073_C719673_7707_mask.nii.gz to pre_treatment folder.
# Moved image1003_C52644_5924_mask.nii.gz to pre_treatment folder.
# Moved image783_C38868_7131_mask.nii.gz to pre_treatment folder.
# Moved image839_C4065273_2150_mask.nii.gz to pre_treatment folder.
# Moved image1113_C735540_4909_mask.nii.gz to pre_treatment folder.
# Moved image1018_C62730_4597_mask.nii.gz to pre_treatment folder.
# Moved image1026_C62730_5676_mask.nii.gz to pre_treatment folder.
# Moved image805_C39606_1301_mask.nii.gz to pre_treatment folder.
# Moved image946_C4312872_4445_mask.nii.gz to pre_treatment folder.
# Moved image752_C38868_4934_mask.nii.gz to pre_treatment folder.
# Moved image798_C38868_8737_mask.nii.gz to pre_treatment folder.
# Moved image947_C4312872_4638_mask.nii.gz to post_treatment folder.
# Moved image1050_C63099_3406_mask.nii.gz to pre_treatment folder.
# Moved image1121_C735540_5563_mask.nii.gz to pre_treatment folder.
# Moved image884_C4127757_627_mask.nii.gz to pre_treatment folder.
# Moved image876_C41082_1475_mask.nii.gz to pre_treatment folder.
# Moved image829_C4065273_1054_mask.nii.gz to pre_treatment folder.
# Moved image994_C48339_2337_mask.nii.gz to post_treatment folder.
# Moved image766_C38868_5717_mask.nii.gz to pre_treatment folder.
# Moved image868_C4095900_482_mask.nii.gz to pre_treatment folder.
# Moved image995_C520905_3470_mask.nii.gz to pre_treatment folder.
# Moved image767_C38868_5817_mask.nii.gz to pre_treatment folder.
# Moved image964_C46863_4299_mask.nii.gz to pre_treatment folder.
# Moved image1097_C719673_9541_mask.nii.gz to pre_treatment folder.
# Moved image1098_C719673_9666_mask.nii.gz to pre_treatment folder.
# Moved image813_C3971547_6177_mask.nii.gz to pre_treatment folder.
# Moved image789_C38868_7821_mask.nii.gz to pre_treatment folder.
# Moved image784_C38868_7223_mask.nii.gz to pre_treatment folder.
# Moved image821_C3971547_7175_mask.nii.gz to pre_treatment folder.
# Moved image1074_C719673_7779_mask.nii.gz to pre_treatment folder.
# Moved image814_C3971547_6309_mask.nii.gz to pre_treatment folder.
# Moved image1027_C62730_5761_mask.nii.gz to pre_treatment folder.
# Moved image1042_C62730_9565_mask.nii.gz to pre_treatment folder.
# Moved image1082_C719673_8406_mask.nii.gz to pre_treatment folder.
# Moved image1051_C63099_3440_mask.nii.gz to pre_treatment folder.
# Moved image1035_C62730_7730_mask.nii.gz to pre_treatment folder.
# Moved image1058_C66420_1474_mask.nii.gz to pre_treatment folder.
# Moved image799_C393477_5065_mask.nii.gz to pre_treatment folder.
# Moved image877_C41082_1582_mask.nii.gz to pre_treatment folder.
# Moved image1091_C719673_9148_mask.nii.gz to pre_treatment folder.
# Moved image830_C4065273_1275_mask.nii.gz to pre_treatment folder.
# Moved image845_C4065273_3611_mask.nii.gz to pre_treatment folder.
# Moved image972_C46863_4933_mask.nii.gz to pre_treatment folder.
# Moved image768_C38868_5908_mask.nii.gz to pre_treatment folder.
# Moved image1066_C66420_2073_mask.nii.gz to pre_treatment folder.
# Moved image965_C46863_4345_mask.nii.gz to pre_treatment folder.
# Moved image1004_C52644_6120_mask.nii.gz to pre_treatment folder.
# Moved image840_C4065273_2238_mask.nii.gz to pre_treatment folder.
# Moved image790_C38868_7915_mask.nii.gz to pre_treatment folder.
# Moved image1114_C735540_4976_mask.nii.gz to pre_treatment folder.
# Moved image1161_C77490_3897_mask.nii.gz to pre_treatment folder.
# Moved image1099_C719673_9855_mask.nii.gz to pre_treatment folder.
# Moved image806_C39606_1345_mask.nii.gz to pre_treatment folder.
# Moved image1028_C62730_5975_mask.nii.gz to pre_treatment folder.
# Moved image1020_C62730_4744_mask.nii.gz to pre_treatment folder.
# Moved image1043_C62730_9981_mask.nii.gz to pre_treatment folder.
# Moved image1021_C62730_4833_mask.nii.gz to pre_treatment folder.
# Moved image932_C4309797_1999_mask.nii.gz to pre_treatment folder.
# Moved image1029_C62730_6138_mask.nii.gz to pre_treatment folder.
# Moved image855_C4095900_1620_mask.nii.gz to pre_treatment folder.
# Moved image1059_C66420_1558_mask.nii.gz to pre_treatment folder.
# Moved image1036_C62730_8097_mask.nii.gz to pre_treatment folder.
# Moved image1130_C744642_1771_mask.nii.gz to pre_treatment folder.
# Moved image800_C393477_5079_mask.nii.gz to pre_treatment folder.
# Moved image878_C41082_1678_mask.nii.gz to pre_treatment folder.
# Moved image1083_C719673_8491_mask.nii.gz to pre_treatment folder.
# Moved image831_C4065273_1404_mask.nii.gz to pre_treatment folder.
# Moved image996_C520905_3555_mask.nii.gz to pre_treatment folder.
# Moved image1092_C719673_9309_mask.nii.gz to pre_treatment folder.
# Moved image973_C46863_5046_mask.nii.gz to pre_treatment folder.
# Moved image943_C4312872_2877_mask.nii.gz to pre_treatment folder.
# Moved image997_C520905_3638_mask.nii.gz to pre_treatment folder.
# Moved image1177_C801960_6475_mask.nii.gz to post_treatment folder.
# Moved image1005_C52644_6334_mask.nii.gz to pre_treatment folder.
# Moved image1075_C719673_7881_mask.nii.gz to pre_treatment folder.
# Moved image990_C48339_2082_mask.nii.gz to post_treatment folder.
# Moved image1185_C801960_7324_mask.nii.gz to post_treatment folder.
# Moved image791_C38868_8007_mask.nii.gz to pre_treatment folder.
# Moved image815_C3971547_6412_mask.nii.gz to pre_treatment folder.
# Moved image1006_C52644_6400_mask.nii.gz to pre_treatment folder.
# Moved image886_C4175850_7121_mask.nii.gz to pre_treatment folder.
# Moved image1030_C62730_6277_mask.nii.gz to pre_treatment folder.
# Moved image856_C4095900_1830_mask.nii.gz to pre_treatment folder.
# Moved image933_C4309797_2219_mask.nii.gz to pre_treatment folder.
# Moved image1060_C66420_1649_mask.nii.gz to pre_treatment folder.
# Moved image1037_C62730_8255_mask.nii.gz to pre_treatment folder.
# Moved image1169_C801960_5763_mask.nii.gz to post_treatment folder.
# Moved image887_C4175850_7134_mask.nii.gz to pre_treatment folder.
# Moved image1038_C62730_8594_mask.nii.gz to pre_treatment folder.
# Moved image1193_C801960_8225_mask.nii.gz to post_treatment folder.
# Moved image966_C46863_4394_mask.nii.gz to pre_treatment folder.
# Moved image888_C4175850_7144_mask.nii.gz to post_treatment folder.
# Moved image1067_C66420_2130_mask.nii.gz to pre_treatment folder.
# Moved image1194_C801960_8399_mask.nii.gz to post_treatment folder.
# Moved image998_C520905_3691_mask.nii.gz to pre_treatment folder.
# Moved image967_C46863_4457_mask.nii.gz to pre_treatment folder.
# Moved image944_C4312872_3276_mask.nii.gz to pre_treatment folder.
# Moved image1178_C801960_6512_mask.nii.gz to post_treatment folder.
# Moved image807_C39606_1367_mask.nii.gz to pre_treatment folder.
# Moved image968_C46863_4534_mask.nii.gz to pre_treatment folder.
# Moved image1186_C801960_7436_mask.nii.gz to post_treatment folder.
# Moved image1108_C735540_4347_mask.nii.gz to pre_treatment folder.
# Moved image1007_C52644_6787_mask.nii.gz to pre_treatment folder.
# Moved image1022_C62730_4925_mask.nii.gz to pre_treatment folder.
# Moved image1053_C663339_7074_mask.nii.gz to pre_treatment folder.
# Moved image1084_C719673_8581_mask.nii.gz to pre_treatment folder.
# Moved image928_C429393_2254_mask.nii.gz to pre_treatment folder.
# Moved image934_C4309797_2394_mask.nii.gz to pre_treatment folder.
# Moved image832_C4065273_1509_mask.nii.gz to pre_treatment folder.
# Moved image879_C41082_185_mask.nii.gz to pre_treatment folder.
# Moved image1093_C719673_9346_mask.nii.gz to pre_treatment folder.
# Moved image1170_C801960_5854_mask.nii.gz to post_treatment folder.
# Moved image1094_C719673_9353_mask.nii.gz to pre_treatment folder.
# Moved image1133_C744642_1998_mask.nii.gz to pre_treatment folder.
# Moved image1095_C719673_9442_mask.nii.gz to pre_treatment folder.
# Moved image1076_C719673_7951_mask.nii.gz to pre_treatment folder.
# Moved image792_C38868_8099_mask.nii.gz to pre_treatment folder.
# Moved image1096_C719673_9487_mask.nii.gz to pre_treatment folder.
# Moved image816_C3971547_6475_mask.nii.gz to pre_treatment folder.
# Moved image1155_C75891_8419_mask.nii.gz to pre_treatment folder.
# Moved image808_C39606_1389_mask.nii.gz to post_treatment folder.
# Moved image1109_C735540_4415_mask.nii.gz to pre_treatment folder.
# Moved image1054_C663339_7155_mask.nii.gz to pre_treatment folder.
# Moved image1110_C735540_4509_mask.nii.gz to pre_treatment folder.
# Moved image1031_C62730_6680_mask.nii.gz to pre_treatment folder.
# Moved image1085_C719673_8680_mask.nii.gz to pre_treatment folder.
# Moved image935_C4309797_2626_mask.nii.gz to pre_treatment folder.
# Moved image1281_C860508_3235_mask.nii.gz to pre_treatment folder.
# Moved image1039_C62730_9137_mask.nii.gz to pre_treatment folder.
# Moved image1171_C801960_5924_mask.nii.gz to post_treatment folder.
# Moved image1289_C860508_4094_mask.nii.gz to pre_treatment folder.
# Moved image1068_C66420_2319_mask.nii.gz to pre_treatment folder.
# Moved image975_C46863_5695_mask.nii.gz to pre_treatment folder.
# Moved image1040_C62730_9306_mask.nii.gz to pre_treatment folder.
# Moved image1241_C836892_4969_mask.nii.gz to pre_treatment folder.
# Moved image1195_C801960_8581_mask.nii.gz to post_treatment folder.
# Moved image1000_C52644_5660_mask.nii.gz to pre_treatment folder.
# Moved image1179_C801960_6617_mask.nii.gz to post_treatment folder.
# Moved image1077_C719673_8009_mask.nii.gz to pre_treatment folder.
# Moved image1305_C883263_6147_mask.nii.gz to post_treatment folder.
# Moved image1257_C854604_7192_mask.nii.gz to pre_treatment folder.
# Moved image1187_C801960_7555_mask.nii.gz to post_treatment folder.
# Moved image1156_C75891_8426_mask.nii.gz to pre_treatment folder.
# Moved image1329_C88929_5080_mask.nii.gz to pre_treatment folder.
# Moved image1165_C77490_4451_mask.nii.gz to pre_treatment folder.
# Moved image1205_C808971_4492_mask.nii.gz to pre_treatment folder.
# Moved image1265_C854604_7910_mask.nii.gz to pre_treatment folder.
# Moved image1258_C854604_7277_mask.nii.gz to pre_treatment folder.
# Moved image1023_C62730_5003_mask.nii.gz to pre_treatment folder.
# Moved image1157_C77490_3478_mask.nii.gz to pre_treatment folder.
# Moved image1218_C83640_1561_mask.nii.gz to pre_treatment folder.
# Moved image1111_C735540_4608_mask.nii.gz to pre_treatment folder.
# Moved image1062_C66420_1813_mask.nii.gz to pre_treatment folder.
# Moved image1273_C854604_8533_mask.nii.gz to pre_treatment folder.
# Moved image880_C41082_271_mask.nii.gz to pre_treatment folder.
# Moved image1086_C719673_8771_mask.nii.gz to pre_treatment folder.
# Moved image1282_C860508_3331_mask.nii.gz to pre_treatment folder.
# Moved image1353_C95079_1652_mask.nii.gz to pre_treatment folder.
# Moved image1297_C883263_5813_mask.nii.gz to post_treatment folder.
# Moved image1069_C66420_2416_mask.nii.gz to pre_treatment folder.
# Moved image1172_C801960_6036_mask.nii.gz to post_treatment folder.
# Moved image1313_C883509_4297_mask.nii.gz to pre_treatment folder.
# Moved image1321_C883509_6236_mask.nii.gz to pre_treatment folder.
# Moved image1173_C801960_6134_mask.nii.gz to post_treatment folder.
# Moved image1180_C801960_6743_mask.nii.gz to post_treatment folder.
# Moved image1078_C719673_8087_mask.nii.gz to pre_treatment folder.
# Moved image1330_C88929_5088_mask.nii.gz to pre_treatment folder.
# Moved image1188_C801960_7646_mask.nii.gz to post_treatment folder.
# Moved image1338_C916473_2359_mask.nii.gz to pre_treatment folder.
# Moved image1166_C801960_5596_mask.nii.gz to pre_treatment folder.
# Moved image1055_C663339_7245_mask.nii.gz to pre_treatment folder.
# Moved image1266_C854604_8005_mask.nii.gz to pre_treatment folder.
# Moved image1393_C2647698_4216_mask.nii.gz to post_treatment folder.
# Moved image1158_C77490_3527_mask.nii.gz to pre_treatment folder.
# Moved image1167_C801960_5632_mask.nii.gz to pre_treatment folder.
# Moved image1345_C924714_5108_mask.nii.gz to pre_treatment folder.
# Moved image1112_C735540_4732_mask.nii.gz to pre_treatment folder.
# Moved image1220_C83640_2336_mask.nii.gz to pre_treatment folder.
# Moved image1063_C66420_1856_mask.nii.gz to pre_treatment folder.
# Moved image1160_C77490_3713_mask.nii.gz to pre_treatment folder.
# Moved image1235_C836892_4150_mask.nii.gz to pre_treatment folder.
# Moved image1087_C719673_8821_mask.nii.gz to pre_treatment folder.
# Moved image1064_C66420_1904_mask.nii.gz to pre_treatment folder.
# Moved image1298_C883263_5892_mask.nii.gz to post_treatment folder.
# Moved image1377_C972192_1923_mask.nii.gz to pre_treatment folder.
# Moved image1291_C860508_4275_mask.nii.gz to pre_treatment folder.
# Moved image1117_C735540_5217_mask.nii.gz to pre_treatment folder.
# Moved image1292_C860508_4915_mask.nii.gz to pre_treatment folder.
# Moved image1385_C972192_5354_mask.nii.gz to pre_treatment folder.
# Moved image1071_C719673_10233_mask.nii.gz to pre_treatment folder.
# Moved image1306_C883263_6149_mask.nii.gz to post_treatment folder.
# Moved image1293_C860508_5003_mask.nii.gz to pre_treatment folder.
# Moved image1322_C883509_6556_mask.nii.gz to pre_treatment folder.
# Moved image1181_C801960_6841_mask.nii.gz to post_treatment folder.
# Moved image1079_C719673_8175_mask.nii.gz to pre_treatment folder.
# Moved image1259_C854604_7358_mask.nii.gz to pre_treatment folder.
# Moved image1307_C883263_6162_mask.nii.gz to post_treatment folder.
# Moved image1189_C801960_7758_mask.nii.gz to post_treatment folder.
# Moved image1024_C62730_5122_mask.nii.gz to pre_treatment folder.
# Moved image1080_C719673_8238_mask.nii.gz to pre_treatment folder.
# Moved image1151_C744642_4962_mask.nii.gz to pre_treatment folder.
# Moved image1260_C854604_7452_mask.nii.gz to pre_treatment folder.
# Moved image1274_C854604_8536_mask.nii.gz to pre_treatment folder.
# Moved image960_C46863_4166_mask.nii.gz to pre_treatment folder.
# Moved image1267_C854604_8092_mask.nii.gz to pre_treatment folder.
# ...
# Moved image1076_C719673_7951.nii.gz to pre_treatment folder.
# Moved image1077_C719673_8009.nii.gz to pre_treatment folder.
# Moved image1078_C719673_8087.nii.gz to pre_treatment folder.
# Moved image1079_C719673_8175.nii.gz to pre_treatment folder.
# Moved image1080_C719673_8238.nii.gz to pre_treatment folder.
# Moved image1081_C719673_8315.nii.gz to pre_treatment folder.
# Moved image1082_C719673_8406.nii.gz to pre_treatment folder.
# Moved image1083_C719673_8491.nii.gz to pre_treatment folder.
# Moved image1084_C719673_8581.nii.gz to pre_treatment folder.
# Moved image1085_C719673_8680.nii.gz to pre_treatment folder.
# Moved image1086_C719673_8771.nii.gz to pre_treatment folder.
# Moved image1087_C719673_8821.nii.gz to pre_treatment folder.
# Moved image1088_C719673_8913.nii.gz to pre_treatment folder.
# Moved image1089_C719673_8953.nii.gz to pre_treatment folder.
# Moved image1090_C719673_9036.nii.gz to pre_treatment folder.
# Moved image1091_C719673_9148.nii.gz to pre_treatment folder.
# Moved image1092_C719673_9309.nii.gz to pre_treatment folder.
# Moved image1093_C719673_9346.nii.gz to pre_treatment folder.
# Moved image1094_C719673_9353.nii.gz to pre_treatment folder.
# Moved image1095_C719673_9442.nii.gz to pre_treatment folder.
# Moved image1096_C719673_9487.nii.gz to pre_treatment folder.
# Moved image1097_C719673_9541.nii.gz to pre_treatment folder.
# Moved image1098_C719673_9666.nii.gz to pre_treatment folder.
# Moved image1099_C719673_9855.nii.gz to pre_treatment folder.
# Moved image1108_C735540_4347.nii.gz to pre_treatment folder.
# Moved image1109_C735540_4415.nii.gz to pre_treatment folder.
# Moved image1110_C735540_4509.nii.gz to pre_treatment folder.
# Moved image1111_C735540_4608.nii.gz to pre_treatment folder.
# Moved image1112_C735540_4732.nii.gz to pre_treatment folder.
# Moved image1113_C735540_4909.nii.gz to pre_treatment folder.
# Moved image1114_C735540_4976.nii.gz to pre_treatment folder.
# Moved image1117_C735540_5217.nii.gz to pre_treatment folder.
# Moved image1118_C735540_5304.nii.gz to pre_treatment folder.
# Moved image1119_C735540_5417.nii.gz to pre_treatment folder.
# Moved image1120_C735540_5476.nii.gz to pre_treatment folder.
# Moved image1121_C735540_5563.nii.gz to pre_treatment folder.
# Moved image1130_C744642_1771.nii.gz to pre_treatment folder.
# Moved image1133_C744642_1998.nii.gz to pre_treatment folder.
# Moved image1151_C744642_4962.nii.gz to pre_treatment folder.
# Moved image1152_C744642_5068.nii.gz to pre_treatment folder.
# Moved image1155_C75891_8419.nii.gz to pre_treatment folder.
# Moved image1156_C75891_8426.nii.gz to pre_treatment folder.
# Moved image1157_C77490_3478.nii.gz to pre_treatment folder.
# Moved image1158_C77490_3527.nii.gz to pre_treatment folder.
# Moved image1160_C77490_3713.nii.gz to pre_treatment folder.
# Moved image1161_C77490_3897.nii.gz to pre_treatment folder.
# Moved image1165_C77490_4451.nii.gz to pre_treatment folder.
# Moved image1166_C801960_5596.nii.gz to pre_treatment folder.
# Moved image1167_C801960_5632.nii.gz to pre_treatment folder.
# Moved image1168_C801960_5707.nii.gz to post_treatment folder.
# Moved image1169_C801960_5763.nii.gz to post_treatment folder.
# Moved image1170_C801960_5854.nii.gz to post_treatment folder.
# Moved image1171_C801960_5924.nii.gz to post_treatment folder.
# Moved image1172_C801960_6036.nii.gz to post_treatment folder.
# Moved image1173_C801960_6134.nii.gz to post_treatment folder.
# Moved image1174_C801960_6260.nii.gz to post_treatment folder.
# Moved image1175_C801960_6358.nii.gz to post_treatment folder.
# Moved image1176_C801960_6456.nii.gz to post_treatment folder.
# Moved image1177_C801960_6475.nii.gz to post_treatment folder.
# Moved image1178_C801960_6512.nii.gz to post_treatment folder.
# Moved image1179_C801960_6617.nii.gz to post_treatment folder.
# Moved image1180_C801960_6743.nii.gz to post_treatment folder.
# Moved image1181_C801960_6841.nii.gz to post_treatment folder.
# Moved image1182_C801960_6939.nii.gz to post_treatment folder.
# Moved image1183_C801960_7051.nii.gz to post_treatment folder.
# Moved image1184_C801960_7205.nii.gz to post_treatment folder.
# Moved image1185_C801960_7324.nii.gz to post_treatment folder.
# Moved image1186_C801960_7436.nii.gz to post_treatment folder.
# Moved image1187_C801960_7555.nii.gz to post_treatment folder.
# Moved image1188_C801960_7646.nii.gz to post_treatment folder.
# Moved image1189_C801960_7758.nii.gz to post_treatment folder.
# Moved image1190_C801960_7877.nii.gz to post_treatment folder.
# Moved image1191_C801960_8029.nii.gz to post_treatment folder.
# Moved image1192_C801960_8119.nii.gz to post_treatment folder.
# Moved image1193_C801960_8225.nii.gz to post_treatment folder.
# Moved image1194_C801960_8399.nii.gz to post_treatment folder.
# Moved image1195_C801960_8581.nii.gz to post_treatment folder.
# Moved image1205_C808971_4492.nii.gz to pre_treatment folder.
# Moved image1214_C818811_4330.nii.gz to pre_treatment folder.
# Moved image1215_C818811_4341.nii.gz to pre_treatment folder.
# Moved image1216_C818811_4366.nii.gz to post_treatment folder.
# Moved image1218_C83640_1561.nii.gz to pre_treatment folder.
# Moved image1220_C83640_2336.nii.gz to pre_treatment folder.
# Moved image1221_C83640_3058.nii.gz to pre_treatment folder.
# Moved image1222_C83640_3099.nii.gz to pre_treatment folder.
# Moved image1234_C836892_3920.nii.gz to pre_treatment folder.
# Moved image1235_C836892_4150.nii.gz to pre_treatment folder.
# Moved image1236_C836892_4255.nii.gz to pre_treatment folder.
# Moved image1237_C836892_4381.nii.gz to pre_treatment folder.
# Moved image1238_C836892_4479.nii.gz to pre_treatment folder.
# Moved image1240_C836892_4790.nii.gz to pre_treatment folder.
# Moved image1241_C836892_4969.nii.gz to pre_treatment folder.
# Moved image1253_C854604_6673.nii.gz to pre_treatment folder.
# Moved image1254_C854604_6910.nii.gz to pre_treatment folder.
# Moved image1255_C854604_7008.nii.gz to pre_treatment folder.
# Moved image1256_C854604_7091.nii.gz to pre_treatment folder.
# Moved image1257_C854604_7192.nii.gz to pre_treatment folder.
# Moved image1258_C854604_7277.nii.gz to pre_treatment folder.
# Moved image1259_C854604_7358.nii.gz to pre_treatment folder.
# Moved image1260_C854604_7452.nii.gz to pre_treatment folder.
# Moved image1261_C854604_7555.nii.gz to pre_treatment folder.
# Moved image1262_C854604_7647.nii.gz to pre_treatment folder.
# Moved image1263_C854604_7728.nii.gz to pre_treatment folder.
# Moved image1264_C854604_7821.nii.gz to pre_treatment folder.
# Moved image1265_C854604_7910.nii.gz to pre_treatment folder.
# Moved image1266_C854604_8005.nii.gz to pre_treatment folder.
# Moved image1267_C854604_8092.nii.gz to pre_treatment folder.
# Moved image1268_C854604_8185.nii.gz to pre_treatment folder.
# Moved image1269_C854604_8277.nii.gz to pre_treatment folder.
# Moved image1270_C854604_8369.nii.gz to pre_treatment folder.
# Moved image1271_C854604_8457.nii.gz to pre_treatment folder.
# Moved image1272_C854604_8512.nii.gz to pre_treatment folder.
# Moved image1273_C854604_8533.nii.gz to pre_treatment folder.
# Moved image1274_C854604_8536.nii.gz to pre_treatment folder.
# Moved image1275_C854604_8542.nii.gz to pre_treatment folder.
# Moved image1276_C854604_8680.nii.gz to pre_treatment folder.
# Moved image1277_C860508_2846.nii.gz to pre_treatment folder.
# Moved image1280_C860508_3131.nii.gz to pre_treatment folder.
# Moved image1281_C860508_3235.nii.gz to pre_treatment folder.
# Moved image1282_C860508_3331.nii.gz to pre_treatment folder.
# Moved image1283_C860508_3435.nii.gz to pre_treatment folder.
# Moved image1284_C860508_3523.nii.gz to pre_treatment folder.
# Moved image1285_C860508_3692.nii.gz to pre_treatment folder.
# Moved image1286_C860508_3796.nii.gz to pre_treatment folder.
# Moved image1288_C860508_3879.nii.gz to pre_treatment folder.
# Moved image1289_C860508_4094.nii.gz to pre_treatment folder.
# Moved image1290_C860508_4143.nii.gz to pre_treatment folder.
# Moved image1291_C860508_4275.nii.gz to pre_treatment folder.
# Moved image1292_C860508_4915.nii.gz to pre_treatment folder.
# Moved image1293_C860508_5003.nii.gz to pre_treatment folder.
# Moved image1296_C871578_6344.nii.gz to post_treatment folder.
# Moved image1297_C883263_5813.nii.gz to post_treatment folder.
# Moved image1298_C883263_5892.nii.gz to post_treatment folder.
# Moved image1299_C883263_6017.nii.gz to post_treatment folder.
# Moved image1300_C883263_6041.nii.gz to post_treatment folder.
# Moved image1301_C883263_6081.nii.gz to post_treatment folder.
# Moved image1302_C883263_6089.nii.gz to post_treatment folder.
# Moved image1303_C883263_6112.nii.gz to post_treatment folder.
# Moved image1304_C883263_6120.nii.gz to post_treatment folder.
# Moved image1305_C883263_6147.nii.gz to post_treatment folder.
# Moved image1306_C883263_6149.nii.gz to post_treatment folder.
# Moved image1307_C883263_6162.nii.gz to post_treatment folder.
# Moved image1308_C883263_6169.nii.gz to post_treatment folder.
# Moved image1309_C883263_6171.nii.gz to post_treatment folder.
# Moved image1310_C883263_6331.nii.gz to post_treatment folder.
# Moved image1311_C883263_6423.nii.gz to post_treatment folder.
# Moved image1312_C883263_6511.nii.gz to post_treatment folder.
# Moved image1313_C883509_4297.nii.gz to pre_treatment folder.
# Moved image1314_C883509_4676.nii.gz to pre_treatment folder.
# Moved image1315_C883509_4932.nii.gz to pre_treatment folder.
# Moved image1316_C883509_5128.nii.gz to pre_treatment folder.
# Moved image1317_C883509_5533.nii.gz to pre_treatment folder.
# Moved image1318_C883509_6079.nii.gz to pre_treatment folder.
# Moved image1319_C883509_6145.nii.gz to pre_treatment folder.
# Moved image1320_C883509_6149.nii.gz to pre_treatment folder.
# Moved image1321_C883509_6236.nii.gz to pre_treatment folder.
# Moved image1322_C883509_6556.nii.gz to pre_treatment folder.
# Moved image1323_C883509_7196.nii.gz to pre_treatment folder.
# Moved image1324_C88929_4486.nii.gz to pre_treatment folder.
# Moved image1326_C88929_4725.nii.gz to pre_treatment folder.
# Moved image1327_C88929_4790.nii.gz to pre_treatment folder.
# Moved image1328_C88929_4905.nii.gz to pre_treatment folder.
# Moved image1329_C88929_5080.nii.gz to pre_treatment folder.
# Moved image1330_C88929_5088.nii.gz to pre_treatment folder.
# Moved image1338_C916473_2359.nii.gz to pre_treatment folder.
# Moved image1339_C916473_2548.nii.gz to pre_treatment folder.
# Moved image1340_C916473_2711.nii.gz to pre_treatment folder.
# Moved image1341_C916473_2887.nii.gz to pre_treatment folder.
# Moved image1342_C916473_3123.nii.gz to pre_treatment folder.
# Moved image1343_C916473_3503.nii.gz to pre_treatment folder.
# Moved image1344_C916473_4077.nii.gz to pre_treatment folder.
# Moved image1345_C924714_5108.nii.gz to pre_treatment folder.
# Moved image1346_C924714_5304.nii.gz to pre_treatment folder.
# Moved image1351_C95079_1463.nii.gz to pre_treatment folder.
# Moved image1352_C95079_1465.nii.gz to pre_treatment folder.
# Moved image1353_C95079_1652.nii.gz to pre_treatment folder.
# Moved image1354_C95079_1735.nii.gz to pre_treatment folder.
# Moved image1355_C95079_1828.nii.gz to pre_treatment folder.
# Moved image1377_C972192_1923.nii.gz to pre_treatment folder.
# Moved image1378_C972192_2033.nii.gz to pre_treatment folder.
# Moved image1379_C972192_2264.nii.gz to pre_treatment folder.
# Moved image1380_C972192_2645.nii.gz to pre_treatment folder.
# Moved image1381_C972192_3282.nii.gz to pre_treatment folder.
# Moved image1382_C972192_4388.nii.gz to pre_treatment folder.
# Moved image1383_C972192_5045.nii.gz to pre_treatment folder.
# Moved image1384_C972192_5108.nii.gz to pre_treatment folder.
# Moved image1385_C972192_5354.nii.gz to pre_treatment folder.
# Moved image1386_C974898_4039.nii.gz to pre_treatment folder.
# Moved image1387_C974898_4040.nii.gz to pre_treatment folder.
# Moved image1388_C974898_4043.nii.gz to post_treatment folder.
# Moved image1391_C2354097_4552.nii.gz to pre_treatment folder.
# Moved image1392_C2354097_5646.nii.gz to pre_treatment folder.
# Moved image1393_C2647698_4216.nii.gz to post_treatment folder.
# Moved image47_C1047222_5220_mask.nii.gz to pre_treatment folder.
# Moved image47_C1047222_5220.nii.gz to pre_treatment folder.
# Moved image56_C1064934_4587_mask.nii.gz to post_treatment folder.
# Moved image56_C1064934_4587.nii.gz to post_treatment folder.
# Moved image161_C136161_1728_mask.nii.gz to post_treatment folder.
# Moved image161_C136161_1728.nii.gz to post_treatment folder.
# Moved image162_C136161_1778_mask.nii.gz to post_treatment folder.
# Moved image162_C136161_1778.nii.gz to post_treatment folder.
# Moved image163_C136161_1867_mask.nii.gz to post_treatment folder.
# Moved image163_C136161_1867.nii.gz to post_treatment folder.
# Moved image193_C136161_3936_mask.nii.gz to post_treatment folder.
# Moved image193_C136161_3936.nii.gz to post_treatment folder.
# Moved image195_C136161_4026_mask.nii.gz to post_treatment folder.
# Moved image195_C136161_4026.nii.gz to post_treatment folder.
# Moved image260_C140466_7588_mask.nii.gz to post_treatment folder.
# Moved image260_C140466_7588.nii.gz to post_treatment folder.
# Moved image319_C2354097_2656_mask.nii.gz to pre_treatment folder.
# Moved image319_C2354097_2656.nii.gz to pre_treatment folder.
# Moved image487_C2879184_3453_mask.nii.gz to post_treatment folder.
# Moved image487_C2879184_3453.nii.gz to post_treatment folder.
# Moved image514_C324351_4652_mask.nii.gz to pre_treatment folder.
# Moved image514_C324351_4652.nii.gz to pre_treatment folder.
# Moved image515_C324351_5530_mask.nii.gz to pre_treatment folder.
# Moved image515_C324351_5530.nii.gz to pre_treatment folder.
# Moved image516_C324351_5882_mask.nii.gz to pre_treatment folder.
# Moved image516_C324351_5882.nii.gz to pre_treatment folder.
# Moved image534_C324597_6311_mask.nii.gz to pre_treatment folder.
# Moved image534_C324597_6311.nii.gz to pre_treatment folder.
# Moved image684_C3684588_5967_mask.nii.gz to pre_treatment folder.
# Moved image684_C3684588_5967.nii.gz to pre_treatment folder.
# Moved image685_C3684588_5968_mask.nii.gz to post_treatment folder.
# Moved image685_C3684588_5968.nii.gz to post_treatment folder.
# Moved image719_C3817551_1232_mask.nii.gz to pre_treatment folder.
# Moved image719_C3817551_1232.nii.gz to pre_treatment folder.
# Moved image720_C3817551_1330_mask.nii.gz to pre_treatment folder.
# Moved image720_C3817551_1330.nii.gz to pre_treatment folder.
# Moved image721_C3817551_1421_mask.nii.gz to pre_treatment folder.
# Moved image721_C3817551_1421.nii.gz to pre_treatment folder.
# Moved image729_C38868_1252_mask.nii.gz to pre_treatment folder.
# Moved image729_C38868_1252.nii.gz to pre_treatment folder.
# Moved image769_C38868_6032_mask.nii.gz to pre_treatment folder.
# Moved image769_C38868_6032.nii.gz to pre_treatment folder.
# Moved image771_C38868_6062_mask.nii.gz to pre_treatment folder.
# Moved image771_C38868_6062.nii.gz to pre_treatment folder.
# Moved image818_C3971547_6754_mask.nii.gz to pre_treatment folder.
# Moved image818_C3971547_6754.nii.gz to pre_treatment folder.
# Moved image820_C3971547_7030_mask.nii.gz to pre_treatment folder.
# Moved image820_C3971547_7030.nii.gz to pre_treatment folder.
# Moved image828_C3971547_9814_mask.nii.gz to pre_treatment folder.
# Moved image828_C3971547_9814.nii.gz to pre_treatment folder.
# Moved image859_C4095900_2271_mask.nii.gz to pre_treatment folder.
# Moved image859_C4095900_2271.nii.gz to pre_treatment folder.
# Moved image1032_C62730_6855.nii.gz to pre_treatment folder.
# Moved image1008_C53013_4399_mask.nii.gz to pre_treatment folder.
# Moved image1009_C53013_4558_mask.nii.gz to pre_treatment folder.
# Moved image1032_C62730_6855_mask.nii.gz to pre_treatment folder.
# Moved image1048_C63099_3057_mask.nii.gz to pre_treatment folder.
# Moved image1234_C836892_3920_mask.nii.gz to pre_treatment folder.
# Moved image1236_C836892_4255_mask.nii.gz to pre_treatment folder.
# Moved image1240_C836892_4790_mask.nii.gz to pre_treatment folder.
# Moved image126_C123861_4026_mask.nii.gz to pre_treatment folder.
# Moved image1276_C854604_8680_mask.nii.gz to pre_treatment folder.
# Moved image1280_C860508_3131_mask.nii.gz to pre_treatment folder.
# Moved image1290_C860508_4143_mask.nii.gz to pre_treatment folder.
# Moved image160_C136161_1598_mask.nii.gz to post_treatment folder.
# Failed on 0 files.  0 patients failed: set()

# %% [markdown]
# ### Compare IDs between folders and move files from exclusion list

# %%
pre_treatment_directory = Path("/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/cbtn_longitudinal_dataset/pre_event/accepted/pre_treatment")
post_treatment_directory = Path("/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/cbtn_longitudinal_dataset/pre_event/accepted/post_treatment")
ids_pre = extract_unique_patient_ids_from_directory(pre_treatment_directory)
ids_post = extract_unique_patient_ids_from_directory(post_treatment_directory)
files_pre = count_files(pre_treatment_directory)
files_post = count_files(post_treatment_directory)
print(f"Unique patient IDs from the post-treatment directory: {len(ids_post)}, Files: {files_post}")
print(f"Unique patient IDs from the pre-treatment directory: {len(ids_pre)}, Files: {files_pre}")

# from the unique ids in the pre-treatment directory, filter out ids and scans belonging to certain patients that are recorded in a exclusion list
def filter_out_excluded_patients(directory_path, exclusion_list):
    """
    Filter out the patients and their scans that are in the exclusion list.
    """
    os.makedirs(os.path.join(directory_path, "filtered"), exist_ok=True)
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            if file.endswith(".nii.gz") or file.endswith("_mask.nii.gz"):
                patient_id = file.split("_")[1]
                if patient_id in exclusion_list:
                    file_path = os.path.join(root, file)
                    dst_path = os.path.join(directory_path, "filtered", file)
                    shutil.move(file_path, dst_path)
                    print(f"Moved {file_path} from the directory.")

#exclusion_list = ["4791484", "298046", "299321", "335968", "4636143", "4159396", "4192047", "233126"]
#filter_out_excluded_patients(pre_treatment_directory, exclusion_list)
#filter_out_excluded_patients(post_treatment_directory, exclusion_list)
# Out:
# Unique patient IDs from the post-treatment directory: 37, Files: 462
# Unique patient IDs from the pre-treatment directory: 91, Files: 1258

# %% [markdown]
# ### Filter patients with less than 3 scans available

# %%
from datetime import datetime, timedelta
# analyze the number of scans per patient in the pre-treatment directory and make sure there are at least three scans per patient
def analyze_scans_per_patient(directory_path):
    """
    Analyze the number of scans per patient in the directory.
    """
    patient_scan_counts = defaultdict(int)
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            if file.endswith(".nii.gz"):
                patient_id = file.split("_")[1]
                patient_scan_counts[patient_id] += 1
    return patient_scan_counts

# for patients with less than 3 scans, move them to a different directory
def move_patients_with_less_than_three_scans(directory_path, pre_treatment_scan_counts, min_scans=6):
    """
    Move the patients with less than the minimum number of scans to a different directory.
    """
    count = 0 
    os.makedirs(os.path.join(directory_path, "insufficient_scans"), exist_ok=True)
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            if file.endswith(".nii.gz"):
                patient_id = file.split("_")[1]
                if pre_treatment_scan_counts[patient_id] < min_scans:
                    file_path = os.path.join(root, file)
                    dst_path = os.path.join(directory_path, "insufficient_scans", file)
                    shutil.move(file_path, dst_path)
                    # print(f"Moved {file_path} to insufficient_scans directory.")
                    count = count + 1
    print(f"Moved {count} files.")


# remember to divide by two since there are two files per scan
pre_treatment_scan_counts = analyze_scans_per_patient(pre_treatment_directory)
print("Number of scans per patient in the pre-treatment directory:", pre_treatment_scan_counts)
move_patients_with_less_than_three_scans(pre_treatment_directory, pre_treatment_scan_counts)
ids_pre = extract_unique_patient_ids_from_directory(pre_treatment_directory)
ids_removed = extract_unique_patient_ids_from_directory(os.path.join(pre_treatment_directory, "insufficient_scans"))
print("Unique patient IDs from the pre-treatment directory after 3 scans condition:", len(ids_pre))
print("Unique patient IDs from the removed directory:", len(ids_removed))
# Out:
# Number of scans per patient in the pre-treatment directory: defaultdict(<class 'int'>, {'C1077234': 22, 'C1003434': 6, 'C1042056': 32, 'C1077357': 10, 'C123861': 56, 'C1047222': 8, 'C2313384': 2, 'C19557': 6, 'C2354097': 58, 'C2334909': 4, 'C2380788': 14, 'C2617194': 8, 'C1095315': 10, 'C1264809': 2, 'C19188': 4, 'C1026558': 4, 'C1060998': 4, 'C2568978': 12, 'C2313876': 4, 'C243540': 4, 'C1042179': 6, 'C2318181': 4, 'C2647698': 4, 'C2334663': 10, 'C1232829': 8, 'C1064934': 4, 'C2697882': 4, 'C2795544': 4, 'C311190': 4, 'C154980': 2, 'C324597': 32, 'C3396522': 60, 'C2855076': 8, 'C3400212': 6, 'C2859135': 4, 'C324351': 36, 'C3557160': 8, 'C3399720': 20, 'C24969': 2, 'C28413': 4, 'C2832936': 4, 'C3684711': 22, 'C36654': 24, 'C270477': 2, 'C33825': 4, 'C38868': 108, 'C2653971': 4, 'C3684588': 6, 'C2819775': 2, 'C3817551': 10, 'C2819898': 2, 'C3615216': 4, 'C4065273': 32, 'C3971547': 20, 'C4095900': 14, 'C4311150': 2, 'C41082': 14, 'C46863': 28, 'C52644': 16, 'C53013': 14, 'C62730': 50, 'C63099': 8, 'C4127757': 4, 'C719673': 58, 'C66420': 24, 'C735540': 24, 'C39606': 6, 'C4312872': 6, 'C520905': 8, 'C393477': 4, 'C77490': 10, 'C4309797': 8, 'C744642': 8, 'C4175850': 4, 'C663339': 6, 'C429393': 2, 'C75891': 4, 'C860508': 28, 'C836892': 14, 'C854604': 48, 'C88929': 12, 'C808971': 2, 'C83640': 8, 'C95079': 10, 'C883509': 22, 'C916473': 14, 'C801960': 4, 'C924714': 4, 'C972192': 18, 'C974898': 4, 'C818811': 4})
# Moved 248 files.
# Unique patient IDs from the pre-treatment directory after 3 scans condition: 55
# Unique patient IDs from the removed directory: 36

# %% [markdown]
# ### Follow-up should be at least 1 year!

# %%
# make sure the first and last scan per paritent are at least 1 year apart, print the patients that do not meet this criteria
def check_time_between_first_and_last_scan(directory_path, min_time_difference=365):
    """
    Check the time difference between the first and last scan for each patient.
    """
    patient_first_last_scan_dates = {}
    fail_ids = []
    for file in os.listdir(directory_path):
        if file.endswith(".nii.gz"):
            patient_id = file.split("_")[1]
            age = file.split("_")[2].split(".")[0]
            
            if patient_id not in patient_first_last_scan_dates:
                patient_first_last_scan_dates[patient_id] = []
            patient_first_last_scan_dates[patient_id].append(int(age))

    for patient_id, ages in patient_first_last_scan_dates.items():
        if len(ages) > 1:
            ages.sort()
            time_difference = ages[-1] - ages[0]
            if abs(time_difference) < min_time_difference:
                print(f"Patient {patient_id} has scans less than 1 year apart: {ages[-1]} - {ages[0]}")
                fail_ids.append(patient_id)

    return fail_ids

fail_ids = check_time_between_first_and_last_scan(pre_treatment_directory)
# count the number of scans (files have format imageXYZ_patientID_scanID.nii.gz) of those patients listed the patient_first_last_scan_dates dictionary as keys above
scan_counts = {}
for file in os.listdir(pre_treatment_directory):
    if file.endswith(".nii.gz"):
        patient_id = file.split("_")[1]
        if patient_id in fail_ids:
            if patient_id not in scan_counts:
                scan_counts[patient_id] = 1
            else:
                scan_counts[patient_id] += 1
print(scan_counts)

#total numebr of files that should be moved due to the time difference condition
total_files = sum(scan_counts.values())
print(f"Total number of files that should be moved due to the time difference condition: {total_files}")
# Out:
# Patient C1042179 has scans less than 1 year apart: 1319 - 1256
# Patient C1077357 has scans less than 1 year apart: 3195 - 3034
# Patient C19557 has scans less than 1 year apart: 743 - 610
# Patient C2617194 has scans less than 1 year apart: 5351 - 5332
# Patient C3400212 has scans less than 1 year apart: 752 - 676
# Patient C3557160 has scans less than 1 year apart: 2096 - 1849
# Patient C3684588 has scans less than 1 year apart: 5967 - 5876
# Patient C39606 has scans less than 1 year apart: 1367 - 1301
# Patient C520905 has scans less than 1 year apart: 3691 - 3470
# Patient C663339 has scans less than 1 year apart: 7245 - 7074
# {'C1042179': 6, 'C1077357': 10, 'C19557': 6, 'C2617194': 8, 'C3400212': 6, 'C3557160': 8, 'C3684588': 6, 'C39606': 6, 'C520905': 8, 'C663339': 6}
# Total number of files that should be moved due to the time difference condition: 70

# %%
# move the patients that do not meet the time difference criteria to a different directory
def move_patients_with_less_than_min_time_difference(directory_path, fail_ids):
    """
    Move the patients with less than the minimum time difference between first and last scan to a different directory.
    """
    os.makedirs(os.path.join(directory_path, "time_difference"), exist_ok=True)
    count = 0
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            if file.endswith(".nii.gz"):
                patient_id = file.split("_")[1]
                if patient_id in fail_ids:
                    file_path = os.path.join(root, file)
                    dst_path = os.path.join(directory_path, "time_difference", file)
                    shutil.move(file_path, dst_path)
                    count = count + 1
    print(f"Moved {count} files.")
    
move_patients_with_less_than_min_time_difference(pre_treatment_directory, fail_ids)
# Out:
# Moved 140 files.

# %% [markdown]
# ### Final count

# %%
# Replace these paths with the actual paths of your directories
final_dir = "/mnt/93E8-0534/JuanCarlos/mri-classification-sequences/cbtn_longitudinal_dataset/pre_event/accepted/pre_treatment"

# Function to extract patientID and scanID
def get_identifier(file_name):
    parts = file_name.split('_')
    return parts[1], parts[2]

# Extract identifiers from both directories
identifiers_ = set()
ids_ = set()
for file_name in os.listdir(final_dir):
    if file_name.endswith(".nii.gz"):
        patid, scanid = get_identifier(file_name)
        identifiers_.add((patid, scanid))
        ids_.add(patid)


print(f"Number of unique patients in final CBTN set: {len(ids_)}")
print(f"Number of total files in final CBTN data: {len(identifiers_)}, scans {int(len(identifiers_) /2)}")
# Out:
# Number of unique patients in final CBTN set: 45
# Number of total files in final CBTN data: 1064, scans 532

# %%
patient_ids = []
files_per_patient = {}

for file in os.listdir(final_dir):
    if file.endswith(".nii.gz"):
        patient_id = file.split("_")[1]
        patient_ids.append(patient_id)
        if patient_id not in files_per_patient:
            files_per_patient[patient_id] = 1
        else:
            files_per_patient[patient_id] += 1

total_patients = len(set(patient_ids))

print("Total number of patients:", total_patients)
print("Number of files per patient:")
for patient_id, file_count in files_per_patient.items():
    print(f"Patient {patient_id}: {int(file_count / 2)} scans")
# Out:
# Total number of patients: 45
# Number of files per patient:
# Patient C1077234: 11 scans
# Patient C1003434: 3 scans
# Patient C1042056: 16 scans
# Patient C123861: 28 scans
# Patient C1047222: 4 scans
# Patient C2354097: 29 scans
# Patient C2380788: 7 scans
# Patient C1095315: 5 scans
# Patient C2568978: 6 scans
# Patient C2334663: 5 scans
# Patient C1232829: 4 scans
# Patient C3396522: 30 scans
# Patient C324597: 16 scans
# Patient C2855076: 4 scans
# Patient C324351: 18 scans
# Patient C3399720: 10 scans
# Patient C3684711: 11 scans
# Patient C36654: 12 scans
# Patient C38868: 54 scans
# Patient C3817551: 5 scans
# Patient C4065273: 16 scans
# Patient C3971547: 10 scans
# Patient C46863: 14 scans
# Patient C52644: 8 scans
# Patient C53013: 7 scans
# Patient C62730: 25 scans
# Patient C63099: 4 scans
# Patient C66420: 12 scans
# Patient C735540: 12 scans
# Patient C4312872: 3 scans
# Patient C4095900: 7 scans
# Patient C77490: 5 scans
# Patient C4309797: 4 scans
# Patient C744642: 4 scans
# Patient C41082: 7 scans
# Patient C860508: 14 scans
# Patient C836892: 7 scans
# Patient C854604: 24 scans
# Patient C88929: 6 scans
# Patient C83640: 4 scans
# Patient C95079: 5 scans
# Patient C883509: 11 scans
# Patient C916473: 7 scans
# Patient C972192: 9 scans
# Patient C719673: 29 scans
